# %%
def extract_event_number(filename):
    """
    Extract event number from filenames like:
    res_23_1993_1_Ens07_binary_10cm.tif -> 1
    res_23_1993_123_Ens07_binary_10cm.tif -> 123
    """
    match = re.search(r'_(\d+)_Ens\d+_(?:binary|filtered)_', filename)
    if match:
        return int(match.group(1))
    return None


def iter_event_tifs(ha_num, data_kind, ensembles=None, thresholds=None):
    """
    Yield metadata for every event tif in:
    tifs/EnsXX_<HA_NUM>/<data_kind>/10cm/*.tif
    tifs/EnsXX_<HA_NUM>/<data_kind>/30cm/*.tif
    """
    if data_kind not in {"binary", "filtered"}:
        raise ValueError(f"Unsupported data_kind={data_kind}")

    ensembles = ensembles or ENSEMBLE_MEMBERS
    thresholds = thresholds or THRESHOLDS
    ha_num = str(ha_num)

    for ens in ensembles:
        ens_name = f"Ens{ens}_{ha_num}"

        for thr in thresholds:
            tif_glob = os.path.join(TIFS_DIR, ens_name, data_kind, thr, "*.tif")
            tif_paths = sorted(glob.glob(tif_glob))

            if not tif_paths:
                print(f"[WARN] No files found: {os.path.dirname(tif_glob)}")
                continue

            for tif_path in tif_paths:
                event_num = extract_event_number(os.path.basename(tif_path))
                if event_num is None:
                    print(f"[WARN] Could not extract event number from: {os.path.basename(tif_path)}")
                    continue
                
                yield {
                    "ha_num": ha_num,
                    "ensemble": ens_name,
                    "threshold": thr,
                    "data_kind": data_kind,
                    "path": tif_path,
                    "event_num": event_num,
                }


def process_single_event_area(binary_file, x5, y5, nx, ny, qa_out_tif=None):
    """
    Process a single binary flood tif and return flooded area per 5km grid cell.
    Maps 30m pixels directly to the original 5km grid using coordinates.
    """
    # Open flood raster
    flood = rxr.open_rasterio(
        binary_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if flood.rio.crs is None or flood.rio.crs.to_string() != "EPSG:27700":
        flood = flood.rio.reproject("EPSG:27700")

    # Identify valid pixels
    valid = flood.notnull()

    # Get flood pixel coordinates and values
    flood_x = flood.x.values
    flood_y = flood.y.values
    
    # Create meshgrid of flood coordinates
    xx, yy = np.meshgrid(flood_x, flood_y)
    
    # Flatten coordinates and values
    x_flat = xx.ravel()
    y_flat = yy.ravel()
    flood_flat = flood.values.ravel()
    valid_flat = valid.values.ravel()
    
    # Only keep valid, flooded pixels
    mask = valid_flat & (flood_flat > 0)
    x_flood = x_flat[mask]
    y_flood = y_flat[mask]
    
    if x_flood.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    # Map flood-pixel centers to 5km cell indices using cell edges.
    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_flood - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_flood) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_flood - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_flood) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)
    
    # Convert 2D indices to 1D linear indices
    linear_idx = iy * nx + ix

    if qa_out_tif is not None:
        # Build QA raster in original 30m grid:
        # value = 5km linear cell index for flooded pixels, -1 elsewhere.
        flooded_flat_idx = np.where(mask)[0]
        flooded_flat_idx_in_grid = flooded_flat_idx[in_grid]
        qa_flat = np.full(flood_flat.shape, -1, dtype=np.int32)
        qa_flat[flooded_flat_idx_in_grid] = linear_idx.astype(np.int32)
        qa_arr = qa_flat.reshape(flood.shape)

        qa_da = xr.DataArray(qa_arr, coords=flood.coords, dims=flood.dims)
        qa_da = qa_da.rio.write_crs(flood.rio.crs)
        qa_da.rio.write_transform(flood.rio.transform(), inplace=True)

        os.makedirs(os.path.dirname(qa_out_tif), exist_ok=True)
        qa_da.rio.to_raster(qa_out_tif)
    
    # Count flooded pixels per grid cell
    counts_flat = np.bincount(linear_idx, minlength=nx * ny)
    counts = counts_flat.reshape(ny, nx)
    
    # Convert flooded-pixel counts to total flooded area using actual raster resolution.
    xres, yres = flood.rio.resolution()
    pixel_area_km2 = (abs(xres) * abs(yres)) / 1e6
    flood_area = counts.astype(np.float32) * pixel_area_km2
    
    return flood_area


def process_single_event_volume(depth_file, x5, y5, nx, ny):
    """
    Process a single depth flood tif and return flooded volume per 5km grid cell.
    Volume is computed as sum(depth_m * pixel_area_m2) over pixels within each 5km cell.
    """
    depth = rxr.open_rasterio(
        depth_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if depth.rio.crs is None or depth.rio.crs.to_string() != "EPSG:27700":
        depth = depth.rio.reproject("EPSG:27700")

    valid = depth.notnull()

    depth_x = depth.x.values
    depth_y = depth.y.values
    xx, yy = np.meshgrid(depth_x, depth_y)

    x_flat = xx.ravel()
    y_flat = yy.ravel()
    depth_flat = depth.values.ravel()
    valid_flat = valid.values.ravel()

    # Only include valid, positive depths in the volume sum.
    mask = valid_flat & (depth_flat > 0)
    x_depth = x_flat[mask]
    y_depth = y_flat[mask]
    depth_vals = depth_flat[mask].astype(np.float64)

    if x_depth.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_depth - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_depth) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_depth - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_depth) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]
    depth_vals = depth_vals[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    linear_idx = iy * nx + ix

    xres, yres = depth.rio.resolution()
    pixel_area_m2 = abs(xres) * abs(yres)

    # Depth rasters are in meters, so depth[m] * area[m2] -> volume[m3].
    contrib_m3 = depth_vals * pixel_area_m2
    volume_flat = np.bincount(linear_idx, weights=contrib_m3, minlength=nx * ny)
    flood_volume = volume_flat.reshape(ny, nx).astype(np.float32)

    return flood_volume

# %%
import os
import glob
import re
import argparse
import xarray as xr
import rioxarray as rxr
import numpy as np
from rasterio.transform import from_bounds

# -----------------------------
# CONFIG
# -----------------------------
ROOT_DIR = "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4"
# OUTPUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

TIFS_DIR = os.path.join(ROOT_DIR, "tifs")

# Your 12 ensembles
ENSEMBLE_MEMBERS = ["01", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "15"]

# Only the two thresholds you care about
THRESHOLDS = ["10cm", "30cm"]

# QA output: write 30m geotiffs showing assigned 5km cell id per flooded pixel.
WRITE_QA_GRID_INDEX_TIF = False
QA_MAX_EVENTS_PER_THRESHOLD = 1

# Input grid
GRID_5KM_FILE = "/scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc"
# GRID_5KM_FILE = "/scratch/hydro5/users/ld14116/SDM_bias_correction/Hourly/01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_20801101-20801130.nc"

# %%
files = os.listdir("/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4/tifs/")

# Extract everything after 'Ens15_'
catchment_numbers = set()
for f in files:
    match = re.search(r'Ens15_(.+)', f)
    if match:
        catchment_numbers.add(match.group(1))

# -----------------------------
# FILTER TO ONLY INCOMPLETE CATCHMENTS
# -----------------------------
def all_outputs_exist(ha_num):
    out_dir_base = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{ha_num}"
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(out_dir_base, f"Ens{ens}_{ha_num}", thr)
            for kind in ("area", "volume"):
                fname = f"flooded_{kind}_5km_total_Ens{ens}_{ha_num}_{thr}.nc"
                if not os.path.exists(os.path.join(out_dir, fname)):
                    return False
    return True

catchments_to_skip = {c for c in catchment_numbers if all_outputs_exist(c)}
catchments_to_run = catchment_numbers - catchments_to_skip

print(f"{len(catchments_to_skip)} catchments already complete, skipping.")
print(f"{len(catchments_to_run)} catchments to process: {sorted(catchments_to_run)}")
# Out:
# 41 catchments already complete, skipping.
# 73 catchments to process: ['10', '105', '106', '107', '11', '16', '17', '19', '2', '21', '22', '24', '25', '27_a', '27_b', '27_c', '28_a', '28_b', '3', '30', '31', '32', '33_b', '34', '35', '37', '38', '39_a', '39_b', '39_d', '4', '41', '42', '43', '45', '46', '47', '49', '50', '51', '54_a', '54_b', '54_c', '54_d', '55', '56', '57', '58', '6', '60', '61', '62', '63', '65', '66', '67', '69', '71', '72', '74', '76', '79', '8', '83', '85', '87', '88', '89', '92', '93', '94', '95', '97']

# %%
for HA_NUM in catchments_to_run:
    print(f"Running for {HA_NUM}")
    OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"
    print(f"Outputs to be stored in {OUT_DIR}")
    
    # -----------------------------
    # OPEN 5km GRID
    # -----------------------------
    print(f"Loading 5km grid from {GRID_5KM_FILE}...")
    ds = xr.open_dataset(GRID_5KM_FILE)

    x5 = ds["projection_x_coordinate"]
    y5 = ds["projection_y_coordinate"]

    nx = x5.size
    ny = y5.size

    dx = float(abs(x5[1] - x5[0]))
    dy = float(abs(y5[1] - y5[0]))

    xmin = float(x5.min() - dx/2)
    xmax = float(x5.max() + dx/2)
    ymin = float(y5.min() - dy/2)
    ymax = float(y5.max() + dy/2)

    # -----------------------------
    # CREATE GRID-ID RASTER
    # -----------------------------
    grid_ids = np.arange(nx * ny).reshape(ny, nx)

    # Use standard y, x dimension names for rioxarray compatibility
    grid_da = xr.DataArray(
        grid_ids,
        coords={"y": y5.values, "x": x5.values},
        dims=("y", "x")
    )

    grid_da = grid_da.rio.write_crs("EPSG:27700")

    transform = from_bounds(xmin, ymin, xmax, ymax, nx, ny)
    grid_da.rio.write_transform(transform, inplace=True)

    # Export a GeoTIFF copy of the 5km grid IDs for visual QA.
    # grid_out_dir = os.path.join(OUT_DIR, "grid")
    # os.makedirs(grid_out_dir, exist_ok=True)
    # grid_tif_path = os.path.join(grid_out_dir, f"grid_id_5km_from_input_{HA_NUM}.tif")
    # print(f"Saving 5km grid GeoTIFF to {grid_tif_path}...")
    # grid_da.astype("int32").rio.to_raster(grid_tif_path)

    # -----------------------------
    # COLLECT ALL EVENT FILES
    # -----------------------------
    print(f"Scanning for binary tif files for HA_NUM={HA_NUM}...")
    binary_event_files = list(iter_event_tifs(HA_NUM, data_kind="binary"))

    print(f"Scanning for filtered depth tif files for HA_NUM={HA_NUM}...")
    filtered_event_files = list(iter_event_tifs(HA_NUM, data_kind="filtered"))

    if not binary_event_files:
        raise ValueError(f"No binary tif files found for HA_NUM={HA_NUM}")

    if not filtered_event_files:
        raise ValueError(f"No filtered depth tif files found for HA_NUM={HA_NUM}")

    print(f"Found {len(binary_event_files)} binary event files")
    print(f"Found {len(filtered_event_files)} filtered depth event files")

    # -----------------------------
    # GROUP BY ENSEMBLE
    # -----------------------------
    from collections import defaultdict
    binary_by_ensemble = defaultdict(list)
    filtered_lookup = {}

    for info in binary_event_files:
        binary_by_ensemble[info['ensemble']].append(info)

    for info in filtered_event_files:
        key = (info["ensemble"], info["threshold"], info["event_num"])
        filtered_lookup[key] = info

    print(f"Found {len(binary_by_ensemble)} ensemble members")

    # -----------------------------
    # PROCESS EACH ENSEMBLE + THRESHOLD SEPARATELY
    # -----------------------------
    for ens_name in sorted(binary_by_ensemble.keys()):
        ens_events = binary_by_ensemble[ens_name]
        ens_events.sort(key=lambda x: (x['threshold'], x['event_num']))

        print(f"\n{'='*60}")
        print(f"Processing {ens_name}: {len(ens_events)} total events")
        print(f"{'='*60}")

        for thr in THRESHOLDS:
            thr_events = [e for e in ens_events if e["threshold"] == thr]
            if not thr_events:
                print(f"[WARN] No events for {ens_name} threshold {thr}")
                continue

            print(f"\n[{ens_name} | {thr}] Processing {len(thr_events)} events")

            flood_areas = []
            flood_volumes = []
            for i, info in enumerate(thr_events):
                print(f"[{i+1}/{len(thr_events)}] Processing {os.path.basename(info['path'])} (event={info['event_num']})")

                key = (ens_name, thr, info["event_num"])
                if key not in filtered_lookup:
                    raise ValueError(
                        f"Missing filtered depth tif for {ens_name}, {thr}, event={info['event_num']}"
                    )

                filtered_info = filtered_lookup[key]

                qa_out_tif = None
                if WRITE_QA_GRID_INDEX_TIF and i < QA_MAX_EVENTS_PER_THRESHOLD:
                    print("Performing QA")
                    qa_dir = os.path.join(OUT_DIR, "qa", ens_name, thr)
                    qa_out_tif = os.path.join(
                        qa_dir,
                        f"qa_5km_cell_index_{ens_name}_{thr}_event_{info['event_num']:03d}.tif"
                    )
                    print(f"    Writing QA 30m->5km index raster: {qa_out_tif}")
                else:
                    print("Skippping QA")

                flood_area = process_single_event_area(
                    info['path'],
                    x5, y5, nx, ny,
                    qa_out_tif=qa_out_tif)

                flood_volume = process_single_event_volume(
                    filtered_info["path"],
                    x5, y5, nx, ny)

                total_km2 = float(np.sum(flood_area))
                total_m3 = float(np.sum(flood_volume))
                print(f"    Total flooded area (sum of 5km cells): {total_km2:.4f} km2")
                print(f"    Total flooded volume (sum of 5km cells): {total_m3:.2f} m3")
                flood_areas.append(flood_area)
                flood_volumes.append(flood_volume)

            flood_areas_stack = np.stack(flood_areas, axis=0)
            flood_volumes_stack = np.stack(flood_volumes, axis=0)
            event_nums = np.array([info['event_num'] for info in thr_events], dtype=np.int32)

            out_area = xr.Dataset(
                {
                    "flooded_area_5km_km2": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_areas_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            out_volume = xr.Dataset(
                {
                    "flooded_volume_5km_m3": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_volumes_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            for out_ds in (out_area, out_volume):
                out_ds["projection_x_coordinate"].attrs.update({
                    "standard_name": "projection_x_coordinate",
                    "long_name": "x coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["projection_y_coordinate"].attrs.update({
                    "standard_name": "projection_y_coordinate",
                    "long_name": "y coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["event_num"].attrs["long_name"] = "event number"
                out_ds["event"].attrs["long_name"] = "event number"

            out_area = out_area.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_area.rio.write_transform(transform, inplace=True)
            out_area.rio.write_crs("EPSG:27700", inplace=True)
            out_area.rio.write_coordinate_system(inplace=True)

            out_volume = out_volume.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_volume.rio.write_transform(transform, inplace=True)
            out_volume.rio.write_crs("EPSG:27700", inplace=True)
            out_volume.rio.write_coordinate_system(inplace=True)

            out_area["flooded_area_5km_km2"].attrs["long_name"] = "Total flooded area per 5km grid cell"
            out_area["flooded_area_5km_km2"].attrs["units"] = "km2"
            out_volume["flooded_volume_5km_m3"].attrs["long_name"] = "Total flooded volume per 5km grid cell"
            out_volume["flooded_volume_5km_m3"].attrs["units"] = "m3"

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

            print(f"Saving area to {output_area_nc}...")
            out_area.to_netcdf(output_area_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_area_nc}")

            print(f"Saving volume to {output_volume_nc}...")
            out_volume.to_netcdf(output_volume_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_volume_nc}")

    print(f"\n{'='*60}")
    print(f"All {len(binary_by_ensemble)} ensemble members processed!")
# Out:
# Running for 21
# Outputs to be stored in /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_21
# Loading 5km grid from /scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc...
# Scanning for binary tif files for HA_NUM=21...
# Scanning for filtered depth tif files for HA_NUM=21...
# Found 3168 binary event files
# Found 3168 filtered depth event files
# Found 12 ensemble members
#
# ============================================================
# Processing Ens01_21: 298 total events
# ============================================================
#
# [Ens01_21 | 10cm] Processing 149 events
# [1/149] Processing res_21_1991_1_Ens01_binary_10cm.tif (event=1)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7326 km2
#     Total flooded volume (sum of 5km cells): 202841.08 m3
# [2/149] Processing res_21_1992_2_Ens01_binary_10cm.tif (event=2)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4815 km2
#     Total flooded volume (sum of 5km cells): 155520.00 m3
# [3/149] Processing res_21_1993_3_Ens01_binary_10cm.tif (event=3)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0790 km2
#     Total flooded volume (sum of 5km cells): 825432.25 m3
# [4/149] Processing res_21_1995_4_Ens01_binary_10cm.tif (event=4)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1221 km2
#     Total flooded volume (sum of 5km cells): 1255041.00 m3
# [5/149] Processing res_21_1995_5_Ens01_binary_10cm.tif (event=5)
# Skippping QA
#     Total flooded area (sum of 5km cells): 22.0626 km2
#     Total flooded volume (sum of 5km cells): 9116266.00 m3
# [6/149] Processing res_21_1998_6_Ens01_binary_10cm.tif (event=6)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2249 km2
#     Total flooded volume (sum of 5km cells): 331761.59 m3
# [7/149] Processing res_21_2001_7_Ens01_binary_10cm.tif (event=7)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4814 km2
#     Total flooded volume (sum of 5km cells): 632252.69 m3
# [8/149] Processing res_21_2002_8_Ens01_binary_10cm.tif (event=8)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.8816 km2
#     Total flooded volume (sum of 5km cells): 1883695.50 m3
# [9/149] Processing res_21_2004_9_Ens01_binary_10cm.tif (event=9)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7776 km2
#     Total flooded volume (sum of 5km cells): 226449.00 m3
# [10/149] Processing res_21_2008_10_Ens01_binary_10cm.tif (event=10)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0387 km2
#     Total flooded volume (sum of 5km cells): 9088.20 m3
# [11/149] Processing res_21_2008_11_Ens01_binary_10cm.tif (event=11)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4086 km2
#     Total flooded volume (sum of 5km cells): 99468.91 m3
# [12/149] Processing res_21_2009_12_Ens01_binary_10cm.tif (event=12)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2349 km2
#     Total flooded volume (sum of 5km cells): 169126.22 m3
# [13/149] Processing res_21_2013_13_Ens01_binary_10cm.tif (event=13)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.0859 km2
#     Total flooded volume (sum of 5km cells): 1706044.50 m3
# [14/149] Processing res_21_2016_14_Ens01_binary_10cm.tif (event=14)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7416 km2
#     Total flooded volume (sum of 5km cells): 308520.91 m3
# [15/149] Processing res_21_2016_15_Ens01_binary_10cm.tif (event=15)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.5938 km2
#     Total flooded volume (sum of 5km cells): 1265518.00 m3
# [16/149] Processing res_21_2017_16_Ens01_binary_10cm.tif (event=16)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6705 km2
#     Total flooded volume (sum of 5km cells): 193914.92 m3
# [17/149] Processing res_21_2017_17_Ens01_binary_10cm.tif (event=17)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.9602 km2
#     Total flooded volume (sum of 5km cells): 7819437.50 m3
# [18/149] Processing res_21_2017_18_Ens01_binary_10cm.tif (event=18)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7794 km2
#     Total flooded volume (sum of 5km cells): 290948.38 m3
# [19/149] Processing res_21_2018_19_Ens01_binary_10cm.tif (event=19)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0206 km2
#     Total flooded volume (sum of 5km cells): 296083.78 m3
# [20/149] Processing res_21_2019_20_Ens01_binary_10cm.tif (event=20)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1566 km2
#     Total flooded volume (sum of 5km cells): 48976.20 m3
# [21/149] Processing res_21_2020_21_Ens01_binary_10cm.tif (event=21)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.8726 km2
#     Total flooded volume (sum of 5km cells): 1998334.88 m3
# [22/149] Processing res_21_2020_22_Ens01_binary_10cm.tif (event=22)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3744 km2
#     Total flooded volume (sum of 5km cells): 143396.09 m3
# [23/149] Processing res_21_2023_23_Ens01_binary_10cm.tif (event=23)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.0419 km2
#     Total flooded volume (sum of 5km cells): 4315973.50 m3
# [24/149] Processing res_21_2023_24_Ens01_binary_10cm.tif (event=24)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.3215 km2
#     Total flooded volume (sum of 5km cells): 2651060.75 m3
# [25/149] Processing res_21_2023_25_Ens01_binary_10cm.tif (event=25)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.2804 km2
#     Total flooded volume (sum of 5km cells): 1442050.25 m3
# [26/149] Processing res_21_2025_26_Ens01_binary_10cm.tif (event=26)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.0313 km2
#     Total flooded volume (sum of 5km cells): 3625374.75 m3
# [27/149] Processing res_21_2026_27_Ens01_binary_10cm.tif (event=27)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.8907 km2
#     Total flooded volume (sum of 5km cells): 1566042.25 m3
# [28/149] Processing res_21_2026_28_Ens01_binary_10cm.tif (event=28)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2790 km2
#     Total flooded volume (sum of 5km cells): 123616.80 m3
# [29/149] Processing res_21_2027_29_Ens01_binary_10cm.tif (event=29)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.2424 km2
#     Total flooded volume (sum of 5km cells): 1888792.25 m3
# [30/149] Processing res_21_2027_30_Ens01_binary_10cm.tif (event=30)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.9280 km2
#     Total flooded volume (sum of 5km cells): 3714342.25 m3
# [31/149] Processing res_21_2029_31_Ens01_binary_10cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7307 km2
#     Total flooded volume (sum of 5km cells): 472285.78 m3
# [32/149] Processing res_21_2030_32_Ens01_binary_10cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6462 km2
#     Total flooded volume (sum of 5km cells): 164155.50 m3
# [33/149] Processing res_21_2030_33_Ens01_binary_10cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.1057 km2
#     Total flooded volume (sum of 5km cells): 1719013.62 m3
# [34/149] Processing res_21_2031_34_Ens01_binary_10cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1719 km2
#     Total flooded volume (sum of 5km cells): 63299.70 m3
# [35/149] Processing res_21_2032_35_Ens01_binary_10cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 25.8192 km2
#     Total flooded volume (sum of 5km cells): 9610180.00 m3
# [36/149] Processing res_21_2033_36_Ens01_binary_10cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2473 km2
#     Total flooded volume (sum of 5km cells): 862742.69 m3
# [37/149] Processing res_21_2035_37_Ens01_binary_10cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.2767 km2
#     Total flooded volume (sum of 5km cells): 1733232.50 m3
# [38/149] Processing res_21_2036_38_Ens01_binary_10cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7037 km2
#     Total flooded volume (sum of 5km cells): 594130.50 m3
# [39/149] Processing res_21_2036_39_Ens01_binary_10cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7846 km2
#     Total flooded volume (sum of 5km cells): 1202339.75 m3
# [40/149] Processing res_21_2037_40_Ens01_binary_10cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2133 km2
#     Total flooded volume (sum of 5km cells): 70258.50 m3
# [41/149] Processing res_21_2037_41_Ens01_binary_10cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2122 km2
#     Total flooded volume (sum of 5km cells): 690466.50 m3
# [42/149] Processing res_21_2040_42_Ens01_binary_10cm.tif (event=42)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1015 km2
#     Total flooded volume (sum of 5km cells): 1060414.25 m3
# [43/149] Processing res_21_2040_43_Ens01_binary_10cm.tif (event=43)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6153 km2
#     Total flooded volume (sum of 5km cells): 1194327.00 m3
# [44/149] Processing res_21_2040_44_Ens01_binary_10cm.tif (event=44)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7758 km2
#     Total flooded volume (sum of 5km cells): 241034.41 m3
# [45/149] Processing res_21_2040_45_Ens01_binary_10cm.tif (event=45)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.4903 km2
#     Total flooded volume (sum of 5km cells): 825782.38 m3
# [46/149] Processing res_21_2041_46_Ens01_binary_10cm.tif (event=46)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2177 km2
#     Total flooded volume (sum of 5km cells): 375002.09 m3
# [47/149] Processing res_21_2041_47_Ens01_binary_10cm.tif (event=47)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.9456 km2
#     Total flooded volume (sum of 5km cells): 1147895.00 m3
# [48/149] Processing res_21_2041_48_Ens01_binary_10cm.tif (event=48)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0035 km2
#     Total flooded volume (sum of 5km cells): 308364.28 m3
# [49/149] Processing res_21_2041_49_Ens01_binary_10cm.tif (event=49)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6261 km2
#     Total flooded volume (sum of 5km cells): 1257044.50 m3
# [50/149] Processing res_21_2041_50_Ens01_binary_10cm.tif (event=50)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3861 km2
#     Total flooded volume (sum of 5km cells): 167634.89 m3
# [51/149] Processing res_21_2041_51_Ens01_binary_10cm.tif (event=51)
# Skippping QA
#     Total flooded area (sum of 5km cells): 21.9312 km2
#     Total flooded volume (sum of 5km cells): 8623940.00 m3
# [52/149] Processing res_21_2041_52_Ens01_binary_10cm.tif (event=52)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6252 km2
#     Total flooded volume (sum of 5km cells): 1253293.25 m3
# [53/149] Processing res_21_2041_53_Ens01_binary_10cm.tif (event=53)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1403 km2
#     Total flooded volume (sum of 5km cells): 512002.78 m3
# [54/149] Processing res_21_2041_54_Ens01_binary_10cm.tif (event=54)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1826 km2
#     Total flooded volume (sum of 5km cells): 369547.19 m3
# [55/149] Processing res_21_2041_55_Ens01_binary_10cm.tif (event=55)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2043 km2
#     Total flooded volume (sum of 5km cells): 141427.80 m3
# [56/149] Processing res_21_2041_56_Ens01_binary_10cm.tif (event=56)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2097 km2
#     Total flooded volume (sum of 5km cells): 51570.00 m3
# [57/149] Processing res_21_2042_57_Ens01_binary_10cm.tif (event=57)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1078 km2
#     Total flooded volume (sum of 5km cells): 883434.62 m3
# [58/149] Processing res_21_2042_58_Ens01_binary_10cm.tif (event=58)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0260 km2
#     Total flooded volume (sum of 5km cells): 259036.20 m3
# [59/149] Processing res_21_2042_59_Ens01_binary_10cm.tif (event=59)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.3858 km2
#     Total flooded volume (sum of 5km cells): 1437463.88 m3
# [60/149] Processing res_21_2042_60_Ens01_binary_10cm.tif (event=60)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.0330 km2
#     Total flooded volume (sum of 5km cells): 1101656.75 m3
# [61/149] Processing res_21_2042_61_Ens01_binary_10cm.tif (event=61)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7756 km2
#     Total flooded volume (sum of 5km cells): 1038342.62 m3
# [62/149] Processing res_21_2043_62_Ens01_binary_10cm.tif (event=62)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6894 km2
#     Total flooded volume (sum of 5km cells): 241495.19 m3
# [63/149] Processing res_21_2043_63_Ens01_binary_10cm.tif (event=63)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6263 km2
#     Total flooded volume (sum of 5km cells): 766260.88 m3
# [64/149] Processing res_21_2045_64_Ens01_binary_10cm.tif (event=64)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8172 km2
#     Total flooded volume (sum of 5km cells): 222633.02 m3
# [65/149] Processing res_21_2045_65_Ens01_binary_10cm.tif (event=65)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.3211 km2
#     Total flooded volume (sum of 5km cells): 792803.69 m3
# [66/149] Processing res_21_2045_66_Ens01_binary_10cm.tif (event=66)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.0168 km2
#     Total flooded volume (sum of 5km cells): 827271.88 m3
# [67/149] Processing res_21_2045_67_Ens01_binary_10cm.tif (event=67)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.3093 km2
#     Total flooded volume (sum of 5km cells): 1243204.25 m3
# [68/149] Processing res_21_2045_68_Ens01_binary_10cm.tif (event=68)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.3800 km2
#     Total flooded volume (sum of 5km cells): 2332571.50 m3
# [69/149] Processing res_21_2045_69_Ens01_binary_10cm.tif (event=69)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3798 km2
#     Total flooded volume (sum of 5km cells): 117344.70 m3
# [70/149] Processing res_21_2046_70_Ens01_binary_10cm.tif (event=70)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1763 km2
#     Total flooded volume (sum of 5km cells): 415150.19 m3
# [71/149] Processing res_21_2047_71_Ens01_binary_10cm.tif (event=71)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1095 km2
#     Total flooded volume (sum of 5km cells): 1363503.62 m3
# [72/149] Processing res_21_2047_72_Ens01_binary_10cm.tif (event=72)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7341 km2
#     Total flooded volume (sum of 5km cells): 1230825.62 m3
# [73/149] Processing res_21_2048_73_Ens01_binary_10cm.tif (event=73)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.0308 km2
#     Total flooded volume (sum of 5km cells): 2392754.50 m3
# [74/149] Processing res_21_2048_74_Ens01_binary_10cm.tif (event=74)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.3964 km2
#     Total flooded volume (sum of 5km cells): 2013768.75 m3
# [75/149] Processing res_21_2048_75_Ens01_binary_10cm.tif (event=75)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7377 km2
#     Total flooded volume (sum of 5km cells): 1108098.88 m3
# [76/149] Processing res_21_2048_76_Ens01_binary_10cm.tif (event=76)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.0931 km2
#     Total flooded volume (sum of 5km cells): 1647170.00 m3
# [77/149] Processing res_21_2050_77_Ens01_binary_10cm.tif (event=77)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2347 km2
#     Total flooded volume (sum of 5km cells): 685188.94 m3
# [78/149] Processing res_21_2050_78_Ens01_binary_10cm.tif (event=78)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6480 km2
#     Total flooded volume (sum of 5km cells): 192210.31 m3
# [79/149] Processing res_21_2050_79_Ens01_binary_10cm.tif (event=79)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.2461 km2
#     Total flooded volume (sum of 5km cells): 4973792.50 m3
# [80/149] Processing res_21_2050_80_Ens01_binary_10cm.tif (event=80)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.8504 km2
#     Total flooded volume (sum of 5km cells): 563181.31 m3
# [81/149] Processing res_21_2051_81_Ens01_binary_10cm.tif (event=81)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5337 km2
#     Total flooded volume (sum of 5km cells): 172597.50 m3
# [82/149] Processing res_21_2051_82_Ens01_binary_10cm.tif (event=82)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2997 km2
#     Total flooded volume (sum of 5km cells): 121299.30 m3
# [83/149] Processing res_21_2051_83_Ens01_binary_10cm.tif (event=83)
# Skippping QA
#     Total flooded area (sum of 5km cells): 28.6380 km2
#     Total flooded volume (sum of 5km cells): 9970384.00 m3
# [84/149] Processing res_21_2052_84_Ens01_binary_10cm.tif (event=84)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.5474 km2
#     Total flooded volume (sum of 5km cells): 2744560.75 m3
# [85/149] Processing res_21_2053_85_Ens01_binary_10cm.tif (event=85)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.1200 km2
#     Total flooded volume (sum of 5km cells): 2307265.00 m3
# [86/149] Processing res_21_2053_86_Ens01_binary_10cm.tif (event=86)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8487 km2
#     Total flooded volume (sum of 5km cells): 242264.69 m3
# [87/149] Processing res_21_2053_87_Ens01_binary_10cm.tif (event=87)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4608 km2
#     Total flooded volume (sum of 5km cells): 173349.91 m3
# [88/149] Processing res_21_2053_88_Ens01_binary_10cm.tif (event=88)
# Skippping QA
#     Total flooded area (sum of 5km cells): 44.5878 km2
#     Total flooded volume (sum of 5km cells): 17572704.00 m3
# [89/149] Processing res_21_2055_89_Ens01_binary_10cm.tif (event=89)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9530 km2
#     Total flooded volume (sum of 5km cells): 690614.06 m3
# [90/149] Processing res_21_2055_90_Ens01_binary_10cm.tif (event=90)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8613 km2
#     Total flooded volume (sum of 5km cells): 361355.41 m3
# [91/149] Processing res_21_2056_91_Ens01_binary_10cm.tif (event=91)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5192 km2
#     Total flooded volume (sum of 5km cells): 477506.69 m3
# [92/149] Processing res_21_2058_92_Ens01_binary_10cm.tif (event=92)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4451 km2
#     Total flooded volume (sum of 5km cells): 1233235.75 m3
# [93/149] Processing res_21_2059_93_Ens01_binary_10cm.tif (event=93)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.8386 km2
#     Total flooded volume (sum of 5km cells): 1107421.25 m3
# [94/149] Processing res_21_2060_94_Ens01_binary_10cm.tif (event=94)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0639 km2
#     Total flooded volume (sum of 5km cells): 19583.10 m3
# [95/149] Processing res_21_2060_95_Ens01_binary_10cm.tif (event=95)
# Skippping QA
#     Total flooded area (sum of 5km cells): 16.9740 km2
#     Total flooded volume (sum of 5km cells): 6112920.50 m3
# [96/149] Processing res_21_2060_96_Ens01_binary_10cm.tif (event=96)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7387 km2
#     Total flooded volume (sum of 5km cells): 1057535.00 m3
# [97/149] Processing res_21_2062_97_Ens01_binary_10cm.tif (event=97)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.5190 km2
#     Total flooded volume (sum of 5km cells): 4463199.00 m3
# [98/149] Processing res_21_2062_98_Ens01_binary_10cm.tif (event=98)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.2228 km2
#     Total flooded volume (sum of 5km cells): 1296613.00 m3
# [99/149] Processing res_21_2062_99_Ens01_binary_10cm.tif (event=99)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.7662 km2
#     Total flooded volume (sum of 5km cells): 2270178.25 m3
# [100/149] Processing res_21_2063_100_Ens01_binary_10cm.tif (event=100)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6993 km2
#     Total flooded volume (sum of 5km cells): 190461.61 m3
# [101/149] Processing res_21_2065_101_Ens01_binary_10cm.tif (event=101)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.7385 km2
#     Total flooded volume (sum of 5km cells): 5694647.50 m3
# [102/149] Processing res_21_2065_102_Ens01_binary_10cm.tif (event=102)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.5116 km2
#     Total flooded volume (sum of 5km cells): 1966784.38 m3
# [103/149] Processing res_21_2065_103_Ens01_binary_10cm.tif (event=103)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4158 km2
#     Total flooded volume (sum of 5km cells): 147892.50 m3
# [104/149] Processing res_21_2066_104_Ens01_binary_10cm.tif (event=104)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.6289 km2
#     Total flooded volume (sum of 5km cells): 839808.00 m3
# [105/149] Processing res_21_2066_105_Ens01_binary_10cm.tif (event=105)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0124 km2
#     Total flooded volume (sum of 5km cells): 625262.38 m3
# [106/149] Processing res_21_2067_106_Ens01_binary_10cm.tif (event=106)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2905 km2
#     Total flooded volume (sum of 5km cells): 704803.50 m3
# [107/149] Processing res_21_2067_107_Ens01_binary_10cm.tif (event=107)
# Skippping QA
#     Total flooded area (sum of 5km cells): 15.1146 km2
#     Total flooded volume (sum of 5km cells): 5710781.50 m3
# [108/149] Processing res_21_2067_108_Ens01_binary_10cm.tif (event=108)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7541 km2
#     Total flooded volume (sum of 5km cells): 492650.97 m3
# [109/149] Processing res_21_2067_109_Ens01_binary_10cm.tif (event=109)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3159 km2
#     Total flooded volume (sum of 5km cells): 85733.10 m3
# [110/149] Processing res_21_2067_110_Ens01_binary_10cm.tif (event=110)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.8827 km2
#     Total flooded volume (sum of 5km cells): 756558.94 m3
# [111/149] Processing res_21_2068_111_Ens01_binary_10cm.tif (event=111)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.9700 km2
#     Total flooded volume (sum of 5km cells): 1066924.75 m3
# [112/149] Processing res_21_2068_112_Ens01_binary_10cm.tif (event=112)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0495 km2
#     Total flooded volume (sum of 5km cells): 11238.30 m3
# [113/149] Processing res_21_2069_113_Ens01_binary_10cm.tif (event=113)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.2695 km2
#     Total flooded volume (sum of 5km cells): 2046022.12 m3
# [114/149] Processing res_21_2069_114_Ens01_binary_10cm.tif (event=114)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0540 km2
#     Total flooded volume (sum of 5km cells): 21528.90 m3
# [115/149] Processing res_21_2069_115_Ens01_binary_10cm.tif (event=115)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9180 km2
#     Total flooded volume (sum of 5km cells): 355297.47 m3
# [116/149] Processing res_21_2069_116_Ens01_binary_10cm.tif (event=116)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.9529 km2
#     Total flooded volume (sum of 5km cells): 3813494.50 m3
# [117/149] Processing res_21_2071_117_Ens01_binary_10cm.tif (event=117)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5958 km2
#     Total flooded volume (sum of 5km cells): 175913.09 m3
# [118/149] Processing res_21_2072_118_Ens01_binary_10cm.tif (event=118)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1556 km2
#     Total flooded volume (sum of 5km cells): 590940.00 m3
# [119/149] Processing res_21_2073_119_Ens01_binary_10cm.tif (event=119)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2140 km2
#     Total flooded volume (sum of 5km cells): 850906.81 m3
# [120/149] Processing res_21_2074_120_Ens01_binary_10cm.tif (event=120)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5516 km2
#     Total flooded volume (sum of 5km cells): 735859.81 m3
# [121/149] Processing res_21_2074_121_Ens01_binary_10cm.tif (event=121)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3564 km2
#     Total flooded volume (sum of 5km cells): 101781.00 m3
# [122/149] Processing res_21_2074_122_Ens01_binary_10cm.tif (event=122)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1914 km2
#     Total flooded volume (sum of 5km cells): 1078870.62 m3
# [123/149] Processing res_21_2075_123_Ens01_binary_10cm.tif (event=123)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0405 km2
#     Total flooded volume (sum of 5km cells): 8365.50 m3
# [124/149] Processing res_21_2075_124_Ens01_binary_10cm.tif (event=124)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0899 km2
#     Total flooded volume (sum of 5km cells): 362860.22 m3
# [125/149] Processing res_21_2075_125_Ens01_binary_10cm.tif (event=125)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.6730 km2
#     Total flooded volume (sum of 5km cells): 1005163.12 m3
# [126/149] Processing res_21_2076_126_Ens01_binary_10cm.tif (event=126)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7638 km2
#     Total flooded volume (sum of 5km cells): 1360458.00 m3
# [127/149] Processing res_21_2076_127_Ens01_binary_10cm.tif (event=127)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7891 km2
#     Total flooded volume (sum of 5km cells): 825021.88 m3
# [128/149] Processing res_21_2076_128_Ens01_binary_10cm.tif (event=128)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.4168 km2
#     Total flooded volume (sum of 5km cells): 3094933.50 m3
# [129/149] Processing res_21_2076_129_Ens01_binary_10cm.tif (event=129)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2312 km2
#     Total flooded volume (sum of 5km cells): 359842.50 m3
# [130/149] Processing res_21_2076_130_Ens01_binary_10cm.tif (event=130)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.3115 km2
#     Total flooded volume (sum of 5km cells): 3109874.25 m3
# [131/149] Processing res_21_2077_131_Ens01_binary_10cm.tif (event=131)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1015 km2
#     Total flooded volume (sum of 5km cells): 646622.06 m3
# [132/149] Processing res_21_2077_132_Ens01_binary_10cm.tif (event=132)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3735 km2
#     Total flooded volume (sum of 5km cells): 125953.20 m3
# [133/149] Processing res_21_2077_133_Ens01_binary_10cm.tif (event=133)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2349 km2
#     Total flooded volume (sum of 5km cells): 63036.00 m3
# [134/149] Processing res_21_2078_134_Ens01_binary_10cm.tif (event=134)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0772 km2
#     Total flooded volume (sum of 5km cells): 662322.62 m3
# [135/149] Processing res_21_2078_135_Ens01_binary_10cm.tif (event=135)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4607 km2
#     Total flooded volume (sum of 5km cells): 499835.69 m3
# [136/149] Processing res_21_2078_136_Ens01_binary_10cm.tif (event=136)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0153 km2
#     Total flooded volume (sum of 5km cells): 15048.90 m3
# [137/149] Processing res_21_2078_137_Ens01_binary_10cm.tif (event=137)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5814 km2
#     Total flooded volume (sum of 5km cells): 217984.50 m3
# [138/149] Processing res_21_2078_138_Ens01_binary_10cm.tif (event=138)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.1813 km2
#     Total flooded volume (sum of 5km cells): 1601749.75 m3
# [139/149] Processing res_21_2078_139_Ens01_binary_10cm.tif (event=139)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2492 km2
#     Total flooded volume (sum of 5km cells): 487242.88 m3
# [140/149] Processing res_21_2078_140_Ens01_binary_10cm.tif (event=140)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.9789 km2
#     Total flooded volume (sum of 5km cells): 1647902.75 m3
# [141/149] Processing res_21_2078_141_Ens01_binary_10cm.tif (event=141)
# Skippping QA
#     Total flooded area (sum of 5km cells): 38.3040 km2
#     Total flooded volume (sum of 5km cells): 13405551.00 m3
# [142/149] Processing res_21_2078_142_Ens01_binary_10cm.tif (event=142)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.8422 km2
#     Total flooded volume (sum of 5km cells): 952628.38 m3
# [143/149] Processing res_21_2079_143_Ens01_binary_10cm.tif (event=143)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7335 km2
#     Total flooded volume (sum of 5km cells): 254066.41 m3
# [144/149] Processing res_21_2079_144_Ens01_binary_10cm.tif (event=144)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.3036 km2
#     Total flooded volume (sum of 5km cells): 1971656.12 m3
# [145/149] Processing res_21_2080_145_Ens01_binary_10cm.tif (event=145)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0377 km2
#     Total flooded volume (sum of 5km cells): 378242.09 m3
# [146/149] Processing res_21_2080_146_Ens01_binary_10cm.tif (event=146)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.0548 km2
#     Total flooded volume (sum of 5km cells): 3149093.00 m3
# [147/149] Processing res_21_2080_147_Ens01_binary_10cm.tif (event=147)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.5731 km2
#     Total flooded volume (sum of 5km cells): 924954.25 m3
# [148/149] Processing res_21_2080_148_Ens01_binary_10cm.tif (event=148)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.8688 km2
#     Total flooded volume (sum of 5km cells): 2316856.50 m3
# [149/149] Processing res_21_2080_149_Ens01_binary_10cm.tif (event=149)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.7595 km2
#     Total flooded volume (sum of 5km cells): 3631872.50 m3
# Saving area to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_21/Ens01_21/10cm/flooded_area_5km_total_Ens01_21_10cm.nc...
# Done! Saved 149 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_21/Ens01_21/10cm/flooded_area_5km_total_Ens01_21_10cm.nc
# Saving volume to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_21/Ens01_21/10cm/flooded_volume_5km_total_Ens01_21_10cm.nc...
# Done! Saved 149 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_21/Ens01_21/10cm/flooded_volume_5km_total_Ens01_21_10cm.nc
#
# [Ens01_21 | 30cm] Processing 149 events
# [1/149] Processing res_21_1991_1_Ens01_binary_30cm.tif (event=1)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1224 km2
#     Total flooded volume (sum of 5km cells): 75580.20 m3
# [2/149] Processing res_21_1992_2_Ens01_binary_30cm.tif (event=2)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0999 km2
#     Total flooded volume (sum of 5km cells): 69273.90 m3
# [3/149] Processing res_21_1993_3_Ens01_binary_30cm.tif (event=3)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5391 km2
#     Total flooded volume (sum of 5km cells): 410419.81 m3
# [4/149] Processing res_21_1995_4_Ens01_binary_30cm.tif (event=4)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6174 km2
#     Total flooded volume (sum of 5km cells): 541094.38 m3
# [5/149] Processing res_21_1995_5_Ens01_binary_30cm.tif (event=5)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.4872 km2
#     Total flooded volume (sum of 5km cells): 5134056.00 m3
# [6/149] Processing res_21_1998_6_Ens01_binary_30cm.tif (event=6)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2457 km2
#     Total flooded volume (sum of 5km cells): 135348.31 m3
# [7/149] Processing res_21_2001_7_Ens01_binary_30cm.tif (event=7)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2853 km2
#     Total flooded volume (sum of 5km cells): 292539.62 m3
# [8/149] Processing res_21_2002_8_Ens01_binary_30cm.tif (event=8)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2978 km2
#     Total flooded volume (sum of 5km cells): 1025681.50 m3
# [9/149] Processing res_21_2004_9_Ens01_binary_30cm.tif (event=9)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1341 km2
#     Total flooded volume (sum of 5km cells): 88763.40 m3
# [10/149] Processing res_21_2008_10_Ens01_binary_30cm.tif (event=10)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0000 km2
#     Total flooded volume (sum of 5km cells): 0.00 m3
# [11/149] Processing res_21_2008_11_Ens01_binary_30cm.tif (event=11)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0333 km2
#     Total flooded volume (sum of 5km cells): 23995.80 m3
# [12/149] Processing res_21_2009_12_Ens01_binary_30cm.tif (event=12)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0693 km2
#     Total flooded volume (sum of 5km cells): 102381.30 m3
# [13/149] Processing res_21_2013_13_Ens01_binary_30cm.tif (event=13)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1916 km2
#     Total flooded volume (sum of 5km cells): 851286.62 m3
# [14/149] Processing res_21_2016_14_Ens01_binary_30cm.tif (event=14)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2196 km2
#     Total flooded volume (sum of 5km cells): 189209.70 m3
# [15/149] Processing res_21_2016_15_Ens01_binary_30cm.tif (event=15)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7623 km2
#     Total flooded volume (sum of 5km cells): 732647.75 m3
# [16/149] Processing res_21_2017_16_Ens01_binary_30cm.tif (event=16)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1458 km2
#     Total flooded volume (sum of 5km cells): 81171.00 m3
# [17/149] Processing res_21_2017_17_Ens01_binary_30cm.tif (event=17)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.7960 km2
#     Total flooded volume (sum of 5km cells): 4572389.50 m3
# [18/149] Processing res_21_2017_18_Ens01_binary_30cm.tif (event=18)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2295 km2
#     Total flooded volume (sum of 5km cells): 174287.70 m3
# [19/149] Processing res_21_2018_19_Ens01_binary_30cm.tif (event=19)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2646 km2
#     Total flooded volume (sum of 5km cells): 145542.59 m3
# [20/149] Processing res_21_2019_20_Ens01_binary_30cm.tif (event=20)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0216 km2
#     Total flooded volume (sum of 5km cells): 18011.70 m3
# [21/149] Processing res_21_2020_21_Ens01_binary_30cm.tif (event=21)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3176 km2
#     Total flooded volume (sum of 5km cells): 1068561.00 m3
# [22/149] Processing res_21_2020_22_Ens01_binary_30cm.tif (event=22)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0540 km2
#     Total flooded volume (sum of 5km cells): 55918.80 m3
# [23/149] Processing res_21_2023_23_Ens01_binary_30cm.tif (event=23)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.3093 km2
#     Total flooded volume (sum of 5km cells): 2233962.00 m3
# [24/149] Processing res_21_2023_24_Ens01_binary_30cm.tif (event=24)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0952 km2
#     Total flooded volume (sum of 5km cells): 1515535.25 m3
# [25/149] Processing res_21_2023_25_Ens01_binary_30cm.tif (event=25)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0314 km2
#     Total flooded volume (sum of 5km cells): 737723.69 m3
# [26/149] Processing res_21_2025_26_Ens01_binary_30cm.tif (event=26)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2932 km2
#     Total flooded volume (sum of 5km cells): 1652220.00 m3
# [27/149] Processing res_21_2026_27_Ens01_binary_30cm.tif (event=27)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9900 km2
#     Total flooded volume (sum of 5km cells): 811800.94 m3
# [28/149] Processing res_21_2026_28_Ens01_binary_30cm.tif (event=28)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0594 km2
#     Total flooded volume (sum of 5km cells): 61156.80 m3
# [29/149] Processing res_21_2027_29_Ens01_binary_30cm.tif (event=29)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3968 km2
#     Total flooded volume (sum of 5km cells): 877400.12 m3
# [30/149] Processing res_21_2027_30_Ens01_binary_30cm.tif (event=30)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2032 km2
#     Total flooded volume (sum of 5km cells): 1943351.00 m3
# [31/149] Processing res_21_2029_31_Ens01_binary_30cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3312 km2
#     Total flooded volume (sum of 5km cells): 187239.59 m3
# [32/149] Processing res_21_2030_32_Ens01_binary_30cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0909 km2
#     Total flooded volume (sum of 5km cells): 52148.70 m3
# [33/149] Processing res_21_2030_33_Ens01_binary_30cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4085 km2
#     Total flooded volume (sum of 5km cells): 914541.31 m3
# [34/149] Processing res_21_2031_34_Ens01_binary_30cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0252 km2
#     Total flooded volume (sum of 5km cells): 32741.10 m3
# [35/149] Processing res_21_2032_35_Ens01_binary_30cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.7985 km2
#     Total flooded volume (sum of 5km cells): 5617423.50 m3
# [36/149] Processing res_21_2033_36_Ens01_binary_30cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5166 km2
#     Total flooded volume (sum of 5km cells): 435732.31 m3
# [37/149] Processing res_21_2035_37_Ens01_binary_30cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1628 km2
#     Total flooded volume (sum of 5km cells): 792637.19 m3
# [38/149] Processing res_21_2036_38_Ens01_binary_30cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3204 km2
#     Total flooded volume (sum of 5km cells): 262791.88 m3
# [39/149] Processing res_21_2036_39_Ens01_binary_30cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9135 km2
#     Total flooded volume (sum of 5km cells): 763766.06 m3
# [40/149] Processing res_21_2037_40_Ens01_binary_30cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0504 km2
#     Total flooded volume (sum of 5km cells): 36663.30 m3
# [41/149] Processing res_21_2037_41_Ens01_binary_30cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5112 km2
#     Total flooded volume (sum of 5km cells): 327266.12 m3
# [42/149] Processing res_21_2040_42_Ens01_binary_30cm.tif (event=42)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6786 km2
#     Total flooded volume (sum of 5km cells): 658232.12 m3
# [43/149] Processing res_21_2040_43_Ens01_binary_30cm.tif (event=43)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7830 km2
#     Total flooded volume (sum of 5km cells): 560503.81 m3
# [44/149] Processing res_21_2040_44_Ens01_binary_30cm.tif (event=44)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1188 km2
#     Total flooded volume (sum of 5km cells): 107287.20 m3
# [45/149] Processing res_21_2040_45_Ens01_binary_30cm.tif (event=45)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5580 km2
#     Total flooded volume (sum of 5km cells): 377585.12 m3
# [46/149] Processing res_21_2041_46_Ens01_binary_30cm.tif (event=46)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2709 km2
#     Total flooded volume (sum of 5km cells): 164274.31 m3
# [47/149] Processing res_21_2041_47_Ens01_binary_30cm.tif (event=47)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5598 km2
#     Total flooded volume (sum of 5km cells): 390135.59 m3
# [48/149] Processing res_21_2041_48_Ens01_binary_30cm.tif (event=48)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2511 km2
#     Total flooded volume (sum of 5km cells): 147690.00 m3
# [49/149] Processing res_21_2041_49_Ens01_binary_30cm.tif (event=49)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7920 km2
#     Total flooded volume (sum of 5km cells): 579502.81 m3
# [50/149] Processing res_21_2041_50_Ens01_binary_30cm.tif (event=50)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0936 km2
#     Total flooded volume (sum of 5km cells): 98284.50 m3
# [51/149] Processing res_21_2041_51_Ens01_binary_30cm.tif (event=51)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.9282 km2
#     Total flooded volume (sum of 5km cells): 5155017.50 m3
# [52/149] Processing res_21_2041_52_Ens01_binary_30cm.tif (event=52)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8802 km2
#     Total flooded volume (sum of 5km cells): 645598.81 m3
# [53/149] Processing res_21_2041_53_Ens01_binary_30cm.tif (event=53)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2304 km2
#     Total flooded volume (sum of 5km cells): 250879.50 m3
# [54/149] Processing res_21_2041_54_Ens01_binary_30cm.tif (event=54)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2079 km2
#     Total flooded volume (sum of 5km cells): 158929.20 m3
# [55/149] Processing res_21_2041_55_Ens01_binary_30cm.tif (event=55)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0513 km2
#     Total flooded volume (sum of 5km cells): 72626.39 m3
# [56/149] Processing res_21_2041_56_Ens01_binary_30cm.tif (event=56)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0054 km2
#     Total flooded volume (sum of 5km cells): 4246.20 m3
# [57/149] Processing res_21_2042_57_Ens01_binary_30cm.tif (event=57)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4113 km2
#     Total flooded volume (sum of 5km cells): 413549.97 m3
# [58/149] Processing res_21_2042_58_Ens01_binary_30cm.tif (event=58)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1854 km2
#     Total flooded volume (sum of 5km cells): 100517.41 m3
# [59/149] Processing res_21_2042_59_Ens01_binary_30cm.tif (event=59)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9540 km2
#     Total flooded volume (sum of 5km cells): 837682.19 m3
# [60/149] Processing res_21_2042_60_Ens01_binary_30cm.tif (event=60)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6543 km2
#     Total flooded volume (sum of 5km cells): 538687.81 m3
# [61/149] Processing res_21_2042_61_Ens01_binary_30cm.tif (event=61)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5751 km2
#     Total flooded volume (sum of 5km cells): 463706.09 m3
# [62/149] Processing res_21_2043_62_Ens01_binary_30cm.tif (event=62)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0990 km2
#     Total flooded volume (sum of 5km cells): 94032.00 m3
# [63/149] Processing res_21_2043_63_Ens01_binary_30cm.tif (event=63)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5148 km2
#     Total flooded volume (sum of 5km cells): 444105.91 m3
# [64/149] Processing res_21_2045_64_Ens01_binary_30cm.tif (event=64)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1692 km2
#     Total flooded volume (sum of 5km cells): 94306.50 m3
# [65/149] Processing res_21_2045_65_Ens01_binary_30cm.tif (event=65)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5166 km2
#     Total flooded volume (sum of 5km cells): 388293.28 m3
# [66/149] Processing res_21_2045_66_Ens01_binary_30cm.tif (event=66)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5877 km2
#     Total flooded volume (sum of 5km cells): 323028.91 m3
# [67/149] Processing res_21_2045_67_Ens01_binary_30cm.tif (event=67)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7929 km2
#     Total flooded volume (sum of 5km cells): 625853.62 m3
# [68/149] Processing res_21_2045_68_Ens01_binary_30cm.tif (event=68)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7487 km2
#     Total flooded volume (sum of 5km cells): 1092090.62 m3
# [69/149] Processing res_21_2045_69_Ens01_binary_30cm.tif (event=69)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0864 km2
#     Total flooded volume (sum of 5km cells): 51815.70 m3
# [70/149] Processing res_21_2046_70_Ens01_binary_30cm.tif (event=70)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2043 km2
#     Total flooded volume (sum of 5km cells): 180630.00 m3
# [71/149] Processing res_21_2047_71_Ens01_binary_30cm.tif (event=71)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9765 km2
#     Total flooded volume (sum of 5km cells): 767080.81 m3
# [72/149] Processing res_21_2047_72_Ens01_binary_30cm.tif (event=72)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7560 km2
#     Total flooded volume (sum of 5km cells): 571049.06 m3
# [73/149] Processing res_21_2048_73_Ens01_binary_30cm.tif (event=73)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5426 km2
#     Total flooded volume (sum of 5km cells): 1134837.00 m3
# [74/149] Processing res_21_2048_74_Ens01_binary_30cm.tif (event=74)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3401 km2
#     Total flooded volume (sum of 5km cells): 1058171.38 m3
# [75/149] Processing res_21_2048_75_Ens01_binary_30cm.tif (event=75)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6957 km2
#     Total flooded volume (sum of 5km cells): 481286.69 m3
# [76/149] Processing res_21_2048_76_Ens01_binary_30cm.tif (event=76)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1385 km2
#     Total flooded volume (sum of 5km cells): 773063.12 m3
# [77/149] Processing res_21_2050_77_Ens01_binary_30cm.tif (event=77)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4725 km2
#     Total flooded volume (sum of 5km cells): 306037.78 m3
# [78/149] Processing res_21_2050_78_Ens01_binary_30cm.tif (event=78)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1341 km2
#     Total flooded volume (sum of 5km cells): 77568.30 m3
# [79/149] Processing res_21_2050_79_Ens01_binary_30cm.tif (event=79)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.3534 km2
#     Total flooded volume (sum of 5km cells): 2422216.00 m3
# [80/149] Processing res_21_2050_80_Ens01_binary_30cm.tif (event=80)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3429 km2
#     Total flooded volume (sum of 5km cells): 228855.59 m3
# [81/149] Processing res_21_2051_81_Ens01_binary_30cm.tif (event=81)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0504 km2
#     Total flooded volume (sum of 5km cells): 44495.10 m3
# [82/149] Processing res_21_2051_82_Ens01_binary_30cm.tif (event=82)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0720 km2
#     Total flooded volume (sum of 5km cells): 61943.40 m3
# [83/149] Processing res_21_2051_83_Ens01_binary_30cm.tif (event=83)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.2054 km2
#     Total flooded volume (sum of 5km cells): 5156872.00 m3
# [84/149] Processing res_21_2052_84_Ens01_binary_30cm.tif (event=84)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2311 km2
#     Total flooded volume (sum of 5km cells): 1573130.62 m3
# [85/149] Processing res_21_2053_85_Ens01_binary_30cm.tif (event=85)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3203 km2
#     Total flooded volume (sum of 5km cells): 1092662.12 m3
# [86/149] Processing res_21_2053_86_Ens01_binary_30cm.tif (event=86)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1197 km2
#     Total flooded volume (sum of 5km cells): 72636.30 m3
# [87/149] Processing res_21_2053_87_Ens01_binary_30cm.tif (event=87)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1278 km2
#     Total flooded volume (sum of 5km cells): 96036.30 m3
# [88/149] Processing res_21_2053_88_Ens01_binary_30cm.tif (event=88)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.7159 km2
#     Total flooded volume (sum of 5km cells): 10636396.00 m3
# [89/149] Processing res_21_2055_89_Ens01_binary_30cm.tif (event=89)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3609 km2
#     Total flooded volume (sum of 5km cells): 318636.00 m3
# [90/149] Processing res_21_2055_90_Ens01_binary_30cm.tif (event=90)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2871 km2
#     Total flooded volume (sum of 5km cells): 207297.89 m3
# [91/149] Processing res_21_2056_91_Ens01_binary_30cm.tif (event=91)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3231 km2
#     Total flooded volume (sum of 5km cells): 208552.50 m3
# [92/149] Processing res_21_2058_92_Ens01_binary_30cm.tif (event=92)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8631 km2
# ...
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6939 km2
#     Total flooded volume (sum of 5km cells): 384546.56 m3
# [114/377] Processing res_106_2035_114_Ens08_binary_30cm.tif (event=114)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5103 km2
#     Total flooded volume (sum of 5km cells): 373204.88 m3
# [115/377] Processing res_106_2035_115_Ens08_binary_30cm.tif (event=115)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.0231 km2
#     Total flooded volume (sum of 5km cells): 1773405.00 m3
# [116/377] Processing res_106_2035_116_Ens08_binary_30cm.tif (event=116)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9063 km2
#     Total flooded volume (sum of 5km cells): 499923.91 m3
# [117/377] Processing res_106_2035_117_Ens08_binary_30cm.tif (event=117)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2879 km2
#     Total flooded volume (sum of 5km cells): 751334.44 m3
# [118/377] Processing res_106_2035_118_Ens08_binary_30cm.tif (event=118)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0045 km2
#     Total flooded volume (sum of 5km cells): 2526.30 m3
# [119/377] Processing res_106_2035_119_Ens08_binary_30cm.tif (event=119)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4500 km2
#     Total flooded volume (sum of 5km cells): 214902.00 m3
# [120/377] Processing res_106_2036_120_Ens08_binary_30cm.tif (event=120)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1359 km2
#     Total flooded volume (sum of 5km cells): 82547.10 m3
# [121/377] Processing res_106_2036_121_Ens08_binary_30cm.tif (event=121)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1800 km2
#     Total flooded volume (sum of 5km cells): 98821.80 m3
# [122/377] Processing res_106_2036_122_Ens08_binary_30cm.tif (event=122)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3735 km2
#     Total flooded volume (sum of 5km cells): 213888.59 m3
# [123/377] Processing res_106_2036_123_Ens08_binary_30cm.tif (event=123)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0117 km2
#     Total flooded volume (sum of 5km cells): 6407.10 m3
# [124/377] Processing res_106_2036_124_Ens08_binary_30cm.tif (event=124)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2142 km2
#     Total flooded volume (sum of 5km cells): 103985.10 m3
# [125/377] Processing res_106_2036_125_Ens08_binary_30cm.tif (event=125)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0368 km2
#     Total flooded volume (sum of 5km cells): 580145.38 m3
# [126/377] Processing res_106_2036_126_Ens08_binary_30cm.tif (event=126)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2851 km2
#     Total flooded volume (sum of 5km cells): 1304156.75 m3
# [127/377] Processing res_106_2036_127_Ens08_binary_30cm.tif (event=127)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6426 km2
#     Total flooded volume (sum of 5km cells): 394430.38 m3
# [128/377] Processing res_106_2036_128_Ens08_binary_30cm.tif (event=128)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.0015 km2
#     Total flooded volume (sum of 5km cells): 1742527.00 m3
# [129/377] Processing res_106_2036_129_Ens08_binary_30cm.tif (event=129)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7911 km2
#     Total flooded volume (sum of 5km cells): 428924.69 m3
# [130/377] Processing res_106_2036_130_Ens08_binary_30cm.tif (event=130)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3150 km2
#     Total flooded volume (sum of 5km cells): 170831.70 m3
# [131/377] Processing res_106_2036_131_Ens08_binary_30cm.tif (event=131)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0756 km2
#     Total flooded volume (sum of 5km cells): 38325.60 m3
# [132/377] Processing res_106_2036_132_Ens08_binary_30cm.tif (event=132)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3348 km2
#     Total flooded volume (sum of 5km cells): 165130.19 m3
# [133/377] Processing res_106_2036_133_Ens08_binary_30cm.tif (event=133)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1206 km2
#     Total flooded volume (sum of 5km cells): 51695.10 m3
# [134/377] Processing res_106_2037_134_Ens08_binary_30cm.tif (event=134)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2304 km2
#     Total flooded volume (sum of 5km cells): 135406.80 m3
# [135/377] Processing res_106_2037_135_Ens08_binary_30cm.tif (event=135)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0540 km2
#     Total flooded volume (sum of 5km cells): 38747.70 m3
# [136/377] Processing res_106_2037_136_Ens08_binary_30cm.tif (event=136)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0855 km2
#     Total flooded volume (sum of 5km cells): 39113.10 m3
# [137/377] Processing res_106_2037_137_Ens08_binary_30cm.tif (event=137)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0612 km2
#     Total flooded volume (sum of 5km cells): 42709.50 m3
# [138/377] Processing res_106_2037_138_Ens08_binary_30cm.tif (event=138)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7803 km2
#     Total flooded volume (sum of 5km cells): 476571.62 m3
# [139/377] Processing res_106_2037_139_Ens08_binary_30cm.tif (event=139)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3870 km2
#     Total flooded volume (sum of 5km cells): 247986.00 m3
# [140/377] Processing res_106_2038_140_Ens08_binary_30cm.tif (event=140)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0657 km2
#     Total flooded volume (sum of 5km cells): 35616.60 m3
# [141/377] Processing res_106_2038_141_Ens08_binary_30cm.tif (event=141)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0576 km2
#     Total flooded volume (sum of 5km cells): 25576.20 m3
# [142/377] Processing res_106_2038_142_Ens08_binary_30cm.tif (event=142)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4644 km2
#     Total flooded volume (sum of 5km cells): 290497.50 m3
# [143/377] Processing res_106_2038_143_Ens08_binary_30cm.tif (event=143)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0729 km2
#     Total flooded volume (sum of 5km cells): 45585.90 m3
# [144/377] Processing res_106_2038_144_Ens08_binary_30cm.tif (event=144)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6129 km2
#     Total flooded volume (sum of 5km cells): 480589.19 m3
# [145/377] Processing res_106_2038_145_Ens08_binary_30cm.tif (event=145)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0567 km2
#     Total flooded volume (sum of 5km cells): 35172.00 m3
# [146/377] Processing res_106_2038_146_Ens08_binary_30cm.tif (event=146)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1449 km2
#     Total flooded volume (sum of 5km cells): 101241.91 m3
# [147/377] Processing res_106_2038_147_Ens08_binary_30cm.tif (event=147)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1377 km2
#     Total flooded volume (sum of 5km cells): 89986.50 m3
# [148/377] Processing res_106_2038_148_Ens08_binary_30cm.tif (event=148)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0909 km2
#     Total flooded volume (sum of 5km cells): 65434.50 m3
# [149/377] Processing res_106_2038_149_Ens08_binary_30cm.tif (event=149)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1908 km2
#     Total flooded volume (sum of 5km cells): 115435.80 m3
# [150/377] Processing res_106_2039_150_Ens08_binary_30cm.tif (event=150)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1026 km2
#     Total flooded volume (sum of 5km cells): 52654.50 m3
# [151/377] Processing res_106_2039_151_Ens08_binary_30cm.tif (event=151)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5310 km2
#     Total flooded volume (sum of 5km cells): 348965.09 m3
# [152/377] Processing res_106_2039_152_Ens08_binary_30cm.tif (event=152)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2709 km2
#     Total flooded volume (sum of 5km cells): 159981.30 m3
# [153/377] Processing res_106_2039_153_Ens08_binary_30cm.tif (event=153)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1386 km2
#     Total flooded volume (sum of 5km cells): 72298.80 m3
# [154/377] Processing res_106_2039_154_Ens08_binary_30cm.tif (event=154)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3545 km2
#     Total flooded volume (sum of 5km cells): 789507.00 m3
# [155/377] Processing res_106_2039_155_Ens08_binary_30cm.tif (event=155)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0882 km2
#     Total flooded volume (sum of 5km cells): 49666.50 m3
# [156/377] Processing res_106_2039_156_Ens08_binary_30cm.tif (event=156)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1197 km2
#     Total flooded volume (sum of 5km cells): 78228.91 m3
# [157/377] Processing res_106_2039_157_Ens08_binary_30cm.tif (event=157)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0441 km2
#     Total flooded volume (sum of 5km cells): 24789.60 m3
# [158/377] Processing res_106_2039_158_Ens08_binary_30cm.tif (event=158)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0585 km2
#     Total flooded volume (sum of 5km cells): 29892.60 m3
# [159/377] Processing res_106_2040_159_Ens08_binary_30cm.tif (event=159)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1341 km2
#     Total flooded volume (sum of 5km cells): 79395.30 m3
# [160/377] Processing res_106_2040_160_Ens08_binary_30cm.tif (event=160)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0567 km2
#     Total flooded volume (sum of 5km cells): 51236.10 m3
# [161/377] Processing res_106_2040_161_Ens08_binary_30cm.tif (event=161)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3240 km2
#     Total flooded volume (sum of 5km cells): 170500.50 m3
# [162/377] Processing res_106_2040_162_Ens08_binary_30cm.tif (event=162)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0450 km2
#     Total flooded volume (sum of 5km cells): 19363.50 m3
# [163/377] Processing res_106_2040_163_Ens08_binary_30cm.tif (event=163)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0216 km2
#     Total flooded volume (sum of 5km cells): 12739.50 m3
# [164/377] Processing res_106_2040_164_Ens08_binary_30cm.tif (event=164)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4437 km2
#     Total flooded volume (sum of 5km cells): 286829.12 m3
# [165/377] Processing res_106_2040_165_Ens08_binary_30cm.tif (event=165)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1530 km2
#     Total flooded volume (sum of 5km cells): 86011.20 m3
# [166/377] Processing res_106_2040_166_Ens08_binary_30cm.tif (event=166)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0656 km2
#     Total flooded volume (sum of 5km cells): 632083.50 m3
# [167/377] Processing res_106_2040_167_Ens08_binary_30cm.tif (event=167)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2646 km2
#     Total flooded volume (sum of 5km cells): 153376.19 m3
# [168/377] Processing res_106_2040_168_Ens08_binary_30cm.tif (event=168)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2430 km2
#     Total flooded volume (sum of 5km cells): 149055.31 m3
# [169/377] Processing res_106_2040_169_Ens08_binary_30cm.tif (event=169)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1314 km2
#     Total flooded volume (sum of 5km cells): 76042.80 m3
# [170/377] Processing res_106_2040_170_Ens08_binary_30cm.tif (event=170)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6957 km2
#     Total flooded volume (sum of 5km cells): 398333.72 m3
# [171/377] Processing res_106_2040_171_Ens08_binary_30cm.tif (event=171)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0783 km2
#     Total flooded volume (sum of 5km cells): 39513.60 m3
# [172/377] Processing res_106_2040_172_Ens08_binary_30cm.tif (event=172)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3671 km2
#     Total flooded volume (sum of 5km cells): 808759.75 m3
# [173/377] Processing res_106_2040_173_Ens08_binary_30cm.tif (event=173)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5013 km2
#     Total flooded volume (sum of 5km cells): 276399.91 m3
# [174/377] Processing res_106_2041_174_Ens08_binary_30cm.tif (event=174)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3204 km2
#     Total flooded volume (sum of 5km cells): 227173.50 m3
# [175/377] Processing res_106_2041_175_Ens08_binary_30cm.tif (event=175)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3744 km2
#     Total flooded volume (sum of 5km cells): 240382.81 m3
# [176/377] Processing res_106_2041_176_Ens08_binary_30cm.tif (event=176)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0972 km2
#     Total flooded volume (sum of 5km cells): 52708.50 m3
# [177/377] Processing res_106_2041_177_Ens08_binary_30cm.tif (event=177)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3797 km2
#     Total flooded volume (sum of 5km cells): 792021.69 m3
# [178/377] Processing res_106_2041_178_Ens08_binary_30cm.tif (event=178)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0225 km2
#     Total flooded volume (sum of 5km cells): 24333.30 m3
# [179/377] Processing res_106_2041_179_Ens08_binary_30cm.tif (event=179)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4689 km2
#     Total flooded volume (sum of 5km cells): 264619.81 m3
# [180/377] Processing res_106_2041_180_Ens08_binary_30cm.tif (event=180)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0972 km2
#     Total flooded volume (sum of 5km cells): 56020.50 m3
# [181/377] Processing res_106_2042_181_Ens08_binary_30cm.tif (event=181)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0432 km2
#     Total flooded volume (sum of 5km cells): 25972.20 m3
# [182/377] Processing res_106_2042_182_Ens08_binary_30cm.tif (event=182)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0693 km2
#     Total flooded volume (sum of 5km cells): 48765.60 m3
# [183/377] Processing res_106_2042_183_Ens08_binary_30cm.tif (event=183)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1836 km2
#     Total flooded volume (sum of 5km cells): 125263.80 m3
# [184/377] Processing res_106_2042_184_Ens08_binary_30cm.tif (event=184)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2034 km2
#     Total flooded volume (sum of 5km cells): 164449.78 m3
# [185/377] Processing res_106_2042_185_Ens08_binary_30cm.tif (event=185)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1718 km2
#     Total flooded volume (sum of 5km cells): 728618.38 m3
# [186/377] Processing res_106_2042_186_Ens08_binary_30cm.tif (event=186)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9612 km2
#     Total flooded volume (sum of 5km cells): 486850.47 m3
# [187/377] Processing res_106_2042_187_Ens08_binary_30cm.tif (event=187)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1070 km2
#     Total flooded volume (sum of 5km cells): 862849.88 m3
# [188/377] Processing res_106_2042_188_Ens08_binary_30cm.tif (event=188)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8352 km2
#     Total flooded volume (sum of 5km cells): 546185.69 m3
# [189/377] Processing res_106_2042_189_Ens08_binary_30cm.tif (event=189)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8928 km2
#     Total flooded volume (sum of 5km cells): 565954.19 m3
# [190/377] Processing res_106_2042_190_Ens08_binary_30cm.tif (event=190)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0198 km2
#     Total flooded volume (sum of 5km cells): 10919.70 m3
# [191/377] Processing res_106_2043_191_Ens08_binary_30cm.tif (event=191)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3474 km2
#     Total flooded volume (sum of 5km cells): 206513.09 m3
# [192/377] Processing res_106_2043_192_Ens08_binary_30cm.tif (event=192)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4806 km2
#     Total flooded volume (sum of 5km cells): 292739.38 m3
# [193/377] Processing res_106_2043_193_Ens08_binary_30cm.tif (event=193)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1836 km2
#     Total flooded volume (sum of 5km cells): 120559.50 m3
# [194/377] Processing res_106_2043_194_Ens08_binary_30cm.tif (event=194)
# Skippping QA

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Aggregate 30m flood rasters to 5km totals")
#     parser.add_argument(
#         "ha_num",
#         nargs="?",
#         default="23",
#         help="Catchment number (e.g. 23)"
#     )
#     args = parser.parse_args()
