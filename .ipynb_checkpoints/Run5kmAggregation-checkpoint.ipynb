# %%
def extract_event_number(filename):
    """
    Extract event number from filenames like:
    res_23_1993_1_Ens07_binary_10cm.tif -> 1
    res_23_1993_123_Ens07_binary_10cm.tif -> 123
    """
    match = re.search(r'_(\d+)_Ens\d+_(?:binary|filtered)_', filename)
    if match:
        return int(match.group(1))
    return None


def iter_event_tifs(ha_num, data_kind, ensembles=None, thresholds=None):
    """
    Yield metadata for every event tif in:
    tifs/EnsXX_<HA_NUM>/<data_kind>/10cm/*.tif
    tifs/EnsXX_<HA_NUM>/<data_kind>/30cm/*.tif
    """
    if data_kind not in {"binary", "filtered"}:
        raise ValueError(f"Unsupported data_kind={data_kind}")

    ensembles = ensembles or ENSEMBLE_MEMBERS
    thresholds = thresholds or THRESHOLDS
    ha_num = str(ha_num)

    for ens in ensembles:
        ens_name = f"Ens{ens}_{ha_num}"

        for thr in thresholds:
            tif_glob = os.path.join(TIFS_DIR, ens_name, data_kind, thr, "*.tif")
            tif_paths = sorted(glob.glob(tif_glob))

            if not tif_paths:
                print(f"[WARN] No files found: {os.path.dirname(tif_glob)}")
                continue

            for tif_path in tif_paths:
                event_num = extract_event_number(os.path.basename(tif_path))
                if event_num is None:
                    print(f"[WARN] Could not extract event number from: {os.path.basename(tif_path)}")
                    continue
                
                yield {
                    "ha_num": ha_num,
                    "ensemble": ens_name,
                    "threshold": thr,
                    "data_kind": data_kind,
                    "path": tif_path,
                    "event_num": event_num,
                }


def process_single_event_area(binary_file, x5, y5, nx, ny, qa_out_tif=None):
    """
    Process a single binary flood tif and return flooded area per 5km grid cell.
    Maps 30m pixels directly to the original 5km grid using coordinates.
    """
    # Open flood raster
    flood = rxr.open_rasterio(
        binary_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if flood.rio.crs is None or flood.rio.crs.to_string() != "EPSG:27700":
        flood = flood.rio.reproject("EPSG:27700")

    # Identify valid pixels
    valid = flood.notnull()

    # Get flood pixel coordinates and values
    flood_x = flood.x.values
    flood_y = flood.y.values
    
    # Create meshgrid of flood coordinates
    xx, yy = np.meshgrid(flood_x, flood_y)
    
    # Flatten coordinates and values
    x_flat = xx.ravel()
    y_flat = yy.ravel()
    flood_flat = flood.values.ravel()
    valid_flat = valid.values.ravel()
    
    # Only keep valid, flooded pixels
    mask = valid_flat & (flood_flat > 0)
    x_flood = x_flat[mask]
    y_flood = y_flat[mask]
    
    if x_flood.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    # Map flood-pixel centers to 5km cell indices using cell edges.
    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_flood - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_flood) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_flood - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_flood) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)
    
    # Convert 2D indices to 1D linear indices
    linear_idx = iy * nx + ix

    if qa_out_tif is not None:
        # Build QA raster in original 30m grid:
        # value = 5km linear cell index for flooded pixels, -1 elsewhere.
        flooded_flat_idx = np.where(mask)[0]
        flooded_flat_idx_in_grid = flooded_flat_idx[in_grid]
        qa_flat = np.full(flood_flat.shape, -1, dtype=np.int32)
        qa_flat[flooded_flat_idx_in_grid] = linear_idx.astype(np.int32)
        qa_arr = qa_flat.reshape(flood.shape)

        qa_da = xr.DataArray(qa_arr, coords=flood.coords, dims=flood.dims)
        qa_da = qa_da.rio.write_crs(flood.rio.crs)
        qa_da.rio.write_transform(flood.rio.transform(), inplace=True)

        os.makedirs(os.path.dirname(qa_out_tif), exist_ok=True)
        qa_da.rio.to_raster(qa_out_tif)
    
    # Count flooded pixels per grid cell
    counts_flat = np.bincount(linear_idx, minlength=nx * ny)
    counts = counts_flat.reshape(ny, nx)
    
    # Convert flooded-pixel counts to total flooded area using actual raster resolution.
    xres, yres = flood.rio.resolution()
    pixel_area_km2 = (abs(xres) * abs(yres)) / 1e6
    flood_area = counts.astype(np.float32) * pixel_area_km2
    
    return flood_area


def process_single_event_volume(depth_file, x5, y5, nx, ny):
    """
    Process a single depth flood tif and return flooded volume per 5km grid cell.
    Volume is computed as sum(depth_m * pixel_area_m2) over pixels within each 5km cell.
    """
    depth = rxr.open_rasterio(
        depth_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if depth.rio.crs is None or depth.rio.crs.to_string() != "EPSG:27700":
        depth = depth.rio.reproject("EPSG:27700")

    valid = depth.notnull()

    depth_x = depth.x.values
    depth_y = depth.y.values
    xx, yy = np.meshgrid(depth_x, depth_y)

    x_flat = xx.ravel()
    y_flat = yy.ravel()
    depth_flat = depth.values.ravel()
    valid_flat = valid.values.ravel()

    # Only include valid, positive depths in the volume sum.
    mask = valid_flat & (depth_flat > 0)
    x_depth = x_flat[mask]
    y_depth = y_flat[mask]
    depth_vals = depth_flat[mask].astype(np.float64)

    if x_depth.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_depth - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_depth) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_depth - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_depth) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]
    depth_vals = depth_vals[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    linear_idx = iy * nx + ix

    xres, yres = depth.rio.resolution()
    pixel_area_m2 = abs(xres) * abs(yres)

    # Depth rasters are in meters, so depth[m] * area[m2] -> volume[m3].
    contrib_m3 = depth_vals * pixel_area_m2
    volume_flat = np.bincount(linear_idx, weights=contrib_m3, minlength=nx * ny)
    flood_volume = volume_flat.reshape(ny, nx).astype(np.float32)

    return flood_volume

# %%
import os
import glob
import re
import argparse
import xarray as xr
import rioxarray as rxr
import numpy as np
from rasterio.transform import from_bounds

# -----------------------------
# CONFIG
# -----------------------------
HA_NUM = 12

ROOT_DIR = "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4"
# OUTPUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

TIFS_DIR = os.path.join(ROOT_DIR, "tifs")

# Your 12 ensembles
ENSEMBLE_MEMBERS = ["01", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "15"]

# Only the two thresholds you care about
THRESHOLDS = ["10cm", "30cm"]

# QA output: write 30m geotiffs showing assigned 5km cell id per flooded pixel.
WRITE_QA_GRID_INDEX_TIF = False
QA_MAX_EVENTS_PER_THRESHOLD = 1

# Input grid
GRID_5KM_FILE = "/scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc"
# GRID_5KM_FILE = "/scratch/hydro5/users/ld14116/SDM_bias_correction/Hourly/01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_20801101-20801130.nc"

# %%
# -----------------------------
# FILTER TO ONLY INCOMPLETE CATCHMENTS
# -----------------------------
def all_outputs_exist(ha_num):
    out_dir_base = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{ha_num}"
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(out_dir_base, f"Ens{ens}_{ha_num}", thr)
            for kind in ("area", "volume"):
                fname = f"flooded_{kind}_5km_total_Ens{ens}_{ha_num}_{thr}.nc"
                if not os.path.exists(os.path.join(out_dir, fname)):
                    return False
    return True

catchments_to_skip = {c for c in catchment_numbers if all_outputs_exist(c)}
catchments_to_run = catchment_numbers - catchments_to_skip

print(f"{len(catchments_to_skip)} catchments already complete, skipping.")
print(f"{len(catchments_to_run)} catchments to process: {sorted(catchments_to_run)}")


for HA_NUM in catchments_to_run:
    print(f"Running for catchment number: {HA_NUM}")
    OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"
# Out:
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_7/Ens01_7/10cm/flooded_area_5km_total_Ens01_7_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_76/Ens01_76/10cm/flooded_area_5km_total_Ens01_76_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_11/Ens01_11/10cm/flooded_area_5km_total_Ens01_11_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_70/Ens01_70/10cm/flooded_area_5km_total_Ens01_70_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_43/Ens01_43/10cm/flooded_area_5km_total_Ens01_43_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_27_a/Ens01_27_a/10cm/flooded_area_5km_total_Ens01_27_a_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_38/Ens01_38/10cm/flooded_area_5km_total_Ens01_38_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_22/Ens01_22/10cm/flooded_area_5km_total_Ens01_22_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_28_b/Ens01_28_b/10cm/flooded_area_5km_total_Ens01_28_b_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_88/Ens01_88/10cm/flooded_area_5km_total_Ens01_88_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_107/Ens01_107/10cm/flooded_area_5km_total_Ens01_107_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_49/Ens01_49/10cm/flooded_area_5km_total_Ens01_49_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_17/Ens01_17/10cm/flooded_area_5km_total_Ens01_17_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_74/Ens01_74/10cm/flooded_area_5km_total_Ens01_74_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_19/Ens01_19/10cm/flooded_area_5km_total_Ens01_19_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_46/Ens01_46/10cm/flooded_area_5km_total_Ens01_46_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_45/Ens01_45/10cm/flooded_area_5km_total_Ens01_45_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_85/Ens01_85/10cm/flooded_area_5km_total_Ens01_85_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_91/Ens01_91/10cm/flooded_area_5km_total_Ens01_91_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_37/Ens11_37/10cm/flooded_area_5km_total_Ens11_37_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_28_a/Ens01_28_a/10cm/flooded_area_5km_total_Ens01_28_a_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_89/Ens01_89/10cm/flooded_area_5km_total_Ens01_89_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_93/Ens01_93/10cm/flooded_area_5km_total_Ens01_93_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_61/Ens01_61/10cm/flooded_area_5km_total_Ens01_61_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_54_a/Ens01_54_a/10cm/flooded_area_5km_total_Ens01_54_a_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_58/Ens01_58/10cm/flooded_area_5km_total_Ens01_58_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_79/Ens01_79/10cm/flooded_area_5km_total_Ens01_79_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_16/Ens01_16/10cm/flooded_area_5km_total_Ens01_16_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_14/Ens01_14/10cm/flooded_area_5km_total_Ens01_14_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_78/Ens01_78/10cm/flooded_area_5km_total_Ens01_78_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_54_b/Ens01_54_b/10cm/flooded_area_5km_total_Ens01_54_b_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_66/Ens01_66/10cm/flooded_area_5km_total_Ens01_66_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_94/Ens01_94/10cm/flooded_area_5km_total_Ens01_94_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_95/Ens01_95/10cm/flooded_area_5km_total_Ens01_95_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_75/Ens01_75/10cm/flooded_area_5km_total_Ens01_75_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_35/Ens01_35/10cm/flooded_area_5km_total_Ens01_35_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_32/Ens01_32/10cm/flooded_area_5km_total_Ens01_32_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_105/Ens01_105/10cm/flooded_area_5km_total_Ens01_105_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_4/Ens01_4/10cm/flooded_area_5km_total_Ens01_4_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_87/Ens01_87/10cm/flooded_area_5km_total_Ens01_87_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_83/Ens01_83/10cm/flooded_area_5km_total_Ens01_83_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_5/Ens01_5/10cm/flooded_area_5km_total_Ens01_5_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_48/Ens01_48/10cm/flooded_area_5km_total_Ens01_48_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_65/Ens01_65/10cm/flooded_area_5km_total_Ens01_65_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_69/Ens01_69/10cm/flooded_area_5km_total_Ens01_69_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_34/Ens01_34/10cm/flooded_area_5km_total_Ens01_34_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_27_c/Ens01_27_c/10cm/flooded_area_5km_total_Ens01_27_c_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_41/Ens01_41/10cm/flooded_area_5km_total_Ens01_41_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_67/Ens01_67/10cm/flooded_area_5km_total_Ens01_67_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_2/Ens01_2/10cm/flooded_area_5km_total_Ens01_2_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_27_b/Ens01_27_b/10cm/flooded_area_5km_total_Ens01_27_b_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_90/Ens01_90/10cm/flooded_area_5km_total_Ens01_90_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_54_d/Ens01_54_d/10cm/flooded_area_5km_total_Ens01_54_d_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_92/Ens01_92/10cm/flooded_area_5km_total_Ens01_92_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_6/Ens01_6/10cm/flooded_area_5km_total_Ens01_6_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_71/Ens01_71/10cm/flooded_area_5km_total_Ens01_71_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_80/Ens01_80/10cm/flooded_area_5km_total_Ens01_80_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_54_c/Ens01_54_c/10cm/flooded_area_5km_total_Ens01_54_c_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens01_33_b/10cm/flooded_area_5km_total_Ens01_33_b_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_18/Ens01_18/10cm/flooded_area_5km_total_Ens01_18_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_51/Ens01_51/10cm/flooded_area_5km_total_Ens01_51_10cm.nc
# /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_42/Ens01_42/10cm/flooded_area_5km_total_Ens01_42_10cm.nc
# 25 catchments already complete, skipping.
# 62 catchments to process: ['105', '107', '11', '14', '16', '17', '18', '19', '2', '22', '27_a', '27_b', '27_c', '28_a', '28_b', '32', '33_b', '34', '35', '37', '38', '4', '41', '42', '43', '45', '46', '48', '49', '5', '51', '54_a', '54_b', '54_c', '54_d', '58', '6', '61', '65', '66', '67', '69', '7', '70', '71', '74', '75', '76', '78', '79', '80', '83', '85', '87', '88', '89', '90', '91', '92', '93', '94', '95']
# Running for catchment number: 17
# Running for catchment number: 34
# Running for catchment number: 14
# Running for catchment number: 27_c
# Running for catchment number: 7
# Running for catchment number: 74
# Running for catchment number: 19
# Running for catchment number: 76
# Running for catchment number: 46
# Running for catchment number: 45
# Running for catchment number: 78
# Running for catchment number: 41
# Running for catchment number: 67
# Running for catchment number: 54_b
# Running for catchment number: 11
# Running for catchment number: 85
# Running for catchment number: 66
# Running for catchment number: 70
# Running for catchment number: 94
# Running for catchment number: 2
# Running for catchment number: 91
# Running for catchment number: 95
# Running for catchment number: 27_b
# Running for catchment number: 75
# Running for catchment number: 90
# Running for catchment number: 43
# Running for catchment number: 37
# Running for catchment number: 35
# Running for catchment number: 32
# Running for catchment number: 27_a
# Running for catchment number: 38
# Running for catchment number: 54_d
# Running for catchment number: 105
# Running for catchment number: 4
# Running for catchment number: 22
# Running for catchment number: 92
# Running for catchment number: 87
# Running for catchment number: 28_a
# Running for catchment number: 89
# Running for catchment number: 83
# Running for catchment number: 6
# Running for catchment number: 93
# Running for catchment number: 28_b
# Running for catchment number: 71
# Running for catchment number: 80
# Running for catchment number: 5
# Running for catchment number: 54_c
# Running for catchment number: 61
# Running for catchment number: 48
# Running for catchment number: 88
# Running for catchment number: 65
# Running for catchment number: 33_b
# Running for catchment number: 54_a
# Running for catchment number: 69
# Running for catchment number: 18
# Running for catchment number: 58
# Running for catchment number: 79
# Running for catchment number: 107
# Running for catchment number: 49
# Running for catchment number: 51
# Running for catchment number: 16
# Running for catchment number: 42

# %%
import os
import glob
import re
import argparse
import xarray as xr
import rioxarray as rxr
import numpy as np
from rasterio.transform import from_bounds

# -----------------------------
# CONFIG
# -----------------------------
HA_NUM = 12

ROOT_DIR = "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4"
# OUTPUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

TIFS_DIR = os.path.join(ROOT_DIR, "tifs")

# Your 12 ensembles
ENSEMBLE_MEMBERS = ["01", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "15"]

# Only the two thresholds you care about
THRESHOLDS = ["10cm", "30cm"]

# QA output: write 30m geotiffs showing assigned 5km cell id per flooded pixel.
WRITE_QA_GRID_INDEX_TIF = False
QA_MAX_EVENTS_PER_THRESHOLD = 1

# Input grid
GRID_5KM_FILE = "/scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc"
# GRID_5KM_FILE = "/scratch/hydro5/users/ld14116/SDM_bias_correction/Hourly/01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_20801101-20801130.nc"

files = os.listdir("/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4/tifs/")

# Extract everything after 'Ens15_'
catchment_numbers = set()
for f in files:
    match = re.search(r'Ens15_(.+)', f)
    if match:
        catchment_numbers.add(match.group(1))

print(f"{len(catchment_numbers)} catchments found: {sorted(catchment_numbers)}")

# -----------------------------
# FILTER TO ONLY INCOMPLETE CATCHMENTS
# -----------------------------
def all_outputs_exist(ha_num):
    out_dir_base = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{ha_num}"
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(out_dir_base, ens, thr)
            for kind in ("area", "volume"):
                fname = f"flooded_{kind}_5km_total_{ens}_{thr}.nc"
                if not os.path.exists(os.path.join(out_dir, fname)):
                    return False
    return True

catchments_to_skip = {c for c in catchment_numbers if all_outputs_exist(c)}
catchments_to_run = catchment_numbers - catchments_to_skip

print(f"{len(catchments_to_skip)} catchments already complete, skipping.")
print(f"{len(catchments_to_run)} catchments to process: {sorted(catchments_to_run)}")


for HA_NUM in catchment_numbers:
    print(f"Running for catchment number: {HA_NUM}")
    OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

    # -----------------------------
    # CHECK IF ALL OUTPUTS EXIST
    # -----------------------------
    expected_outputs = []
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(OUT_DIR, ens, thr)
            expected_outputs.append(os.path.join(out_dir, f"flooded_area_5km_total_{ens}_{thr}.nc"))
            expected_outputs.append(os.path.join(out_dir, f"flooded_volume_5km_total_{ens}_{thr}.nc"))

    missing = [f for f in expected_outputs if not os.path.exists(f)]
    if not missing:
        print(f"All outputs already exist for {HA_NUM}, skipping.")
        continue
    else:
        print(f"{len(missing)} output(s) missing for {HA_NUM}, processing...")
        for f in missing:
            print(f"  Missing: {f}")

    print(f"Outputs to be stored in {OUT_DIR}")
    
    # -----------------------------
    # OPEN 5km GRID
    # -----------------------------
    print(f"Loading 5km grid from {GRID_5KM_FILE}...")
    ds = xr.open_dataset(GRID_5KM_FILE)

    x5 = ds["projection_x_coordinate"]
    y5 = ds["projection_y_coordinate"]

    nx = x5.size
    ny = y5.size

    dx = float(abs(x5[1] - x5[0]))
    dy = float(abs(y5[1] - y5[0]))

    xmin = float(x5.min() - dx/2)
    xmax = float(x5.max() + dx/2)
    ymin = float(y5.min() - dy/2)
    ymax = float(y5.max() + dy/2)

    # -----------------------------
    # CREATE GRID-ID RASTER
    # -----------------------------
    grid_ids = np.arange(nx * ny).reshape(ny, nx)

    # Use standard y, x dimension names for rioxarray compatibility
    grid_da = xr.DataArray(
        grid_ids,
        coords={"y": y5.values, "x": x5.values},
        dims=("y", "x")
    )

    grid_da = grid_da.rio.write_crs("EPSG:27700")

    transform = from_bounds(xmin, ymin, xmax, ymax, nx, ny)
    grid_da.rio.write_transform(transform, inplace=True)

    # Export a GeoTIFF copy of the 5km grid IDs for visual QA.
    # grid_out_dir = os.path.join(OUT_DIR, "grid")
    # os.makedirs(grid_out_dir, exist_ok=True)
    # grid_tif_path = os.path.join(grid_out_dir, f"grid_id_5km_from_input_{HA_NUM}.tif")
    # print(f"Saving 5km grid GeoTIFF to {grid_tif_path}...")
    # grid_da.astype("int32").rio.to_raster(grid_tif_path)

    # -----------------------------
    # COLLECT ALL EVENT FILES
    # -----------------------------
    print(f"Scanning for binary tif files for HA_NUM={HA_NUM}...")
    binary_event_files = list(iter_event_tifs(HA_NUM, data_kind="binary"))

    print(f"Scanning for filtered depth tif files for HA_NUM={HA_NUM}...")
    filtered_event_files = list(iter_event_tifs(HA_NUM, data_kind="filtered"))

    if not binary_event_files:
        raise ValueError(f"No binary tif files found for HA_NUM={HA_NUM}")

    if not filtered_event_files:
        raise ValueError(f"No filtered depth tif files found for HA_NUM={HA_NUM}")

    print(f"Found {len(binary_event_files)} binary event files")
    print(f"Found {len(filtered_event_files)} filtered depth event files")

    # -----------------------------
    # GROUP BY ENSEMBLE
    # -----------------------------
    from collections import defaultdict
    binary_by_ensemble = defaultdict(list)
    filtered_lookup = {}

    for info in binary_event_files:
        binary_by_ensemble[info['ensemble']].append(info)

    for info in filtered_event_files:
        key = (info["ensemble"], info["threshold"], info["event_num"])
        filtered_lookup[key] = info

    print(f"Found {len(binary_by_ensemble)} ensemble members")

    # -----------------------------
    # PROCESS EACH ENSEMBLE + THRESHOLD SEPARATELY
    # -----------------------------
    for ens_name in sorted(binary_by_ensemble.keys()):
        ens_events = binary_by_ensemble[ens_name]
        ens_events.sort(key=lambda x: (x['threshold'], x['event_num']))

        print(f"\n{'='*60}")
        print(f"Processing {ens_name}: {len(ens_events)} total events")
        print(f"{'='*60}")

        for thr in THRESHOLDS:
            thr_events = [e for e in ens_events if e["threshold"] == thr]
            if not thr_events:
                print(f"[WARN] No events for {ens_name} threshold {thr}")
                continue

            print(f"\n[{ens_name} | {thr}] Processing {len(thr_events)} events")

            flood_areas = []
            flood_volumes = []
            for i, info in enumerate(thr_events):
                print(f"[{i+1}/{len(thr_events)}] Processing {os.path.basename(info['path'])} (event={info['event_num']})")

                key = (ens_name, thr, info["event_num"])
                if key not in filtered_lookup:
                    raise ValueError(
                        f"Missing filtered depth tif for {ens_name}, {thr}, event={info['event_num']}"
                    )

                filtered_info = filtered_lookup[key]

                qa_out_tif = None
                if WRITE_QA_GRID_INDEX_TIF and i < QA_MAX_EVENTS_PER_THRESHOLD:
                    print("Performing QA")
                    qa_dir = os.path.join(OUT_DIR, "qa", ens_name, thr)
                    qa_out_tif = os.path.join(
                        qa_dir,
                        f"qa_5km_cell_index_{ens_name}_{thr}_event_{info['event_num']:03d}.tif"
                    )
                    print(f"    Writing QA 30m->5km index raster: {qa_out_tif}")
                else:
                    print("Skippping QA")

                flood_area = process_single_event_area(
                    info['path'],
                    x5, y5, nx, ny,
                    qa_out_tif=qa_out_tif)

                flood_volume = process_single_event_volume(
                    filtered_info["path"],
                    x5, y5, nx, ny)

                total_km2 = float(np.sum(flood_area))
                total_m3 = float(np.sum(flood_volume))
                print(f"    Total flooded area (sum of 5km cells): {total_km2:.4f} km2")
                print(f"    Total flooded volume (sum of 5km cells): {total_m3:.2f} m3")
                flood_areas.append(flood_area)
                flood_volumes.append(flood_volume)

            flood_areas_stack = np.stack(flood_areas, axis=0)
            flood_volumes_stack = np.stack(flood_volumes, axis=0)
            event_nums = np.array([info['event_num'] for info in thr_events], dtype=np.int32)

            out_area = xr.Dataset(
                {
                    "flooded_area_5km_km2": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_areas_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            out_volume = xr.Dataset(
                {
                    "flooded_volume_5km_m3": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_volumes_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            for out_ds in (out_area, out_volume):
                out_ds["projection_x_coordinate"].attrs.update({
                    "standard_name": "projection_x_coordinate",
                    "long_name": "x coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["projection_y_coordinate"].attrs.update({
                    "standard_name": "projection_y_coordinate",
                    "long_name": "y coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["event_num"].attrs["long_name"] = "event number"
                out_ds["event"].attrs["long_name"] = "event number"

            out_area = out_area.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_area.rio.write_transform(transform, inplace=True)
            out_area.rio.write_crs("EPSG:27700", inplace=True)
            out_area.rio.write_coordinate_system(inplace=True)

            out_volume = out_volume.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_volume.rio.write_transform(transform, inplace=True)
            out_volume.rio.write_crs("EPSG:27700", inplace=True)
            out_volume.rio.write_coordinate_system(inplace=True)

            out_area["flooded_area_5km_km2"].attrs["long_name"] = "Total flooded area per 5km grid cell"
            out_area["flooded_area_5km_km2"].attrs["units"] = "km2"
            out_volume["flooded_volume_5km_m3"].attrs["long_name"] = "Total flooded volume per 5km grid cell"
            out_volume["flooded_volume_5km_m3"].attrs["units"] = "m3"

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

            print(f"Saving area to {output_area_nc}...")
            out_area.to_netcdf(output_area_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_area_nc}")

            print(f"Saving volume to {output_volume_nc}...")
            out_volume.to_netcdf(output_volume_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_volume_nc}")

    print(f"\n{'='*60}")
    print(f"All {len(binary_by_ensemble)} ensemble members processed!")
# Out:
# 87 catchments found: ['101', '102', '104', '105', '107', '11', '12', '13', '14', '16', '17', '18', '19', '2', '22', '23', '26', '27_a', '27_b', '27_c', '28_a', '28_b', '28_c', '29', '32', '33_a', '33_b', '34', '35', '37', '38', '4', '40', '41', '42', '43', '44', '45', '46', '48', '49', '5', '51', '52', '53', '54_a', '54_b', '54_c', '54_d', '58', '59', '6', '61', '64', '65', '66', '67', '68', '69', '7', '70', '71', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '9', '90', '91', '92', '93', '94', '95', '96']
# 0 catchments already complete, skipping.
# 87 catchments to process: ['101', '102', '104', '105', '107', '11', '12', '13', '14', '16', '17', '18', '19', '2', '22', '23', '26', '27_a', '27_b', '27_c', '28_a', '28_b', '28_c', '29', '32', '33_a', '33_b', '34', '35', '37', '38', '4', '40', '41', '42', '43', '44', '45', '46', '48', '49', '5', '51', '52', '53', '54_a', '54_b', '54_c', '54_d', '58', '59', '6', '61', '64', '65', '66', '67', '68', '69', '7', '70', '71', '73', '74', '75', '76', '77', '78', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '9', '90', '91', '92', '93', '94', '95', '96']
# Running for catchment number: 53
# 48 output(s) missing for 53, processing...
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/01/10cm/flooded_area_5km_total_01_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/01/10cm/flooded_volume_5km_total_01_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/01/30cm/flooded_area_5km_total_01_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/01/30cm/flooded_volume_5km_total_01_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/04/10cm/flooded_area_5km_total_04_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/04/10cm/flooded_volume_5km_total_04_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/04/30cm/flooded_area_5km_total_04_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/04/30cm/flooded_volume_5km_total_04_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/05/10cm/flooded_area_5km_total_05_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/05/10cm/flooded_volume_5km_total_05_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/05/30cm/flooded_area_5km_total_05_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/05/30cm/flooded_volume_5km_total_05_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/06/10cm/flooded_area_5km_total_06_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/06/10cm/flooded_volume_5km_total_06_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/06/30cm/flooded_area_5km_total_06_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/06/30cm/flooded_volume_5km_total_06_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/07/10cm/flooded_area_5km_total_07_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/07/10cm/flooded_volume_5km_total_07_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/07/30cm/flooded_area_5km_total_07_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/07/30cm/flooded_volume_5km_total_07_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/08/10cm/flooded_area_5km_total_08_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/08/10cm/flooded_volume_5km_total_08_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/08/30cm/flooded_area_5km_total_08_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/08/30cm/flooded_volume_5km_total_08_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/09/10cm/flooded_area_5km_total_09_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/09/10cm/flooded_volume_5km_total_09_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/09/30cm/flooded_area_5km_total_09_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/09/30cm/flooded_volume_5km_total_09_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/10/10cm/flooded_area_5km_total_10_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/10/10cm/flooded_volume_5km_total_10_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/10/30cm/flooded_area_5km_total_10_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/10/30cm/flooded_volume_5km_total_10_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/11/10cm/flooded_area_5km_total_11_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/11/10cm/flooded_volume_5km_total_11_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/11/30cm/flooded_area_5km_total_11_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/11/30cm/flooded_volume_5km_total_11_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/12/10cm/flooded_area_5km_total_12_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/12/10cm/flooded_volume_5km_total_12_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/12/30cm/flooded_area_5km_total_12_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/12/30cm/flooded_volume_5km_total_12_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/13/10cm/flooded_area_5km_total_13_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/13/10cm/flooded_volume_5km_total_13_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/13/30cm/flooded_area_5km_total_13_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/13/30cm/flooded_volume_5km_total_13_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/15/10cm/flooded_area_5km_total_15_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/15/10cm/flooded_volume_5km_total_15_10cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/15/30cm/flooded_area_5km_total_15_30cm.nc
#   Missing: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53/15/30cm/flooded_volume_5km_total_15_30cm.nc
# Outputs to be stored in /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_53
# Loading 5km grid from /scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc...
# Scanning for binary tif files for HA_NUM=53...
# Scanning for filtered depth tif files for HA_NUM=53...
# Found 1276 binary event files
# Found 1276 filtered depth event files
# Found 12 ensemble members
#
# ============================================================
# Processing Ens01_53: 132 total events
# ============================================================
#
# [Ens01_53 | 10cm] Processing 66 events
# [1/66] Processing res_53_1993_1_Ens01_binary_10cm.tif (event=1)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.8611 km2
#     Total flooded volume (sum of 5km cells): 835575.31 m3
# [2/66] Processing res_53_1998_2_Ens01_binary_10cm.tif (event=2)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.8966 km2
#     Total flooded volume (sum of 5km cells): 3061597.50 m3
# [3/66] Processing res_53_2002_3_Ens01_binary_10cm.tif (event=3)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.2167 km2
#     Total flooded volume (sum of 5km cells): 3784406.25 m3
# [4/66] Processing res_53_2003_4_Ens01_binary_10cm.tif (event=4)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.7989 km2
#     Total flooded volume (sum of 5km cells): 4900293.00 m3
# [5/66] Processing res_53_2004_5_Ens01_binary_10cm.tif (event=5)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4739 km2
#     Total flooded volume (sum of 5km cells): 1410628.50 m3
# [6/66] Processing res_53_2008_6_Ens01_binary_10cm.tif (event=6)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.8050 km2
#     Total flooded volume (sum of 5km cells): 2070578.75 m3
# [7/66] Processing res_53_2012_7_Ens01_binary_10cm.tif (event=7)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2798 km2
#     Total flooded volume (sum of 5km cells): 543938.44 m3
# [8/66] Processing res_53_2015_8_Ens01_binary_10cm.tif (event=8)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.4796 km2
#     Total flooded volume (sum of 5km cells): 3299071.00 m3
# [9/66] Processing res_53_2016_9_Ens01_binary_10cm.tif (event=9)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.1179 km2
#     Total flooded volume (sum of 5km cells): 3297089.50 m3
# [10/66] Processing res_53_2017_10_Ens01_binary_10cm.tif (event=10)
# Skippping QA
#     Total flooded area (sum of 5km cells): 25.6752 km2
#     Total flooded volume (sum of 5km cells): 10117007.00 m3
# [11/66] Processing res_53_2018_11_Ens01_binary_10cm.tif (event=11)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.8891 km2
#     Total flooded volume (sum of 5km cells): 4921151.00 m3
# [12/66] Processing res_53_2019_12_Ens01_binary_10cm.tif (event=12)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.9529 km2
#     Total flooded volume (sum of 5km cells): 1081217.62 m3
# [13/66] Processing res_53_2025_13_Ens01_binary_10cm.tif (event=13)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.4315 km2
#     Total flooded volume (sum of 5km cells): 1924949.62 m3
# [14/66] Processing res_53_2026_14_Ens01_binary_10cm.tif (event=14)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7440 km2
#     Total flooded volume (sum of 5km cells): 1391842.75 m3
# [15/66] Processing res_53_2028_15_Ens01_binary_10cm.tif (event=15)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.2816 km2
#     Total flooded volume (sum of 5km cells): 6622666.50 m3
# [16/66] Processing res_53_2033_16_Ens01_binary_10cm.tif (event=16)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7630 km2
#     Total flooded volume (sum of 5km cells): 953387.12 m3
# [17/66] Processing res_53_2034_17_Ens01_binary_10cm.tif (event=17)
# Skippping QA
#     Total flooded area (sum of 5km cells): 25.5159 km2
#     Total flooded volume (sum of 5km cells): 10694486.00 m3
# [18/66] Processing res_53_2034_18_Ens01_binary_10cm.tif (event=18)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.4066 km2
#     Total flooded volume (sum of 5km cells): 843999.31 m3
# [19/66] Processing res_53_2036_19_Ens01_binary_10cm.tif (event=19)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.3038 km2
#     Total flooded volume (sum of 5km cells): 1333882.75 m3
# [20/66] Processing res_53_2037_20_Ens01_binary_10cm.tif (event=20)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.3749 km2
#     Total flooded volume (sum of 5km cells): 1514781.88 m3
# [21/66] Processing res_53_2038_21_Ens01_binary_10cm.tif (event=21)
# Skippping QA
#     Total flooded area (sum of 5km cells): 27.1980 km2
#     Total flooded volume (sum of 5km cells): 10801970.00 m3
# [22/66] Processing res_53_2040_22_Ens01_binary_10cm.tif (event=22)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7197 km2
#     Total flooded volume (sum of 5km cells): 1431745.25 m3
# [23/66] Processing res_53_2041_23_Ens01_binary_10cm.tif (event=23)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.8604 km2
#     Total flooded volume (sum of 5km cells): 3803377.50 m3
# [24/66] Processing res_53_2041_24_Ens01_binary_10cm.tif (event=24)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.8023 km2
#     Total flooded volume (sum of 5km cells): 2020484.75 m3
# [25/66] Processing res_53_2041_25_Ens01_binary_10cm.tif (event=25)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7224 km2
#     Total flooded volume (sum of 5km cells): 1277824.50 m3
# [26/66] Processing res_53_2041_26_Ens01_binary_10cm.tif (event=26)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.7031 km2
#     Total flooded volume (sum of 5km cells): 2490236.75 m3
# [27/66] Processing res_53_2042_27_Ens01_binary_10cm.tif (event=27)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.3354 km2
#     Total flooded volume (sum of 5km cells): 1278121.50 m3
# [28/66] Processing res_53_2042_28_Ens01_binary_10cm.tif (event=28)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.4063 km2
#     Total flooded volume (sum of 5km cells): 1912594.50 m3
# [29/66] Processing res_53_2042_29_Ens01_binary_10cm.tif (event=29)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1779 km2
#     Total flooded volume (sum of 5km cells): 1170489.75 m3
# [30/66] Processing res_53_2045_30_Ens01_binary_10cm.tif (event=30)
# Skippping QA
#     Total flooded area (sum of 5km cells): 15.4791 km2
#     Total flooded volume (sum of 5km cells): 5526382.50 m3
# [31/66] Processing res_53_2045_31_Ens01_binary_10cm.tif (event=31)
# Skippping QA
# KeyboardInterrupt

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Aggregate 30m flood rasters to 5km totals")
#     parser.add_argument(
#         "ha_num",
#         nargs="?",
#         default="23",
#         help="Catchment number (e.g. 23)"
#     )
#     args = parser.parse_args()
