# %% [markdown]
# ### Playing with data
# Aims of exploratory data anlysis, explore relationships between:
# - Rainfall descriptors (event volume, is this the only rainfall characteristic?)
# - Flooding outcomes ()
# - Catchment descriptors
# - Antecedent soil moisture conditions (mean value over catchment?, would there be a way to find mean value more specifically over the peak of the rainfall event )

# %%
# from jupyterthemes import get_themes
# import jupyterthemes as jt
# from jupyterthemes.stylefx import set_nb_theme

# set_nb_theme('monokai')

# jt -t monokai -N -T -kl

# %%
def mask_to_catchment(cube, catchment):

    catchment_proj = catchment.to_crs(epsg=27700)
    
    # Extract coordinates
    x = cube.coord('projection_x_coordinate').points
    y = cube.coord('projection_y_coordinate').points
    
    # Create 2D meshgrid of coordinates
    xx, yy = np.meshgrid(x, y)
    
    # Flatten coordinates
    points = np.vstack((xx.ravel(), yy.ravel())).T
    
    # Get catchment geometry
    catchment_geom = catchment_proj.geometry.iloc[0]
    
    # Test which grid cells are inside catchment
    mask = np.array([catchment_geom.contains(Point(pt)) for pt in points])
    
    # Reshape to grid
    mask = mask.reshape(len(y), len(x))
    return mask

def plot_soil_moisture_one_year_with_seasonal_boundaries(year, ax, one_plot, dataframe, col):
    one_year_soil_moisture = dataframe[dataframe['year']==year]
    one_year_events = rainfall_events[rainfall_events['start_year']==year].copy()
    
    ax.plot(one_year_soil_moisture['dates'], one_year_soil_moisture[col])
    
    # Axis labels
    if  ax.get_subplotspec().is_first_col() :
        ax.set_ylabel("Catchment Mean \n Soil Moisture")
    else:
        ax.set_ylabel("")

    if  ax.get_subplotspec().is_last_row() :
        ax.set_xlabel("Model Time")
    else:
        ax.set_xlabel("")
    
    # Title
    ax.set_title(year)
    
    #ax.xaxis.set_major_locator(mdates.MonthLocator())
    # Format tick labels to show month only
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))  # Jan, Feb, etc.
    plt.setp(ax.get_xticklabels(), rotation=0)
    if one_plot:
        ax.xaxis.set_major_locator(mdates.MonthLocator())
    else:
        ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))
    
    # # Define season boundaries
    winter_start = pd.Timestamp(f"{year}-01-01")
    spring_start = pd.Timestamp(f"{year}-03-01")
    summer_start = pd.Timestamp(f"{year}-06-01")
    autumn_start = pd.Timestamp(f"{year}-09-01")
    winter2_start = pd.Timestamp(f"{year}-12-01")
    next_year_start = pd.Timestamp(f"{year+1}-01-01")

    # # Add shaded regions
    ax.axvspan(winter_start, spring_start, color='lightblue', alpha=0.2)
    ax.axvspan(spring_start, summer_start, color='lightgreen', alpha=0.2)
    ax.axvspan(summer_start, autumn_start, color='khaki', alpha=0.2)
    ax.axvspan(autumn_start, winter2_start, color='navajowhite', alpha=0.2)
    ax.axvspan(winter2_start, next_year_start, color='lightblue', alpha=0.2)

    event_dates= one_year_events['start_date']
    if len(event_dates) >0:
        for event in event_dates:
            try:
                ax.axvline(event, color = 'red', linestyle='--');
            except:
                print("date which breaks rules")
                
def create_datetime_dates_from_cube(cube):
    time_coord = cube.coord('time')
    dates = time_coord.units.num2date(time_coord.points)
    time_numeric = cube.coord('time').points
    dates = pd.to_datetime("1970-01-01") + pd.to_timedelta(time_numeric, unit='h')
    return dates

# %%
import pandas as pd
import geopandas as gpd
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy import stats
import os
import numpy as np
import contextily as ctx
import iris
import iris.quickplot as qplt
import iris.plot as iplt
import iris.coord_categorisation
from shapely.geometry import Point
import glob
import cartopy.crs as ccrs
import pickle 
import cftime

home_dir = "C:/Users/kv25483/OneDrive - University of Bristol/FutureFlood/Data/"
home_dir = "/scratch/hydro4/users/" # kv25483/"

# %% [markdown]
# # Prepare the data
# Get soil data for one ensemble member over UK (from 1980 to 2080), joined into one cube

# %%
filepaths = sorted(glob.glob(
    "/scratch/hydro4/shared_data/climate_projections/UKCP18/"
    "UKCP_local/Soil_moisture/5km_regridded/Ens_01/*"
))

ds = xr.open_mfdataset(filepaths, combine='by_coords', decode_times=True)

# %%
df[70:90]
# Out:
#             precipitation
# 1981-02-11      26.211790
# 1981-02-12      26.519907
# 1981-02-13      26.370242
# 1981-02-14      26.041286
# 1981-02-15      25.791579
# 1981-02-16      25.657828
# 1981-02-17      25.535545
# 1981-02-18      25.388316
# 1981-02-19      25.253187
# 1981-02-20      25.156173
# 1981-02-21      25.229657
# 1981-02-22      25.159493
# 1981-02-23      25.027789
# 1981-02-24      24.891615
# 1981-02-25      24.870563
# 1981-02-26      25.430658
# 1981-02-27      25.826486
# 1981-02-28      26.100825
# NaT             26.006909
# NaT             26.249756

# %%
def cft_to_string(cfttime_obj):
        month = str(cfttime_obj.month)
        day = str(cfttime_obj.day)

        # This is awful but there were no two-digit months/days by default
        month = '0'+month if len(month)==1 else month
        day = '0'+day if len(day)==1 else day

        return f'{cfttime_obj.year}-{month}-{day}'
    
ds_time_strings = list(map(cft_to_string, ds['time'].data))

# Get precipitation values only (to use in pandas dataframe)
# Suppose the data are from multiple pixels (for whole of Europe)
# - that's why the mean(axis=(1,2))

precipitation = ds['moisture_content_of_soil_layer'].values.mean(axis=(1,2))

# To dataframe
df = pd.DataFrame(index=ds_time_strings, data={'precipitation': precipitation})

# Coerce erroneous dates
df.index = pd.to_datetime(df.index, errors='coerce')

# %%
# Select just the variable you want (e.g., soil moisture)
soil = ds["moisture_content_of_soil_layer"]

# Apply your mask to the lat/lon dims
soil_masked = soil.where(mask)

# Compute catchment mean
catchment_ts = soil_masked.mean(dim=["y", "x"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 5
#       2 soil = ds["moisture_content_of_soil_layer"]
#       4 # Apply your mask to the lat/lon dims
# ----> 5 soil_masked = soil.where(mask)
#       7 # Compute catchment mean
#       8 catchment_ts = soil_masked.mean(dim=["y", "x"])
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/core/common.py:1259, in DataWithCoords.where(self, cond, other, drop)
#    1255     cond = cond.isel(**indexers)
#    1257 from xarray.computation import ops
# -> 1259 return ops.where_method(self, cond, other)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/computation/ops.py:181, in where_method(self, cond, other)
#     179 # alignment for three arguments is complicated, so don't support it yet
#     180 join: Literal["inner", "exact"] = "inner" if other is dtypes.NA else "exact"
# --> 181 return apply_ufunc(
#     182     duck_array_ops.where_method,
#     183     self,
#     184     cond,
#     185     other,
#     186     join=join,
#     187     dataset_join=join,
#     188     dask="allowed",
#     189     keep_attrs=True,
#     190 )
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/computation/apply_ufunc.py:1263, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1261 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1262 elif any(isinstance(a, DataArray) for a in args):
# -> 1263     return apply_dataarray_vfunc(
#    1264         variables_vfunc,
#    1265         *args,
#    1266         signature=signature,
#    1267         join=join,
#    1268         exclude_dims=exclude_dims,
#    1269         keep_attrs=keep_attrs,
#    1270     )
#    1271 # feed Variables directly through apply_variable_ufunc
#    1272 elif any(isinstance(a, Variable) for a in args):
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/computation/apply_ufunc.py:305, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     300 result_coords, result_indexes = build_output_coords_and_indexes(
#     301     args, signature, exclude_dims, combine_attrs=keep_attrs
#     302 )
#     304 data_vars = [getattr(a, "variable", a) for a in args]
# --> 305 result_var = func(*data_vars)
#     307 out: tuple[DataArray, ...] | DataArray
#     308 if signature.num_outputs > 1:
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/computation/apply_ufunc.py:814, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     809 elif vectorize:
#     810     func = _vectorize(
#     811         func, signature, output_dtypes=output_dtypes, exclude_dims=exclude_dims
#     812     )
# --> 814 result_data = func(*input_data)
#     816 if signature.num_outputs == 1:
#     817     result_data = (result_data,)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/core/duck_array_ops.py:416, in where_method(data, cond, other)
#     414 if other is dtypes.NA:
#     415     other = dtypes.get_fill_value(data.dtype)
# --> 416 return where(cond, data, other)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/core/duck_array_ops.py:410, in where(condition, x, y)
#     407 else:
#     408     condition = astype(condition, dtype=dtype, xp=xp)
# --> 410 return xp.where(condition, *as_shared_dtype([x, y], xp=xp))
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/dask/array/core.py:1754, in Array.__array_function__(self, func, types, args, kwargs)
#    1751 if has_keyword(da_func, "like"):
#    1752     kwargs["like"] = self
# -> 1754 return da_func(*args, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/dask/array/routines.py:2114, in where(condition, x, y)
#    2112     return broadcast_to(out, shape).astype(dtype)
#    2113 else:
# -> 2114     return elemwise(np.where, condition, x, y)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/dask/array/core.py:4844, in elemwise(op, out, where, dtype, name, *args, **kwargs)
#    4840     shapes.append(out.shape)
#    4842 shapes = [s if isinstance(s, Iterable) else () for s in shapes]
#    4843 out_ndim = len(
# -> 4844     broadcast_shapes(*shapes)
#    4845 )  # Raises ValueError if dimensions mismatch
#    4846 expr_inds = tuple(range(out_ndim))[::-1]
#    4848 if dtype is not None:
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/dask/array/core.py:4772, in broadcast_shapes(*shapes)
#    4770         dim = 0 if 0 in sizes else np.max(sizes)
#    4771     if any(i not in [-1, 0, 1, dim] and not np.isnan(i) for i in sizes):
# -> 4772         raise ValueError(
#    4773             "operands could not be broadcast together with "
#    4774             "shapes {}".format(" ".join(map(str, shapes)))
#    4775         )
#    4776     out.append(dim)
#    4777 return tuple(reversed(out))
#
# ValueError: operands could not be broadcast together with shapes (244, 244) (36000, 244, 180) ()

# %%
# time_numeric = model_cube.coord('time').points
# dates = pd.to_datetime("1970-01-01") + pd.to_timedelta(time_numeric, unit='h')
# dates

# %%
time_coord = model_cube.coord('time')
dates = time_coord.units.num2date(time_coord.points)
dates
# Out:
# array([cftime.Datetime360Day(1980, 12, 1, 12, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1980, 12, 2, 12, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1980, 12, 3, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.Datetime360Day(2080, 11, 28, 12, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2080, 11, 29, 12, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(2080, 11, 30, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)

# %% [markdown]
# Mask the data to the Newcastle catchment

# %%
## Get spatial extent of catchment
catchments = gpd.read_file(home_dir + "kv25483/FutureFlood/Data/NewcastleExample/catchment_identifier/hyd_areas_GB_with_subcatchments.shp")
newcastle = catchments[catchments['HA_NUM'] == "23"]

# %%
# import numpy as np
# from shapely.geometry import Point

def mask_to_catchment_xr(ds, catchment):
    """
    ds: xarray DataArray or Dataset with x/y coords
    catchment: geopandas GeoDataFrame (projected to same CRS as ds)
    """
    # Reproject catchment to match data coordinates
    catchment_proj = catchment.to_crs(epsg=27700)
    catchment_geom = catchment_proj.geometry.iloc[0]

    # Extract x/y coordinates
    x = ds['projection_x_coordinate'].values
    y = ds['projection_y_coordinate'].values

    # 2D meshgrid
    xx, yy = np.meshgrid(x, y)

    # Flatten
    points = np.vstack([xx.ravel(), yy.ravel()]).T

    # Check which points are inside catchment
    mask_flat = np.array([catchment_geom.contains(Point(pt)) for pt in points])

    # Reshape to grid
    mask_2d = mask_flat.reshape(len(y), len(x))

    return mask_2d

soil = ds["moisture_content_of_soil_layer"]

# mask_2d has shape (y, x)
# mask_2d = mask_to_catchment_xr(ds, newcastle)
# soil_masked = soil.where(mask_2d)  # automatically broadcasts over time
catchment_ts = soil_masked.mean(dim=["projection_y_coordinate", "projection_x_coordinate"])

# %%
import matplotlib.pyplot as plt
import xarray as xr
import nc_time_axis 

# Compute catchment mean
# soil = ds["moisture_content_of_soil_layer"]  # replace with actual variable
# soil_masked = soil.where(mask)  # mask same dims
# catchment_ts = soil_masked.mean(dim=["y", "x"])

# Get unique years from the CFTimeIndex
years = list({t.year for t in catchment_ts.time.values})
years.sort()

fig, axes = plt.subplots(len(years), 1, figsize=(10, 3*len(years)), sharex=False)

if len(years) == 1:
    axes = [axes]

for ax, year in zip(axes, years):
    # select all times in that model year
    ts_year = catchment_ts.sel(time=catchment_ts.time.dt.year == year)
    ts_year.plot(ax=ax)
    ax.set_title(f"Year {year}")

    if ax.is_last_row():
        ax.set_xlabel("Model Time (360‑day calendar)")
    ax.set_ylabel("Soil Moisture")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[58], line 22
#      19 for ax, year in zip(axes, years):
#      20     # select all times in that model year
#      21     ts_year = catchment_ts.sel(time=catchment_ts.time.dt.year == year)
# ---> 22     ts_year.plot(ax=ax)
#      23     ax.set_title(f"Year {year}")
#      25     if ax.is_last_row():
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:310, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     306     plotfunc = hist
#     308 kwargs["ax"] = ax
# --> 310 return plotfunc(darray, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:510, in line(darray, row, col, figsize, aspect, size, ax, hue, x, y, xincrease, yincrease, xscale, yscale, xticks, yticks, xlim, ylim, add_legend, _labels, *args, **kwargs)
#     507 xlabel = label_from_attrs(xplt, extra=x_suffix)
#     508 ylabel = label_from_attrs(yplt, extra=y_suffix)
# --> 510 _ensure_plottable(xplt_val, yplt_val)
#     512 primitive = ax.plot(xplt_val, yplt_val, *args, **kwargs)
#     514 if _labels:
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/xarray/plot/utils.py:721, in _ensure_plottable(*args)
#     719     import nc_time_axis  # noqa: F401
#     720 else:
# --> 721     raise ImportError(
#     722         "Plotting of arrays of cftime.datetime "
#     723         "objects or arrays indexed by "
#     724         "cftime.datetime objects requires the "
#     725         "optional `nc-time-axis` (v1.2.0 or later) "
#     726         "package."
#     727     )
#
# ImportError: Plotting of arrays of cftime.datetime objects or arrays indexed by cftime.datetime objects requires the optional `nc-time-axis` (v1.2.0 or later) package.

# %%
years = np.array([t.year for t in catchment_ts['time'].values])
unique_years = np.unique(years)
unique_years
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#        2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045,
#        2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056,
#        2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067,
#        2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078,
#        2079, 2080])

# %%
unique_years = unique_years[:10]
n_years = len(unique_years)
fig, axes = plt.subplots(n_years, 1, figsize=(12, 3*n_years), sharey=True, sharex=False)

# If only 1 year, axes might not be an array
if n_years == 1:
    axes = [axes]

for i, year in enumerate(unique_years):
    ax = axes[i]
    
    # Select data for this year
    ts_year = catchment_ts.sel(time=[t for t in catchment_ts['time'].values if t.year == year])
    
    ax.plot(ts_year['time'].values, ts_year.values)
    ax.set_title(f"Year {year}")
    
    # Optionally label axes only on left/bottom
    if i == n_years - 1:
        ax.set_xlabel("Model Time (360-day calendar)")
    ax.set_ylabel("Catchment Mean Soil Moisture")
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 15
#      12 # Select data for this year
#      13 ts_year = catchment_ts.sel(time=[t for t in catchment_ts['time'].values if t.year == year])
# ---> 15 ax.plot(ts_year['time'].values, ts_year.values)
#      16 ax.set_title(f"Year {year}")
#      18 # Optionally label axes only on left/bottom
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
# -> 1779     self.add_line(line)
#    1780 if scalex:
#    1781     self._request_autoscale_view("x")
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/axes/_base.py:2417, in _AxesBase.add_line(self, line)
#    2414 if line.get_clip_path() is None:
#    2415     line.set_clip_path(self.patch)
# -> 2417 self._update_line_limits(line)
#    2418 if not line.get_label():
#    2419     line.set_label(f'_child{len(self._children)}')
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/axes/_base.py:2440, in _AxesBase._update_line_limits(self, line)
#    2436 def _update_line_limits(self, line):
#    2437     """
#    2438     Figures out the data limit of the given line, updating `.Axes.dataLim`.
#    2439     """
# -> 2440     path = line.get_path()
#    2441     if path.vertices.size == 0:
#    2442         return
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/lines.py:1052, in Line2D.get_path(self)
#    1050 """Return the `~matplotlib.path.Path` associated with this line."""
#    1051 if self._invalidy or self._invalidx:
# -> 1052     self.recache()
#    1053 return self._path
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/lines.py:689, in Line2D.recache(self, always)
#     687 if always or self._invalidx:
#     688     xconv = self.convert_xunits(self._xorig)
# --> 689     x = _to_unmasked_float_array(xconv).ravel()
#     690 else:
#     691     x = self._x
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/matplotlib/cbook.py:1355, in _to_unmasked_float_array(x)
#    1353     return np.ma.asarray(x, float).filled(np.nan)
#    1354 else:
# -> 1355     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'cftime._cftime.Datetime360Day'

# %% [markdown]
# Get the dates in human readable (and plottable) format

# %%
iris.FUTURE.date_microseconds = True
# Get a list of dates covered by the soil moisture data
dates = create_datetime_dates_from_cube(model_cube)
print(dates[:4])

years = dates.year
print(years[:4])
# Out:
# DatetimeIndex(['1980-10-05 12:00:00', '1980-10-06 12:00:00',
#                '1980-10-07 12:00:00', '1980-10-08 12:00:00'],
#               dtype='datetime64[ns]', freq=None)
# Index([1980, 1980, 1980, 1980], dtype='int32')

# %% [markdown]
# ## Find the mean daily/monthly soil moisture over time in Newcastle catchment

# %% [markdown]
# Find mean moisture over catchment (masking on the fly)

# %%
# def mask_to_catchment(cube, catchment):

#     catchment_proj = catchment.to_crs(epsg=27700)
    
#     # Extract coordinates
#     x = cube.coord('projection_x_coordinate').points
#     y = cube.coord('projection_y_coordinate').points
    
#     # Create 2D meshgrid of coordinates
#     xx, yy = np.meshgrid(x, y)
    
#     # Flatten coordinates
#     points = np.vstack((xx.ravel(), yy.ravel())).T
    
#     # Get catchment geometry
#     catchment_geom = catchment_proj.geometry.iloc[0]
    
#     # Test which grid cells are inside catchment
#     mask = np.array([catchment_geom.contains(Point(pt)) for pt in points])
    
#     # Reshape to grid
#     mask = mask.reshape(len(y), len(x))
#     return mask
# mask = mask_to_catchment(model_cube, newcastle)
# catchment_daily_mean = np.nanmean(np.where(mask, model_cube.data, np.nan), axis=(1, 2))
# def create_datetime_dates_from_cube(cube):
#     time_coord = cube.coord('time')
#     dates = time_coord.units.num2date(time_coord.points)
#     time_numeric = cube.coord('time').points
#     dates = pd.to_datetime("1970-01-01") + pd.to_timedelta(time_numeric, unit='h')
#     return dates    
# dates = create_datetime_dates_from_cube(model_cube)
# daily_means = pd.DataFrame({'dates':dates, 'daily_means':catchment_daily_mean, 'year':years})
# one_year_soil_moisture = daily_means[daily_means['year']==year]
# plt.plot(one_year_soil_moisture['dates'], one_year_soil_moisture['daily_means'])

# %%
# The np.where condition means: Where grid cells are inside Newcastle → keep real soil moisture values
#                               Where grid cells outside Newcastle → replace with np.nan
# This creates (on the fly) a masked 3D array with shape: (nt, ny, nx), which isn't saved but is used in the np.nanmean() calculation
# np.nanmean() then calculates the mean value across ny, nx dimensions (i.e. across the catchment), ignoring any np.nan values 
# To produce an output of shape (,nt).
if os.path.exists('../Data/catchment_daily_mean.pickle'):
    print("File already exists, reading in")
    file = open('../Data/catchment_daily_mean.pickle','rb')
    catchment_daily_mean = pickle.load(file)
else:
    catchment_daily_mean = np.nanmean(np.where(mask, model_cube.data, np.nan), axis=(1, 2))
    with open('../Data/catchment_daily_mean.pickle', 'wb') as handle:
        pickle.dump(catchment_daily_mean, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# File already exists, reading in

# %%
# qplt.plot(catchment_daily_mean)
catchment_daily_mean
# Out:
# array([80.31430311, 79.53589643, 76.6992927 , ..., 80.04838106,
#        80.43415552, 79.4442453 ])

# %% [markdown]
# Convert to dataframe

# %%
daily_means = pd.DataFrame({'dates':dates, 'daily_means':catchment_daily_mean, 'year':years})

# %% [markdown]
# Convert to monthly mean (and recreate daily mean, as setting the index to 'dates' messes it up)

# %%
daily_means = daily_means.set_index('dates')
monthly_means = daily_means['daily_means'].resample('MS').mean()
monthly_means = (daily_means['daily_means'].resample('MS').mean().reset_index())
monthly_means.rename(columns={'daily_means':'monthly_means'}, inplace=True)
monthly_means['year'] = monthly_means['dates'].dt.year
monthly_means['month'] = monthly_means['dates'].dt.month
daily_means = pd.DataFrame({'dates':dates, 'daily_means':catchment_daily_mean, 'year':years})

# %% [markdown]
# ## Get rainfall events

# %%
# os.listdir("/scratch/hydro4/users/ld14116/5km_grid/Rainfall_events/Events_duration_ensemble_monthly_threshold_varying_95th")
rainfall_events =pd.read_csv("/scratch/hydro4/users/ld14116/5km_grid/Rainfall_events/Events_duration_ensemble_monthly_threshold_consistent/NorthEastEngland_Ens_06_2020-2040_full_events.csv")

# %%
# test = rainfall_events[rainfall_events['Month']==2]
# test.sort_values(by='Day')

# %% [markdown]
# Create a date object, NB this has to be created as a 360 day calendar because there are some month/day combinations that are invalid (e.g., 30th Feb)
# 360 day calendar object doesn't work with plotting functionality.

# %%
rainfall_events['start_date'] = [cftime.Datetime360Day(y, m, d, h)
                for y, m, d, h in zip(rainfall_events['start_year'], rainfall_events['start_month'], 
                                      rainfall_events['start_day'], rainfall_events['start_hour'])]
rainfall_events['stop_date'] = [cftime.Datetime360Day(y, m, d, h)
                for y, m, d, h in zip(rainfall_events['stop_year'], rainfall_events['stop_month'], 
                                      rainfall_events['stop_day'], rainfall_events['stop_hour'])]

# %% [markdown]
# ## Plot catchment average soil moisture over time
# For one year

# %%
fig,ax=plt.subplots(figsize=(12,3))
plot_soil_moisture_one_year_with_seasonal_boundaries(year = 2022, ax = ax, one_plot=True,
                                                    dataframe=monthly_means, col='monthly_means')

# %% [markdown]
# For multiple years

# %%
fig,axs=plt.subplots(ncols=3, nrows=4, figsize=(10,10), sharey=True)
axs=axs.flatten()
for ax_num, year in enumerate(range(2020,2032)):
    plot_soil_moisture_one_year_with_seasonal_boundaries(year = year, ax = axs[ax_num], one_plot=False,
                                                        dataframe=monthly_means, col = 'monthly_means')

fig.tight_layout()
# Out:
# date which breaks rules

# %% [markdown]
# ## Look more closely at soil moisture either side of events

# %% [markdown]
# Convert dates of rainfall events

# %%
def convert_360day_to_datetime(year, month, day, origin_year=1970):
    # Number of days since origin in 360-day calendar
    years_since_origin = year - origin_year
    total_days = (
        years_since_origin * 360
        + (month - 1) * 30
        + (day - 1))
    
    return pd.Timestamp("1970-01-01") + pd.Timedelta(days=total_days)

rainfall_events['start_date_tinkered'] = [
    convert_360day_to_datetime(y, m, d)
    for y, m, d in zip(rainfall_events['start_year'],
                       rainfall_events['start_month'],
                       rainfall_events['start_day'])]

# %%
# rainfall_events['start_date'] = [cftime.Datetime360Day(y, m, d, h)
#                 for y, m, d, h in zip(events['start_year'], events['start_month'], events['start_day'], events['start_hour'])]

# %% [markdown]
# Not working because daily_means['dates'][0] is a Timestamp
# And start_window is cftime.Datetime360Day(2022, 1, 30, 20, 0, 0, 0, has_year_zero=True)

# %%
year = 2022

# Get events for that year
one_year_events = rainfall_events[rainfall_events['start_year'] == year].copy()

n_events = len(one_year_events)

if n_events == 0:
    print("No events in this year.")
else:
    
    fig, axes = plt.subplots(int(n_events/3), 3, figsize=(10, 4), sharex=False, sharey=False)
    axes = axes.flatten()
    
    # If only one event, axes is not a list
    if n_events == 1:
        axes = [axes]
    
    for ax, (_, event_row) in zip(axes, one_year_events.iterrows()):
        
        event_date = event_row['start_date_tinkered']
        
        # Define window
        start_window = event_date - pd.Timedelta(days=10)
        end_window   = event_date + pd.Timedelta(days=10)
        
        # Subset soil moisture
        window_data = daily_means[
            (daily_means['dates'] >= start_window) &
            (daily_means['dates'] <= end_window)]
        
        # Plot
        ax.plot(window_data['dates'], window_data['daily_means'], color='black')
        ax.axvline(event_date, color='red', linestyle='--')
        
        # Title
        ax.set_title(f"Event on {event_date.date()}")
        
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%d'))  # Jan, Feb, etc.
        plt.setp(ax.get_xticklabels(), rotation=0)
    
        # Format labels
        if  ax.get_subplotspec().is_first_col() :
            ax.set_ylabel("Catchment Mean \n Soil Moisture")
        else:
            ax.set_ylabel("")

        if  ax.get_subplotspec().is_last_row() :
            ax.set_xlabel("Day")
        else:
            ax.set_xlabel("")

    
    plt.tight_layout()
    plt.show()
