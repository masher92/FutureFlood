# %%
def extract_event_number(filename):
    """
    Extract event number from filenames like:
    res_23_1993_1_Ens07_binary_10cm.tif -> 1
    res_23_1993_123_Ens07_binary_10cm.tif -> 123
    """
    match = re.search(r'_(\d+)_Ens\d+_(?:binary|filtered)_', filename)
    if match:
        return int(match.group(1))
    return None


def iter_event_tifs(ha_num, data_kind, ensembles=None, thresholds=None):
    """
    Yield metadata for every event tif in:
    tifs/EnsXX_<HA_NUM>/<data_kind>/10cm/*.tif
    tifs/EnsXX_<HA_NUM>/<data_kind>/30cm/*.tif
    """
    if data_kind not in {"binary", "filtered"}:
        raise ValueError(f"Unsupported data_kind={data_kind}")

    ensembles = ensembles or ENSEMBLE_MEMBERS
    thresholds = thresholds or THRESHOLDS
    ha_num = str(ha_num)

    for ens in ensembles:
        ens_name = f"Ens{ens}_{ha_num}"

        for thr in thresholds:
            tif_glob = os.path.join(TIFS_DIR, ens_name, data_kind, thr, "*.tif")
            tif_paths = sorted(glob.glob(tif_glob))

            if not tif_paths:
                print(f"[WARN] No files found: {os.path.dirname(tif_glob)}")
                continue

            for tif_path in tif_paths:
                event_num = extract_event_number(os.path.basename(tif_path))
                if event_num is None:
                    print(f"[WARN] Could not extract event number from: {os.path.basename(tif_path)}")
                    continue
                
                yield {
                    "ha_num": ha_num,
                    "ensemble": ens_name,
                    "threshold": thr,
                    "data_kind": data_kind,
                    "path": tif_path,
                    "event_num": event_num,
                }


def process_single_event_area(binary_file, x5, y5, nx, ny, qa_out_tif=None):
    """
    Process a single binary flood tif and return flooded area per 5km grid cell.
    Maps 30m pixels directly to the original 5km grid using coordinates.
    """
    # Open flood raster
    flood = rxr.open_rasterio(
        binary_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if flood.rio.crs is None or flood.rio.crs.to_string() != "EPSG:27700":
        flood = flood.rio.reproject("EPSG:27700")

    # Identify valid pixels
    valid = flood.notnull()

    # Get flood pixel coordinates and values
    flood_x = flood.x.values
    flood_y = flood.y.values
    
    # Create meshgrid of flood coordinates
    xx, yy = np.meshgrid(flood_x, flood_y)
    
    # Flatten coordinates and values
    x_flat = xx.ravel()
    y_flat = yy.ravel()
    flood_flat = flood.values.ravel()
    valid_flat = valid.values.ravel()
    
    # Only keep valid, flooded pixels
    mask = valid_flat & (flood_flat > 0)
    x_flood = x_flat[mask]
    y_flood = y_flat[mask]
    
    if x_flood.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    # Map flood-pixel centers to 5km cell indices using cell edges.
    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_flood - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_flood) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_flood - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_flood) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)
    
    # Convert 2D indices to 1D linear indices
    linear_idx = iy * nx + ix

    if qa_out_tif is not None:
        # Build QA raster in original 30m grid:
        # value = 5km linear cell index for flooded pixels, -1 elsewhere.
        flooded_flat_idx = np.where(mask)[0]
        flooded_flat_idx_in_grid = flooded_flat_idx[in_grid]
        qa_flat = np.full(flood_flat.shape, -1, dtype=np.int32)
        qa_flat[flooded_flat_idx_in_grid] = linear_idx.astype(np.int32)
        qa_arr = qa_flat.reshape(flood.shape)

        qa_da = xr.DataArray(qa_arr, coords=flood.coords, dims=flood.dims)
        qa_da = qa_da.rio.write_crs(flood.rio.crs)
        qa_da.rio.write_transform(flood.rio.transform(), inplace=True)

        os.makedirs(os.path.dirname(qa_out_tif), exist_ok=True)
        qa_da.rio.to_raster(qa_out_tif)
    
    # Count flooded pixels per grid cell
    counts_flat = np.bincount(linear_idx, minlength=nx * ny)
    counts = counts_flat.reshape(ny, nx)
    
    # Convert flooded-pixel counts to total flooded area using actual raster resolution.
    xres, yres = flood.rio.resolution()
    pixel_area_km2 = (abs(xres) * abs(yres)) / 1e6
    flood_area = counts.astype(np.float32) * pixel_area_km2
    
    return flood_area


def process_single_event_volume(depth_file, x5, y5, nx, ny):
    """
    Process a single depth flood tif and return flooded volume per 5km grid cell.
    Volume is computed as sum(depth_m * pixel_area_m2) over pixels within each 5km cell.
    """
    depth = rxr.open_rasterio(
        depth_file,
        chunks={"x": 2000, "y": 2000}
    ).squeeze()

    if depth.rio.crs is None or depth.rio.crs.to_string() != "EPSG:27700":
        depth = depth.rio.reproject("EPSG:27700")

    valid = depth.notnull()

    depth_x = depth.x.values
    depth_y = depth.y.values
    xx, yy = np.meshgrid(depth_x, depth_y)

    x_flat = xx.ravel()
    y_flat = yy.ravel()
    depth_flat = depth.values.ravel()
    valid_flat = valid.values.ravel()

    # Only include valid, positive depths in the volume sum.
    mask = valid_flat & (depth_flat > 0)
    x_depth = x_flat[mask]
    y_depth = y_flat[mask]
    depth_vals = depth_flat[mask].astype(np.float64)

    if x_depth.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_depth - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_depth) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_depth - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_depth) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]
    depth_vals = depth_vals[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    linear_idx = iy * nx + ix

    xres, yres = depth.rio.resolution()
    pixel_area_m2 = abs(xres) * abs(yres)

    # Depth rasters are in meters, so depth[m] * area[m2] -> volume[m3].
    contrib_m3 = depth_vals * pixel_area_m2
    volume_flat = np.bincount(linear_idx, weights=contrib_m3, minlength=nx * ny)
    flood_volume = volume_flat.reshape(ny, nx).astype(np.float32)

    return flood_volume

# %%
import os
import glob
import re
import argparse
import xarray as xr
import rioxarray as rxr
import numpy as np
from rasterio.transform import from_bounds

# -----------------------------
# CONFIG
# -----------------------------
ROOT_DIR = "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4"
# OUTPUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

TIFS_DIR = os.path.join(ROOT_DIR, "tifs")

# Your 12 ensembles
ENSEMBLE_MEMBERS = ["01", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "15"]

# Only the two thresholds you care about
THRESHOLDS = ["10cm", "30cm"]

# QA output: write 30m geotiffs showing assigned 5km cell id per flooded pixel.
WRITE_QA_GRID_INDEX_TIF = False
QA_MAX_EVENTS_PER_THRESHOLD = 1

# Input grid
GRID_5KM_FILE = "/scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc"
# GRID_5KM_FILE = "/scratch/hydro5/users/ld14116/SDM_bias_correction/Hourly/01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_20801101-20801130.nc"

# %%
files = os.listdir("/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4/tifs/")

# Extract everything after 'Ens15_'
catchment_numbers = set()
for f in files:
    match = re.search(r'Ens15_(.+)', f)
    if match:
        catchment_numbers.add(match.group(1))

# -----------------------------
# FILTER TO ONLY INCOMPLETE CATCHMENTS
# -----------------------------
def all_outputs_exist(ha_num):
    out_dir_base = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{ha_num}"
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(out_dir_base, f"Ens{ens}_{ha_num}", thr)
            for kind in ("area", "volume"):
                fname = f"flooded_{kind}_5km_total_Ens{ens}_{ha_num}_{thr}.nc"
                if not os.path.exists(os.path.join(out_dir, fname)):
                    return False
    return True

catchments_to_skip = {c for c in catchment_numbers if all_outputs_exist(c)}
catchments_to_run = catchment_numbers - catchments_to_skip

print(f"{len(catchments_to_skip)} catchments already complete, skipping.")
print(f"{len(catchments_to_run)} catchments to process: {sorted(catchments_to_run)}")
# Out:
# 114 catchments already complete, skipping.
# 0 catchments to process: []

# %%
for HA_NUM in ['33_b']:
    print(f"Running for {HA_NUM}")
    OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"
    print(f"Outputs to be stored in {OUT_DIR}")
    
    # -----------------------------
    # OPEN 5km GRID
    # -----------------------------
    print(f"Loading 5km grid from {GRID_5KM_FILE}...")
    ds = xr.open_dataset(GRID_5KM_FILE)

    x5 = ds["projection_x_coordinate"]
    y5 = ds["projection_y_coordinate"]

    nx = x5.size
    ny = y5.size

    dx = float(abs(x5[1] - x5[0]))
    dy = float(abs(y5[1] - y5[0]))

    xmin = float(x5.min() - dx/2)
    xmax = float(x5.max() + dx/2)
    ymin = float(y5.min() - dy/2)
    ymax = float(y5.max() + dy/2)

    # -----------------------------
    # CREATE GRID-ID RASTER
    # -----------------------------
    grid_ids = np.arange(nx * ny).reshape(ny, nx)

    # Use standard y, x dimension names for rioxarray compatibility
    grid_da = xr.DataArray(
        grid_ids,
        coords={"y": y5.values, "x": x5.values},
        dims=("y", "x")
    )

    grid_da = grid_da.rio.write_crs("EPSG:27700")

    transform = from_bounds(xmin, ymin, xmax, ymax, nx, ny)
    grid_da.rio.write_transform(transform, inplace=True)

    # Export a GeoTIFF copy of the 5km grid IDs for visual QA.
    # grid_out_dir = os.path.join(OUT_DIR, "grid")
    # os.makedirs(grid_out_dir, exist_ok=True)
    # grid_tif_path = os.path.join(grid_out_dir, f"grid_id_5km_from_input_{HA_NUM}.tif")
    # print(f"Saving 5km grid GeoTIFF to {grid_tif_path}...")
    # grid_da.astype("int32").rio.to_raster(grid_tif_path)

    # -----------------------------
    # COLLECT ALL EVENT FILES
    # -----------------------------
    print(f"Scanning for binary tif files for HA_NUM={HA_NUM}...")
    binary_event_files = list(iter_event_tifs(HA_NUM, data_kind="binary"))

    print(f"Scanning for filtered depth tif files for HA_NUM={HA_NUM}...")
    filtered_event_files = list(iter_event_tifs(HA_NUM, data_kind="filtered"))

    if not binary_event_files:
        raise ValueError(f"No binary tif files found for HA_NUM={HA_NUM}")

    if not filtered_event_files:
        raise ValueError(f"No filtered depth tif files found for HA_NUM={HA_NUM}")

    print(f"Found {len(binary_event_files)} binary event files")
    print(f"Found {len(filtered_event_files)} filtered depth event files")

    # -----------------------------
    # GROUP BY ENSEMBLE
    # -----------------------------
    from collections import defaultdict
    binary_by_ensemble = defaultdict(list)
    filtered_lookup = {}

    for info in binary_event_files:
        binary_by_ensemble[info['ensemble']].append(info)

    for info in filtered_event_files:
        key = (info["ensemble"], info["threshold"], info["event_num"])
        filtered_lookup[key] = info

    print(f"Found {len(binary_by_ensemble)} ensemble members")

    # -----------------------------
    # PROCESS EACH ENSEMBLE + THRESHOLD SEPARATELY
    # -----------------------------
    for ens_name in sorted(binary_by_ensemble.keys()):
#     for ens_name in ['Ens13_106']:        
        ens_events = binary_by_ensemble[ens_name]
        ens_events.sort(key=lambda x: (x['threshold'], x['event_num']))

        print(f"\n{'='*60}")
        print(f"Processing {ens_name}: {len(ens_events)} total events")
        print(f"{'='*60}")
        
        for thr in THRESHOLDS:
            thr_events = [e for e in ens_events if e["threshold"] == thr]
            if not thr_events:
                print(f"[WARN] No events for {ens_name} threshold {thr}")
                continue

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

            if os.path.exists(output_area_nc) and os.path.exists(output_volume_nc):
                print(f"[SKIP] Outputs already exist for {ens_name} | {thr}")
                continue

            print(f"\n[{ens_name} | {thr}] Processing {len(thr_events)} events")

            flood_areas = []
            flood_volumes = []
            for i, info in enumerate(thr_events):
                print(f"[{i+1}/{len(thr_events)}] Processing {os.path.basename(info['path'])} (event={info['event_num']})")

                key = (ens_name, thr, info["event_num"])
                if key not in filtered_lookup:
                    raise ValueError(
                        f"Missing filtered depth tif for {ens_name}, {thr}, event={info['event_num']}"
                    )

                filtered_info = filtered_lookup[key]

                qa_out_tif = None
                if WRITE_QA_GRID_INDEX_TIF and i < QA_MAX_EVENTS_PER_THRESHOLD:
                    print("Performing QA")
                    qa_dir = os.path.join(OUT_DIR, "qa", ens_name, thr)
                    qa_out_tif = os.path.join(
                        qa_dir,
                        f"qa_5km_cell_index_{ens_name}_{thr}_event_{info['event_num']:03d}.tif"
                    )
                    print(f"    Writing QA 30m->5km index raster: {qa_out_tif}")
                else:
                    print("Skippping QA")

                flood_area = process_single_event_area(
                    info['path'],
                    x5, y5, nx, ny,
                    qa_out_tif=qa_out_tif)

                flood_volume = process_single_event_volume(
                    filtered_info["path"],
                    x5, y5, nx, ny)

                total_km2 = float(np.sum(flood_area))
                total_m3 = float(np.sum(flood_volume))
                print(f"    Total flooded area (sum of 5km cells): {total_km2:.4f} km2")
                print(f"    Total flooded volume (sum of 5km cells): {total_m3:.2f} m3")
                flood_areas.append(flood_area)
                flood_volumes.append(flood_volume)

            flood_areas_stack = np.stack(flood_areas, axis=0)
            flood_volumes_stack = np.stack(flood_volumes, axis=0)
            event_nums = np.array([info['event_num'] for info in thr_events], dtype=np.int32)

            out_area = xr.Dataset(
                {
                    "flooded_area_5km_km2": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_areas_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            out_volume = xr.Dataset(
                {
                    "flooded_volume_5km_m3": (
                        ("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_volumes_stack
                    ),
                    "event_num": ("event", event_nums),
                },
                coords={
                    "event": event_nums,
                    "projection_x_coordinate": x5,
                    "projection_y_coordinate": y5
                }
            )

            for out_ds in (out_area, out_volume):
                out_ds["projection_x_coordinate"].attrs.update({
                    "standard_name": "projection_x_coordinate",
                    "long_name": "x coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["projection_y_coordinate"].attrs.update({
                    "standard_name": "projection_y_coordinate",
                    "long_name": "y coordinate of British National Grid projection",
                    "units": "m"
                })
                out_ds["event_num"].attrs["long_name"] = "event number"
                out_ds["event"].attrs["long_name"] = "event number"

            out_area = out_area.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_area.rio.write_transform(transform, inplace=True)
            out_area.rio.write_crs("EPSG:27700", inplace=True)
            out_area.rio.write_coordinate_system(inplace=True)

            out_volume = out_volume.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate"
            )
            out_volume.rio.write_transform(transform, inplace=True)
            out_volume.rio.write_crs("EPSG:27700", inplace=True)
            out_volume.rio.write_coordinate_system(inplace=True)

            out_area["flooded_area_5km_km2"].attrs["long_name"] = "Total flooded area per 5km grid cell"
            out_area["flooded_area_5km_km2"].attrs["units"] = "km2"
            out_volume["flooded_volume_5km_m3"].attrs["long_name"] = "Total flooded volume per 5km grid cell"
            out_volume["flooded_volume_5km_m3"].attrs["units"] = "m3"

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

            print(f"Saving area to {output_area_nc}...")
            out_area.to_netcdf(output_area_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_area_nc}")

            print(f"Saving volume to {output_volume_nc}...")
            out_volume.to_netcdf(output_volume_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_volume_nc}")

    print(f"\n{'='*60}")
    print(f"All {len(binary_by_ensemble)} ensemble members processed!")
# Out:
# Running for 33_b
# Outputs to be stored in /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b
# Loading 5km grid from /scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc...
# Scanning for binary tif files for HA_NUM=33_b...
# Scanning for filtered depth tif files for HA_NUM=33_b...
# Found 3016 binary event files
# Found 3016 filtered depth event files
# Found 12 ensemble members
#
# ============================================================
# Processing Ens01_33_b: 292 total events
# ============================================================
# [SKIP] Outputs already exist for Ens01_33_b | 10cm
# [SKIP] Outputs already exist for Ens01_33_b | 30cm
#
# ============================================================
# Processing Ens04_33_b: 388 total events
# ============================================================
#
# [Ens04_33_b | 10cm] Processing 194 events
# [1/194] Processing res_33_b_1995_1_Ens04_binary_10cm.tif (event=1)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9071 km2
#     Total flooded volume (sum of 5km cells): 376250.41 m3
# [2/194] Processing res_33_b_1995_2_Ens04_binary_10cm.tif (event=2)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3329 km2
#     Total flooded volume (sum of 5km cells): 241226.09 m3
# [3/194] Processing res_33_b_1998_3_Ens04_binary_10cm.tif (event=3)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.2984 km2
#     Total flooded volume (sum of 5km cells): 840514.56 m3
# [4/194] Processing res_33_b_1999_4_Ens04_binary_10cm.tif (event=4)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.8533 km2
#     Total flooded volume (sum of 5km cells): 1951084.00 m3
# [5/194] Processing res_33_b_1999_5_Ens04_binary_10cm.tif (event=5)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.8951 km2
#     Total flooded volume (sum of 5km cells): 1248582.62 m3
# [6/194] Processing res_33_b_2000_6_Ens04_binary_10cm.tif (event=6)
# Skippping QA
#     Total flooded area (sum of 5km cells): 37.6623 km2
#     Total flooded volume (sum of 5km cells): 9634274.00 m3
# [7/194] Processing res_33_b_2000_7_Ens04_binary_10cm.tif (event=7)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.4916 km2
#     Total flooded volume (sum of 5km cells): 1565018.12 m3
# [8/194] Processing res_33_b_2000_8_Ens04_binary_10cm.tif (event=8)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4229 km2
#     Total flooded volume (sum of 5km cells): 394124.44 m3
# [9/194] Processing res_33_b_2001_9_Ens04_binary_10cm.tif (event=9)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.4483 km2
#     Total flooded volume (sum of 5km cells): 1894514.38 m3
# [10/194] Processing res_33_b_2001_10_Ens04_binary_10cm.tif (event=10)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.5793 km2
#     Total flooded volume (sum of 5km cells): 906622.12 m3
# [11/194] Processing res_33_b_2001_11_Ens04_binary_10cm.tif (event=11)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.3112 km2
#     Total flooded volume (sum of 5km cells): 762655.50 m3
# [12/194] Processing res_33_b_2002_12_Ens04_binary_10cm.tif (event=12)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.7360 km2
#     Total flooded volume (sum of 5km cells): 3145229.25 m3
# [13/194] Processing res_33_b_2002_13_Ens04_binary_10cm.tif (event=13)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.1660 km2
#     Total flooded volume (sum of 5km cells): 1384288.25 m3
# [14/194] Processing res_33_b_2003_14_Ens04_binary_10cm.tif (event=14)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.7838 km2
#     Total flooded volume (sum of 5km cells): 2134404.00 m3
# [15/194] Processing res_33_b_2003_15_Ens04_binary_10cm.tif (event=15)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.9655 km2
#     Total flooded volume (sum of 5km cells): 615379.56 m3
# [16/194] Processing res_33_b_2004_16_Ens04_binary_10cm.tif (event=16)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.8900 km2
#     Total flooded volume (sum of 5km cells): 638286.31 m3
# [17/194] Processing res_33_b_2004_17_Ens04_binary_10cm.tif (event=17)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7352 km2
#     Total flooded volume (sum of 5km cells): 413379.91 m3
# [18/194] Processing res_33_b_2004_18_Ens04_binary_10cm.tif (event=18)
# Skippping QA
#     Total flooded area (sum of 5km cells): 18.6327 km2
#     Total flooded volume (sum of 5km cells): 4549288.00 m3
# [19/194] Processing res_33_b_2006_19_Ens04_binary_10cm.tif (event=19)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.6296 km2
#     Total flooded volume (sum of 5km cells): 1077163.25 m3
# [20/194] Processing res_33_b_2006_20_Ens04_binary_10cm.tif (event=20)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.4696 km2
#     Total flooded volume (sum of 5km cells): 2690761.75 m3
# [21/194] Processing res_33_b_2006_21_Ens04_binary_10cm.tif (event=21)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.1422 km2
#     Total flooded volume (sum of 5km cells): 1965033.00 m3
# [22/194] Processing res_33_b_2006_22_Ens04_binary_10cm.tif (event=22)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.1559 km2
#     Total flooded volume (sum of 5km cells): 1934801.12 m3
# [23/194] Processing res_33_b_2007_23_Ens04_binary_10cm.tif (event=23)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.8345 km2
#     Total flooded volume (sum of 5km cells): 1964322.12 m3
# [24/194] Processing res_33_b_2007_24_Ens04_binary_10cm.tif (event=24)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.8380 km2
#     Total flooded volume (sum of 5km cells): 2443570.25 m3
# [25/194] Processing res_33_b_2008_25_Ens04_binary_10cm.tif (event=25)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7434 km2
#     Total flooded volume (sum of 5km cells): 171658.81 m3
# [26/194] Processing res_33_b_2008_26_Ens04_binary_10cm.tif (event=26)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.3956 km2
#     Total flooded volume (sum of 5km cells): 3159052.25 m3
# [27/194] Processing res_33_b_2010_27_Ens04_binary_10cm.tif (event=27)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.4734 km2
#     Total flooded volume (sum of 5km cells): 2048410.75 m3
# [28/194] Processing res_33_b_2010_28_Ens04_binary_10cm.tif (event=28)
# Skippping QA
#     Total flooded area (sum of 5km cells): 17.2800 km2
#     Total flooded volume (sum of 5km cells): 3197930.50 m3
# [29/194] Processing res_33_b_2011_29_Ens04_binary_10cm.tif (event=29)
# Skippping QA
#     Total flooded area (sum of 5km cells): 67.6584 km2
#     Total flooded volume (sum of 5km cells): 14907638.00 m3
# [30/194] Processing res_33_b_2012_30_Ens04_binary_10cm.tif (event=30)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0295 km2
#     Total flooded volume (sum of 5km cells): 540510.25 m3
# [31/194] Processing res_33_b_2012_31_Ens04_binary_10cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7018 km2
#     Total flooded volume (sum of 5km cells): 577472.38 m3
# [32/194] Processing res_33_b_2013_32_Ens04_binary_10cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1014 km2
#     Total flooded volume (sum of 5km cells): 566080.19 m3
# [33/194] Processing res_33_b_2014_33_Ens04_binary_10cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4811 km2
#     Total flooded volume (sum of 5km cells): 794312.06 m3
# [34/194] Processing res_33_b_2014_34_Ens04_binary_10cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.8959 km2
#     Total flooded volume (sum of 5km cells): 1529042.38 m3
# [35/194] Processing res_33_b_2017_35_Ens04_binary_10cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.5052 km2
#     Total flooded volume (sum of 5km cells): 1615757.38 m3
# [36/194] Processing res_33_b_2017_36_Ens04_binary_10cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.0696 km2
#     Total flooded volume (sum of 5km cells): 1615263.38 m3
# [37/194] Processing res_33_b_2018_37_Ens04_binary_10cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.5948 km2
#     Total flooded volume (sum of 5km cells): 2865052.00 m3
# [38/194] Processing res_33_b_2018_38_Ens04_binary_10cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0430 km2
#     Total flooded volume (sum of 5km cells): 381030.28 m3
# [39/194] Processing res_33_b_2018_39_Ens04_binary_10cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9998 km2
#     Total flooded volume (sum of 5km cells): 487201.50 m3
# [40/194] Processing res_33_b_2018_40_Ens04_binary_10cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2016 km2
#     Total flooded volume (sum of 5km cells): 44248.50 m3
# [41/194] Processing res_33_b_2018_41_Ens04_binary_10cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 21.5190 km2
#     Total flooded volume (sum of 5km cells): 5156973.00 m3
# [42/194] Processing res_33_b_2018_42_Ens04_binary_10cm.tif (event=42)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9324 km2
#     Total flooded volume (sum of 5km cells): 206179.19 m3
# [43/194] Processing res_33_b_2019_43_Ens04_binary_10cm.tif (event=43)
# Skippping QA
#     Total flooded area (sum of 5km cells): 35.8929 km2
#     Total flooded volume (sum of 5km cells): 9244657.00 m3
# [44/194] Processing res_33_b_2019_44_Ens04_binary_10cm.tif (event=44)
# Skippping QA
#     Total flooded area (sum of 5km cells): 18.2628 km2
#     Total flooded volume (sum of 5km cells): 5170897.50 m3
# [45/194] Processing res_33_b_2019_45_Ens04_binary_10cm.tif (event=45)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.3343 km2
#     Total flooded volume (sum of 5km cells): 4944128.00 m3
# [46/194] Processing res_33_b_2019_46_Ens04_binary_10cm.tif (event=46)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.2444 km2
#     Total flooded volume (sum of 5km cells): 1133898.25 m3
# [47/194] Processing res_33_b_2020_47_Ens04_binary_10cm.tif (event=47)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.1504 km2
#     Total flooded volume (sum of 5km cells): 2208246.50 m3
# [48/194] Processing res_33_b_2020_48_Ens04_binary_10cm.tif (event=48)
# Skippping QA
#     Total flooded area (sum of 5km cells): 23.0868 km2
#     Total flooded volume (sum of 5km cells): 6035859.50 m3
# [49/194] Processing res_33_b_2021_49_Ens04_binary_10cm.tif (event=49)
# Skippping QA
#     Total flooded area (sum of 5km cells): 50.7888 km2
#     Total flooded volume (sum of 5km cells): 11290181.00 m3
# [50/194] Processing res_33_b_2021_50_Ens04_binary_10cm.tif (event=50)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1779 km2
#     Total flooded volume (sum of 5km cells): 552079.81 m3
# [51/194] Processing res_33_b_2022_51_Ens04_binary_10cm.tif (event=51)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.3128 km2
#     Total flooded volume (sum of 5km cells): 1423466.25 m3
# [52/194] Processing res_33_b_2023_52_Ens04_binary_10cm.tif (event=52)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.6712 km2
#     Total flooded volume (sum of 5km cells): 788610.62 m3
# [53/194] Processing res_33_b_2025_53_Ens04_binary_10cm.tif (event=53)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.9416 km2
#     Total flooded volume (sum of 5km cells): 3155164.25 m3
# [54/194] Processing res_33_b_2025_54_Ens04_binary_10cm.tif (event=54)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.4336 km2
#     Total flooded volume (sum of 5km cells): 591268.44 m3
# [55/194] Processing res_33_b_2025_55_Ens04_binary_10cm.tif (event=55)
# Skippping QA
#     Total flooded area (sum of 5km cells): 42.0426 km2
#     Total flooded volume (sum of 5km cells): 9556757.00 m3
# [56/194] Processing res_33_b_2027_56_Ens04_binary_10cm.tif (event=56)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.3740 km2
#     Total flooded volume (sum of 5km cells): 1095204.62 m3
# [57/194] Processing res_33_b_2027_57_Ens04_binary_10cm.tif (event=57)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5751 km2
#     Total flooded volume (sum of 5km cells): 165042.00 m3
# [58/194] Processing res_33_b_2028_58_Ens04_binary_10cm.tif (event=58)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2465 km2
#     Total flooded volume (sum of 5km cells): 298725.31 m3
# [59/194] Processing res_33_b_2029_59_Ens04_binary_10cm.tif (event=59)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.2996 km2
#     Total flooded volume (sum of 5km cells): 3555736.25 m3
# [60/194] Processing res_33_b_2029_60_Ens04_binary_10cm.tif (event=60)
# Skippping QA
#     Total flooded area (sum of 5km cells): 38.5929 km2
#     Total flooded volume (sum of 5km cells): 9181898.00 m3
# [61/194] Processing res_33_b_2029_61_Ens04_binary_10cm.tif (event=61)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.4021 km2
#     Total flooded volume (sum of 5km cells): 2388832.25 m3
# [62/194] Processing res_33_b_2030_62_Ens04_binary_10cm.tif (event=62)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.4274 km2
#     Total flooded volume (sum of 5km cells): 3725724.75 m3
# [63/194] Processing res_33_b_2031_63_Ens04_binary_10cm.tif (event=63)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.4284 km2
#     Total flooded volume (sum of 5km cells): 3058105.50 m3
# [64/194] Processing res_33_b_2033_64_Ens04_binary_10cm.tif (event=64)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.3262 km2
#     Total flooded volume (sum of 5km cells): 1407749.50 m3
# [65/194] Processing res_33_b_2033_65_Ens04_binary_10cm.tif (event=65)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.2094 km2
#     Total flooded volume (sum of 5km cells): 3282859.00 m3
# [66/194] Processing res_33_b_2033_66_Ens04_binary_10cm.tif (event=66)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.4243 km2
#     Total flooded volume (sum of 5km cells): 1227448.75 m3
# [67/194] Processing res_33_b_2034_67_Ens04_binary_10cm.tif (event=67)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.5308 km2
#     Total flooded volume (sum of 5km cells): 3742786.50 m3
# [68/194] Processing res_33_b_2035_68_Ens04_binary_10cm.tif (event=68)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.6614 km2
#     Total flooded volume (sum of 5km cells): 2251562.25 m3
# [69/194] Processing res_33_b_2035_69_Ens04_binary_10cm.tif (event=69)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.9612 km2
#     Total flooded volume (sum of 5km cells): 2339573.25 m3
# [70/194] Processing res_33_b_2036_70_Ens04_binary_10cm.tif (event=70)
# Skippping QA
#     Total flooded area (sum of 5km cells): 37.5489 km2
#     Total flooded volume (sum of 5km cells): 7355732.50 m3
# [71/194] Processing res_33_b_2036_71_Ens04_binary_10cm.tif (event=71)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.7406 km2
#     Total flooded volume (sum of 5km cells): 2621254.50 m3
# [72/194] Processing res_33_b_2036_72_Ens04_binary_10cm.tif (event=72)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.8385 km2
#     Total flooded volume (sum of 5km cells): 2905834.50 m3
# [73/194] Processing res_33_b_2036_73_Ens04_binary_10cm.tif (event=73)
# Skippping QA
#     Total flooded area (sum of 5km cells): 52.8552 km2
#     Total flooded volume (sum of 5km cells): 15724116.00 m3
# [74/194] Processing res_33_b_2037_74_Ens04_binary_10cm.tif (event=74)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3375 km2
#     Total flooded volume (sum of 5km cells): 72178.20 m3
# [75/194] Processing res_33_b_2037_75_Ens04_binary_10cm.tif (event=75)
# Skippping QA
#     Total flooded area (sum of 5km cells): 20.5911 km2
#     Total flooded volume (sum of 5km cells): 5026304.00 m3
# [76/194] Processing res_33_b_2038_76_Ens04_binary_10cm.tif (event=76)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9468 km2
#     Total flooded volume (sum of 5km cells): 219455.11 m3
# [77/194] Processing res_33_b_2038_77_Ens04_binary_10cm.tif (event=77)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.4956 km2
#     Total flooded volume (sum of 5km cells): 854031.50 m3
# [78/194] Processing res_33_b_2039_78_Ens04_binary_10cm.tif (event=78)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6020 km2
#     Total flooded volume (sum of 5km cells): 293615.12 m3
# [79/194] Processing res_33_b_2039_79_Ens04_binary_10cm.tif (event=79)
# Skippping QA
#     Total flooded area (sum of 5km cells): 47.7711 km2
#     Total flooded volume (sum of 5km cells): 14651640.00 m3
# [80/194] Processing res_33_b_2039_80_Ens04_binary_10cm.tif (event=80)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7252 km2
#     Total flooded volume (sum of 5km cells): 455727.62 m3
# [81/194] Processing res_33_b_2040_81_Ens04_binary_10cm.tif (event=81)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0187 km2
#     Total flooded volume (sum of 5km cells): 374372.12 m3
# [82/194] Processing res_33_b_2040_82_Ens04_binary_10cm.tif (event=82)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.8456 km2
#     Total flooded volume (sum of 5km cells): 3500568.75 m3
# [83/194] Processing res_33_b_2041_83_Ens04_binary_10cm.tif (event=83)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.4746 km2
#     Total flooded volume (sum of 5km cells): 1845022.50 m3
# [84/194] Processing res_33_b_2041_84_Ens04_binary_10cm.tif (event=84)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.6847 km2
#     Total flooded volume (sum of 5km cells): 536714.06 m3
# [85/194] Processing res_33_b_2041_85_Ens04_binary_10cm.tif (event=85)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.2274 km2
#     Total flooded volume (sum of 5km cells): 3337734.50 m3
# [86/194] Processing res_33_b_2041_86_Ens04_binary_10cm.tif (event=86)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6893 km2
#     Total flooded volume (sum of 5km cells): 527078.69 m3
# [87/194] Processing res_33_b_2042_87_Ens04_binary_10cm.tif (event=87)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7137 km2
#     Total flooded volume (sum of 5km cells): 115053.30 m3
# [88/194] Processing res_33_b_2043_88_Ens04_binary_10cm.tif (event=88)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.5375 km2
#     Total flooded volume (sum of 5km cells): 1904280.12 m3
# [89/194] Processing res_33_b_2043_89_Ens04_binary_10cm.tif (event=89)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.2001 km2
#     Total flooded volume (sum of 5km cells): 1830835.75 m3
# [90/194] Processing res_33_b_2043_90_Ens04_binary_10cm.tif (event=90)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.4645 km2
#     Total flooded volume (sum of 5km cells): 2002679.12 m3
# [91/194] Processing res_33_b_2043_91_Ens04_binary_10cm.tif (event=91)
# Skippping QA
#     Total flooded area (sum of 5km cells): 42.8310 km2
#     Total flooded volume (sum of 5km cells): 9517648.00 m3
# [92/194] Processing res_33_b_2043_92_Ens04_binary_10cm.tif (event=92)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2410 km2
#     Total flooded volume (sum of 5km cells): 596133.81 m3
# [93/194] Processing res_33_b_2043_93_Ens04_binary_10cm.tif (event=93)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.3782 km2
#     Total flooded volume (sum of 5km cells): 1493982.00 m3
# [94/194] Processing res_33_b_2044_94_Ens04_binary_10cm.tif (event=94)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.3478 km2
#     Total flooded volume (sum of 5km cells): 2683458.25 m3
# [95/194] Processing res_33_b_2044_95_Ens04_binary_10cm.tif (event=95)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.5548 km2
#     Total flooded volume (sum of 5km cells): 1284004.88 m3
# [96/194] Processing res_33_b_2044_96_Ens04_binary_10cm.tif (event=96)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1393 km2
#     Total flooded volume (sum of 5km cells): 490298.34 m3
# [97/194] Processing res_33_b_2044_97_Ens04_binary_10cm.tif (event=97)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.3985 km2
#     Total flooded volume (sum of 5km cells): 760758.38 m3
# [98/194] Processing res_33_b_2045_98_Ens04_binary_10cm.tif (event=98)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.6241 km2
#     Total flooded volume (sum of 5km cells): 2913930.00 m3
# [99/194] Processing res_33_b_2045_99_Ens04_binary_10cm.tif (event=99)
# Skippping QA
#     Total flooded area (sum of 5km cells): 34.2396 km2
#     Total flooded volume (sum of 5km cells): 8474780.00 m3
# [100/194] Processing res_33_b_2045_100_Ens04_binary_10cm.tif (event=100)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3986 km2
#     Total flooded volume (sum of 5km cells): 259907.38 m3
# [101/194] Processing res_33_b_2046_101_Ens04_binary_10cm.tif (event=101)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.1710 km2
#     Total flooded volume (sum of 5km cells): 2098097.00 m3
# [102/194] Processing res_33_b_2046_102_Ens04_binary_10cm.tif (event=102)
# Skippping QA
#     Total flooded area (sum of 5km cells): 18.5760 km2
#     Total flooded volume (sum of 5km cells): 4451517.00 m3
# [103/194] Processing res_33_b_2046_103_Ens04_binary_10cm.tif (event=103)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.0140 km2
#     Total flooded volume (sum of 5km cells): 804139.19 m3
# [104/194] Processing res_33_b_2046_104_Ens04_binary_10cm.tif (event=104)
# Skippping QA
#     Total flooded area (sum of 5km cells): 48.2058 km2
#     Total flooded volume (sum of 5km cells): 11014275.00 m3
# [105/194] Processing res_33_b_2046_105_Ens04_binary_10cm.tif (event=105)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8937 km2
#     Total flooded volume (sum of 5km cells): 254542.50 m3
# [106/194] Processing res_33_b_2046_106_Ens04_binary_10cm.tif (event=106)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1302 km2
#     Total flooded volume (sum of 5km cells): 642030.31 m3
# [107/194] Processing res_33_b_2047_107_Ens04_binary_10cm.tif (event=107)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1511 km2
#     Total flooded volume (sum of 5km cells): 255068.09 m3
# [108/194] Processing res_33_b_2048_108_Ens04_binary_10cm.tif (event=108)
# Skippping QA
#     Total flooded area (sum of 5km cells): 28.1592 km2
#     Total flooded volume (sum of 5km cells): 8586596.00 m3
# [109/194] Processing res_33_b_2048_109_Ens04_binary_10cm.tif (event=109)
# Skippping QA
#     Total flooded area (sum of 5km cells): 27.6390 km2
#     Total flooded volume (sum of 5km cells): 6328859.50 m3
# [110/194] Processing res_33_b_2049_110_Ens04_binary_10cm.tif (event=110)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.7955 km2
#     Total flooded volume (sum of 5km cells): 4137324.25 m3
# [111/194] Processing res_33_b_2049_111_Ens04_binary_10cm.tif (event=111)
# Skippping QA
#     Total flooded area (sum of 5km cells): 16.1469 km2
#     Total flooded volume (sum of 5km cells): 3481500.50 m3
# [112/194] Processing res_33_b_2049_112_Ens04_binary_10cm.tif (event=112)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.2472 km2
#     Total flooded volume (sum of 5km cells): 1170108.00 m3
# [113/194] Processing res_33_b_2049_113_Ens04_binary_10cm.tif (event=113)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6900 km2
#     Total flooded volume (sum of 5km cells): 618866.06 m3
# [114/194] Processing res_33_b_2050_114_Ens04_binary_10cm.tif (event=114)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.0837 km2
#     Total flooded volume (sum of 5km cells): 2273025.75 m3
# [115/194] Processing res_33_b_2050_115_Ens04_binary_10cm.tif (event=115)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.8353 km2
#     Total flooded volume (sum of 5km cells): 1940275.88 m3
# [116/194] Processing res_33_b_2050_116_Ens04_binary_10cm.tif (event=116)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.6404 km2
#     Total flooded volume (sum of 5km cells): 1144693.75 m3
# [117/194] Processing res_33_b_2051_117_Ens04_binary_10cm.tif (event=117)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.7324 km2
#     Total flooded volume (sum of 5km cells): 2766342.50 m3
# [118/194] Processing res_33_b_2051_118_Ens04_binary_10cm.tif (event=118)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.1722 km2
#     Total flooded volume (sum of 5km cells): 1744446.62 m3
# [119/194] Processing res_33_b_2053_119_Ens04_binary_10cm.tif (event=119)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.5238 km2
#     Total flooded volume (sum of 5km cells): 2996517.50 m3
# [120/194] Processing res_33_b_2053_120_Ens04_binary_10cm.tif (event=120)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.7861 km2
#     Total flooded volume (sum of 5km cells): 1817646.25 m3
# [121/194] Processing res_33_b_2053_121_Ens04_binary_10cm.tif (event=121)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.0323 km2
#     Total flooded volume (sum of 5km cells): 4438089.00 m3
# [122/194] Processing res_33_b_2053_122_Ens04_binary_10cm.tif (event=122)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6297 km2
#     Total flooded volume (sum of 5km cells): 926972.94 m3
# [123/194] Processing res_33_b_2053_123_Ens04_binary_10cm.tif (event=123)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.7603 km2
#     Total flooded volume (sum of 5km cells): 2750670.00 m3
# [124/194] Processing res_33_b_2053_124_Ens04_binary_10cm.tif (event=124)
# Skippping QA
#     Total flooded area (sum of 5km cells): 43.4709 km2
#     Total flooded volume (sum of 5km cells): 11758990.00 m3
# [125/194] Processing res_33_b_2054_125_Ens04_binary_10cm.tif (event=125)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0538 km2
#     Total flooded volume (sum of 5km cells): 511413.31 m3
# [126/194] Processing res_33_b_2055_126_Ens04_binary_10cm.tif (event=126)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.0882 km2
#     Total flooded volume (sum of 5km cells): 1916245.75 m3
# [127/194] Processing res_33_b_2055_127_Ens04_binary_10cm.tif (event=127)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0475 km2
#     Total flooded volume (sum of 5km cells): 382241.69 m3
# [128/194] Processing res_33_b_2055_128_Ens04_binary_10cm.tif (event=128)
# Skippping QA
#     Total flooded area (sum of 5km cells): 54.3348 km2
#     Total flooded volume (sum of 5km cells): 16361855.00 m3
# [129/194] Processing res_33_b_2056_129_Ens04_binary_10cm.tif (event=129)
# Skippping QA
#     Total flooded area (sum of 5km cells): 80.6643 km2
#     Total flooded volume (sum of 5km cells): 19969710.00 m3
# [130/194] Processing res_33_b_2056_130_Ens04_binary_10cm.tif (event=130)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.1058 km2
#     Total flooded volume (sum of 5km cells): 1035396.88 m3
# [131/194] Processing res_33_b_2056_131_Ens04_binary_10cm.tif (event=131)
# Skippping QA
#     Total flooded area (sum of 5km cells): 24.9309 km2
#     Total flooded volume (sum of 5km cells): 9427768.00 m3
# [132/194] Processing res_33_b_2056_132_Ens04_binary_10cm.tif (event=132)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.5232 km2
#     Total flooded volume (sum of 5km cells): 1504738.75 m3
# [133/194] Processing res_33_b_2057_133_Ens04_binary_10cm.tif (event=133)
# Skippping QA
#     Total flooded area (sum of 5km cells): 16.5780 km2
#     Total flooded volume (sum of 5km cells): 4479344.00 m3
# [134/194] Processing res_33_b_2057_134_Ens04_binary_10cm.tif (event=134)
# Skippping QA
#     Total flooded area (sum of 5km cells): 52.1424 km2
#     Total flooded volume (sum of 5km cells): 13934814.00 m3
# [135/194] Processing res_33_b_2057_135_Ens04_binary_10cm.tif (event=135)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.2273 km2
#     Total flooded volume (sum of 5km cells): 1141995.62 m3
# [136/194] Processing res_33_b_2057_136_Ens04_binary_10cm.tif (event=136)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.6204 km2
#     Total flooded volume (sum of 5km cells): 1525253.50 m3
# [137/194] Processing res_33_b_2058_137_Ens04_binary_10cm.tif (event=137)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.2350 km2
#     Total flooded volume (sum of 5km cells): 2141526.50 m3
# [138/194] Processing res_33_b_2060_138_Ens04_binary_10cm.tif (event=138)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.5177 km2
#     Total flooded volume (sum of 5km cells): 1800267.38 m3
# [139/194] Processing res_33_b_2060_139_Ens04_binary_10cm.tif (event=139)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.9294 km2
#     Total flooded volume (sum of 5km cells): 932715.00 m3
# [140/194] Processing res_33_b_2060_140_Ens04_binary_10cm.tif (event=140)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.8443 km2
#     Total flooded volume (sum of 5km cells): 2348715.75 m3
# [141/194] Processing res_33_b_2060_141_Ens04_binary_10cm.tif (event=141)
# Skippping QA
#     Total flooded area (sum of 5km cells): 18.1395 km2
#     Total flooded volume (sum of 5km cells): 4959838.00 m3
# [142/194] Processing res_33_b_2060_142_Ens04_binary_10cm.tif (event=142)
# Skippping QA
#     Total flooded area (sum of 5km cells): 121.1805 km2
#     Total flooded volume (sum of 5km cells): 30213968.00 m3
# [143/194] Processing res_33_b_2060_143_Ens04_binary_10cm.tif (event=143)
# Skippping QA
#     Total flooded area (sum of 5km cells): 85.2489 km2
#     Total flooded volume (sum of 5km cells): 22287406.00 m3
# [144/194] Processing res_33_b_2060_144_Ens04_binary_10cm.tif (event=144)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.8411 km2
#     Total flooded volume (sum of 5km cells): 3809315.00 m3
# [145/194] Processing res_33_b_2060_145_Ens04_binary_10cm.tif (event=145)
# Skippping QA
#     Total flooded area (sum of 5km cells): 103.2516 km2
#     Total flooded volume (sum of 5km cells): 28233608.00 m3
# [146/194] Processing res_33_b_2060_146_Ens04_binary_10cm.tif (event=146)
# Skippping QA
#     Total flooded area (sum of 5km cells): 68.0211 km2
#     Total flooded volume (sum of 5km cells): 17641408.00 m3
# [147/194] Processing res_33_b_2060_147_Ens04_binary_10cm.tif (event=147)
# Skippping QA
#     Total flooded area (sum of 5km cells): 89.7534 km2
#     Total flooded volume (sum of 5km cells): 25730420.00 m3
# [148/194] Processing res_33_b_2061_148_Ens04_binary_10cm.tif (event=148)
# Skippping QA
#     Total flooded area (sum of 5km cells): 14.4000 km2
#     Total flooded volume (sum of 5km cells): 3689659.50 m3
# [149/194] Processing res_33_b_2061_149_Ens04_binary_10cm.tif (event=149)
# Skippping QA
#     Total flooded area (sum of 5km cells): 206.6031 km2
#     Total flooded volume (sum of 5km cells): 51439512.00 m3
# [150/194] Processing res_33_b_2062_150_Ens04_binary_10cm.tif (event=150)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5840 km2
#     Total flooded volume (sum of 5km cells): 455249.69 m3
# [151/194] Processing res_33_b_2062_151_Ens04_binary_10cm.tif (event=151)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.5313 km2
#     Total flooded volume (sum of 5km cells): 1397795.50 m3
# [152/194] Processing res_33_b_2063_152_Ens04_binary_10cm.tif (event=152)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.0538 km2
#     Total flooded volume (sum of 5km cells): 3578193.50 m3
# [153/194] Processing res_33_b_2063_153_Ens04_binary_10cm.tif (event=153)
# Skippping QA
#     Total flooded area (sum of 5km cells): 13.6674 km2
#     Total flooded volume (sum of 5km cells): 2531866.50 m3
# [154/194] Processing res_33_b_2066_154_Ens04_binary_10cm.tif (event=154)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.0326 km2
#     Total flooded volume (sum of 5km cells): 1650172.50 m3
# [155/194] Processing res_33_b_2067_155_Ens04_binary_10cm.tif (event=155)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.5168 km2
#     Total flooded volume (sum of 5km cells): 1360775.62 m3
# [156/194] Processing res_33_b_2067_156_Ens04_binary_10cm.tif (event=156)
# Skippping QA
#     Total flooded area (sum of 5km cells): 21.9393 km2
#     Total flooded volume (sum of 5km cells): 5897965.00 m3
# [157/194] Processing res_33_b_2067_157_Ens04_binary_10cm.tif (event=157)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.1019 km2
#     Total flooded volume (sum of 5km cells): 2336050.75 m3
# [158/194] Processing res_33_b_2067_158_Ens04_binary_10cm.tif (event=158)
# Skippping QA
#     Total flooded area (sum of 5km cells): 18.2295 km2
#     Total flooded volume (sum of 5km cells): 4799813.00 m3
# [159/194] Processing res_33_b_2068_159_Ens04_binary_10cm.tif (event=159)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.7979 km2
#     Total flooded volume (sum of 5km cells): 1225503.00 m3
# [160/194] Processing res_33_b_2070_160_Ens04_binary_10cm.tif (event=160)
# Skippping QA
#     Total flooded area (sum of 5km cells): 53.9604 km2
#     Total flooded volume (sum of 5km cells): 12400998.00 m3
# [161/194] Processing res_33_b_2070_161_Ens04_binary_10cm.tif (event=161)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7153 km2
#     Total flooded volume (sum of 5km cells): 606114.00 m3
# [162/194] Processing res_33_b_2071_162_Ens04_binary_10cm.tif (event=162)
# Skippping QA
#     Total flooded area (sum of 5km cells): 22.3632 km2
#     Total flooded volume (sum of 5km cells): 6875176.00 m3
# [163/194] Processing res_33_b_2071_163_Ens04_binary_10cm.tif (event=163)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.9321 km2
#     Total flooded volume (sum of 5km cells): 2933336.50 m3
# [164/194] Processing res_33_b_2072_164_Ens04_binary_10cm.tif (event=164)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.8099 km2
#     Total flooded volume (sum of 5km cells): 381480.28 m3
# [165/194] Processing res_33_b_2072_165_Ens04_binary_10cm.tif (event=165)
# Skippping QA
#     Total flooded area (sum of 5km cells): 22.8213 km2
#     Total flooded volume (sum of 5km cells): 5093339.50 m3
# [166/194] Processing res_33_b_2072_166_Ens04_binary_10cm.tif (event=166)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.8200 km2
#     Total flooded volume (sum of 5km cells): 2309676.00 m3
# [167/194] Processing res_33_b_2072_167_Ens04_binary_10cm.tif (event=167)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.9839 km2
#     Total flooded volume (sum of 5km cells): 1742473.88 m3
# [168/194] Processing res_33_b_2072_168_Ens04_binary_10cm.tif (event=168)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.4560 km2
#     Total flooded volume (sum of 5km cells): 795585.62 m3
# [169/194] Processing res_33_b_2073_169_Ens04_binary_10cm.tif (event=169)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6425 km2
#     Total flooded volume (sum of 5km cells): 289019.69 m3
# [170/194] Processing res_33_b_2073_170_Ens04_binary_10cm.tif (event=170)
# Skippping QA
#     Total flooded area (sum of 5km cells): 16.9767 km2
#     Total flooded volume (sum of 5km cells): 4710656.50 m3
# [171/194] Processing res_33_b_2075_171_Ens04_binary_10cm.tif (event=171)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.3208 km2
#     Total flooded volume (sum of 5km cells): 1275912.12 m3
# [172/194] Processing res_33_b_2075_172_Ens04_binary_10cm.tif (event=172)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.4214 km2
#     Total flooded volume (sum of 5km cells): 1902083.25 m3
# [173/194] Processing res_33_b_2075_173_Ens04_binary_10cm.tif (event=173)
# Skippping QA
#     Total flooded area (sum of 5km cells): 29.0799 km2
#     Total flooded volume (sum of 5km cells): 7882297.00 m3
# [174/194] Processing res_33_b_2075_174_Ens04_binary_10cm.tif (event=174)
# Skippping QA
#     Total flooded area (sum of 5km cells): 25.9263 km2
#     Total flooded volume (sum of 5km cells): 6637411.00 m3
# [175/194] Processing res_33_b_2076_175_Ens04_binary_10cm.tif (event=175)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.7928 km2
#     Total flooded volume (sum of 5km cells): 2574020.50 m3
# [176/194] Processing res_33_b_2076_176_Ens04_binary_10cm.tif (event=176)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.9620 km2
#     Total flooded volume (sum of 5km cells): 2204126.00 m3
# [177/194] Processing res_33_b_2076_177_Ens04_binary_10cm.tif (event=177)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.1935 km2
#     Total flooded volume (sum of 5km cells): 2464961.25 m3
# [178/194] Processing res_33_b_2076_178_Ens04_binary_10cm.tif (event=178)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4787 km2
#     Total flooded volume (sum of 5km cells): 252340.20 m3
# [179/194] Processing res_33_b_2076_179_Ens04_binary_10cm.tif (event=179)
# Skippping QA
#     Total flooded area (sum of 5km cells): 32.4576 km2
#     Total flooded volume (sum of 5km cells): 8193003.50 m3
# [180/194] Processing res_33_b_2077_180_Ens04_binary_10cm.tif (event=180)
# Skippping QA
#     Total flooded area (sum of 5km cells): 25.3800 km2
#     Total flooded volume (sum of 5km cells): 6301358.50 m3
# [181/194] Processing res_33_b_2077_181_Ens04_binary_10cm.tif (event=181)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.6727 km2
#     Total flooded volume (sum of 5km cells): 1412167.50 m3
# [182/194] Processing res_33_b_2077_182_Ens04_binary_10cm.tif (event=182)
# Skippping QA
#     Total flooded area (sum of 5km cells): 27.3213 km2
#     Total flooded volume (sum of 5km cells): 7500017.50 m3
# [183/194] Processing res_33_b_2077_183_Ens04_binary_10cm.tif (event=183)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.6611 km2
#     Total flooded volume (sum of 5km cells): 1062209.62 m3
# [184/194] Processing res_33_b_2077_184_Ens04_binary_10cm.tif (event=184)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1851 km2
#     Total flooded volume (sum of 5km cells): 598630.50 m3
# [185/194] Processing res_33_b_2078_185_Ens04_binary_10cm.tif (event=185)
# Skippping QA
#     Total flooded area (sum of 5km cells): 19.6110 km2
#     Total flooded volume (sum of 5km cells): 4727991.50 m3
# [186/194] Processing res_33_b_2078_186_Ens04_binary_10cm.tif (event=186)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.2041 km2
#     Total flooded volume (sum of 5km cells): 2850739.00 m3
# [187/194] Processing res_33_b_2079_187_Ens04_binary_10cm.tif (event=187)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.9929 km2
#     Total flooded volume (sum of 5km cells): 1977817.50 m3
# [188/194] Processing res_33_b_2079_188_Ens04_binary_10cm.tif (event=188)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.4458 km2
#     Total flooded volume (sum of 5km cells): 1223221.50 m3
# [189/194] Processing res_33_b_2079_189_Ens04_binary_10cm.tif (event=189)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.3829 km2
#     Total flooded volume (sum of 5km cells): 980979.38 m3
# [190/194] Processing res_33_b_2079_190_Ens04_binary_10cm.tif (event=190)
# Skippping QA
#     Total flooded area (sum of 5km cells): 55.7028 km2
#     Total flooded volume (sum of 5km cells): 14015546.00 m3
# [191/194] Processing res_33_b_2080_191_Ens04_binary_10cm.tif (event=191)
# Skippping QA
#     Total flooded area (sum of 5km cells): 39.4740 km2
#     Total flooded volume (sum of 5km cells): 10264087.00 m3
# [192/194] Processing res_33_b_2080_192_Ens04_binary_10cm.tif (event=192)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.3501 km2
#     Total flooded volume (sum of 5km cells): 2233909.00 m3
# [193/194] Processing res_33_b_2080_193_Ens04_binary_10cm.tif (event=193)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.9960 km2
#     Total flooded volume (sum of 5km cells): 935890.19 m3
# [194/194] Processing res_33_b_2080_194_Ens04_binary_10cm.tif (event=194)
# Skippping QA
#     Total flooded area (sum of 5km cells): 65.6217 km2
#     Total flooded volume (sum of 5km cells): 15856008.00 m3
# Saving area to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/10cm/flooded_area_5km_total_Ens04_33_b_10cm.nc...
# Done! Saved 194 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/10cm/flooded_area_5km_total_Ens04_33_b_10cm.nc
# Saving volume to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/10cm/flooded_volume_5km_total_Ens04_33_b_10cm.nc...
# Done! Saved 194 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/10cm/flooded_volume_5km_total_Ens04_33_b_10cm.nc
#
# [Ens04_33_b | 30cm] Processing 194 events
# [1/194] Processing res_33_b_1995_1_Ens04_binary_30cm.tif (event=1)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1584 km2
#     Total flooded volume (sum of 5km cells): 76024.80 m3
# [2/194] Processing res_33_b_1995_2_Ens04_binary_30cm.tif (event=2)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0585 km2
#     Total flooded volume (sum of 5km cells): 29277.90 m3
# [3/194] Processing res_33_b_1998_3_Ens04_binary_30cm.tif (event=3)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3411 km2
#     Total flooded volume (sum of 5km cells): 160586.98 m3
# [4/194] Processing res_33_b_1999_4_Ens04_binary_30cm.tif (event=4)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8082 km2
#     Total flooded volume (sum of 5km cells): 501862.50 m3
# [5/194] Processing res_33_b_1999_5_Ens04_binary_30cm.tif (event=5)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8595 km2
#     Total flooded volume (sum of 5km cells): 482751.88 m3
# [6/194] Processing res_33_b_2000_6_Ens04_binary_30cm.tif (event=6)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.4107 km2
#     Total flooded volume (sum of 5km cells): 3730944.75 m3
# [7/194] Processing res_33_b_2000_7_Ens04_binary_30cm.tif (event=7)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6696 km2
#     Total flooded volume (sum of 5km cells): 375328.81 m3
# [8/194] Processing res_33_b_2000_8_Ens04_binary_30cm.tif (event=8)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2430 km2
#     Total flooded volume (sum of 5km cells): 170137.80 m3
# [9/194] Processing res_33_b_2001_9_Ens04_binary_30cm.tif (event=9)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0269 km2
#     Total flooded volume (sum of 5km cells): 557935.25 m3
# [10/194] Processing res_33_b_2001_10_Ens04_binary_30cm.tif (event=10)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5895 km2
#     Total flooded volume (sum of 5km cells): 319024.81 m3
# [11/194] Processing res_33_b_2001_11_Ens04_binary_30cm.tif (event=11)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8082 km2
#     Total flooded volume (sum of 5km cells): 460785.56 m3
# [12/194] Processing res_33_b_2002_12_Ens04_binary_30cm.tif (event=12)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2041 km2
#     Total flooded volume (sum of 5km cells): 1322720.12 m3
# [13/194] Processing res_33_b_2002_13_Ens04_binary_30cm.tif (event=13)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9099 km2
#     Total flooded volume (sum of 5km cells): 551686.56 m3
# [14/194] Processing res_33_b_2003_14_Ens04_binary_30cm.tif (event=14)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7983 km2
#     Total flooded volume (sum of 5km cells): 358164.91 m3
# [15/194] Processing res_33_b_2003_15_Ens04_binary_30cm.tif (event=15)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2844 km2
#     Total flooded volume (sum of 5km cells): 130353.30 m3
# [16/194] Processing res_33_b_2004_16_Ens04_binary_30cm.tif (event=16)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7200 km2
#     Total flooded volume (sum of 5km cells): 403305.28 m3
# [17/194] Processing res_33_b_2004_17_Ens04_binary_30cm.tif (event=17)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2403 km2
#     Total flooded volume (sum of 5km cells): 124198.19 m3
# [18/194] Processing res_33_b_2004_18_Ens04_binary_30cm.tif (event=18)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.5218 km2
#     Total flooded volume (sum of 5km cells): 1513373.50 m3
# [19/194] Processing res_33_b_2006_19_Ens04_binary_30cm.tif (event=19)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5733 km2
#     Total flooded volume (sum of 5km cells): 302196.62 m3
# [20/194] Processing res_33_b_2006_20_Ens04_binary_30cm.tif (event=20)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6299 km2
#     Total flooded volume (sum of 5km cells): 923135.44 m3
# [21/194] Processing res_33_b_2006_21_Ens04_binary_30cm.tif (event=21)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8460 km2
#     Total flooded volume (sum of 5km cells): 446053.53 m3
# [22/194] Processing res_33_b_2006_22_Ens04_binary_30cm.tif (event=22)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2582 km2
#     Total flooded volume (sum of 5km cells): 797744.69 m3
# [23/194] Processing res_33_b_2007_23_Ens04_binary_30cm.tif (event=23)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4076 km2
#     Total flooded volume (sum of 5km cells): 822734.00 m3
# [24/194] Processing res_33_b_2007_24_Ens04_binary_30cm.tif (event=24)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0340 km2
#     Total flooded volume (sum of 5km cells): 1116027.88 m3
# [25/194] Processing res_33_b_2008_25_Ens04_binary_30cm.tif (event=25)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0981 km2
#     Total flooded volume (sum of 5km cells): 44637.30 m3
# [26/194] Processing res_33_b_2008_26_Ens04_binary_30cm.tif (event=26)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6929 km2
#     Total flooded volume (sum of 5km cells): 937946.69 m3
# [27/194] Processing res_33_b_2010_27_Ens04_binary_30cm.tif (event=27)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0341 km2
#     Total flooded volume (sum of 5km cells): 522023.41 m3
# [28/194] Processing res_33_b_2010_28_Ens04_binary_30cm.tif (event=28)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0224 km2
#     Total flooded volume (sum of 5km cells): 453958.19 m3
# [29/194] Processing res_33_b_2011_29_Ens04_binary_30cm.tif (event=29)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.3483 km2
#     Total flooded volume (sum of 5km cells): 4570027.50 m3
# [30/194] Processing res_33_b_2012_30_Ens04_binary_30cm.tif (event=30)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3276 km2
#     Total flooded volume (sum of 5km cells): 204577.20 m3
# [31/194] Processing res_33_b_2012_31_Ens04_binary_30cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2745 km2
#     Total flooded volume (sum of 5km cells): 127330.20 m3
# [32/194] Processing res_33_b_2013_32_Ens04_binary_30cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1350 km2
#     Total flooded volume (sum of 5km cells): 64659.60 m3
# [33/194] Processing res_33_b_2014_33_Ens04_binary_30cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1620 km2
#     Total flooded volume (sum of 5km cells): 71566.20 m3
# [34/194] Processing res_33_b_2014_34_Ens04_binary_30cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0701 km2
#     Total flooded volume (sum of 5km cells): 610581.62 m3
# [35/194] Processing res_33_b_2017_35_Ens04_binary_30cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0323 km2
#     Total flooded volume (sum of 5km cells): 583043.38 m3
# [36/194] Processing res_33_b_2017_36_Ens04_binary_30cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0980 km2
#     Total flooded volume (sum of 5km cells): 664746.31 m3
# [37/194] Processing res_33_b_2018_37_Ens04_binary_30cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9989 km2
#     Total flooded volume (sum of 5km cells): 1261792.75 m3
# [38/194] Processing res_33_b_2018_38_Ens04_binary_30cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1206 km2
#     Total flooded volume (sum of 5km cells): 56268.00 m3
# [39/194] Processing res_33_b_2018_39_Ens04_binary_30cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3303 km2
#     Total flooded volume (sum of 5km cells): 153967.52 m3
# [40/194] Processing res_33_b_2018_40_Ens04_binary_30cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0171 km2
#     Total flooded volume (sum of 5km cells): 9655.20 m3
# [41/194] Processing res_33_b_2018_41_Ens04_binary_30cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.0294 km2
#     Total flooded volume (sum of 5km cells): 1805247.00 m3
# ...
#     Total flooded volume (sum of 5km cells): 6238652.00 m3
# [132/194] Processing res_33_b_2056_132_Ens04_binary_30cm.tif (event=132)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9621 km2
#     Total flooded volume (sum of 5km cells): 461515.50 m3
# [133/194] Processing res_33_b_2057_133_Ens04_binary_30cm.tif (event=133)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6477 km2
#     Total flooded volume (sum of 5km cells): 1950363.00 m3
# [134/194] Processing res_33_b_2057_134_Ens04_binary_30cm.tif (event=134)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.3266 km2
#     Total flooded volume (sum of 5km cells): 5950895.00 m3
# [135/194] Processing res_33_b_2057_135_Ens04_binary_30cm.tif (event=135)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7245 km2
#     Total flooded volume (sum of 5km cells): 451795.47 m3
# [136/194] Processing res_33_b_2057_136_Ens04_binary_30cm.tif (event=136)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7533 km2
#     Total flooded volume (sum of 5km cells): 417305.69 m3
# [137/194] Processing res_33_b_2058_137_Ens04_binary_30cm.tif (event=137)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5534 km2
#     Total flooded volume (sum of 5km cells): 912088.88 m3
# [138/194] Processing res_33_b_2060_138_Ens04_binary_30cm.tif (event=138)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3248 km2
#     Total flooded volume (sum of 5km cells): 677946.56 m3
# [139/194] Processing res_33_b_2060_139_Ens04_binary_30cm.tif (event=139)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5355 km2
#     Total flooded volume (sum of 5km cells): 300132.91 m3
# [140/194] Processing res_33_b_2060_140_Ens04_binary_30cm.tif (event=140)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9116 km2
#     Total flooded volume (sum of 5km cells): 1002510.88 m3
# [141/194] Processing res_33_b_2060_141_Ens04_binary_30cm.tif (event=141)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.7404 km2
#     Total flooded volume (sum of 5km cells): 2103878.00 m3
# [142/194] Processing res_33_b_2060_142_Ens04_binary_30cm.tif (event=142)
# Skippping QA
#     Total flooded area (sum of 5km cells): 20.6064 km2
#     Total flooded volume (sum of 5km cells): 11852490.00 m3
# [143/194] Processing res_33_b_2060_143_Ens04_binary_30cm.tif (event=143)
# Skippping QA
#     Total flooded area (sum of 5km cells): 16.7931 km2
#     Total flooded volume (sum of 5km cells): 9487297.00 m3
# [144/194] Processing res_33_b_2060_144_Ens04_binary_30cm.tif (event=144)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.8116 km2
#     Total flooded volume (sum of 5km cells): 1667254.50 m3
# [145/194] Processing res_33_b_2060_145_Ens04_binary_30cm.tif (event=145)
# Skippping QA
#     Total flooded area (sum of 5km cells): 22.7583 km2
#     Total flooded volume (sum of 5km cells): 13114671.00 m3
# [146/194] Processing res_33_b_2060_146_Ens04_binary_30cm.tif (event=146)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.8773 km2
#     Total flooded volume (sum of 5km cells): 7183906.00 m3
# [147/194] Processing res_33_b_2060_147_Ens04_binary_30cm.tif (event=147)
# Skippping QA
#     Total flooded area (sum of 5km cells): 20.7297 km2
#     Total flooded volume (sum of 5km cells): 12726261.00 m3
# [148/194] Processing res_33_b_2061_148_Ens04_binary_30cm.tif (event=148)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.3670 km2
#     Total flooded volume (sum of 5km cells): 1321599.50 m3
# [149/194] Processing res_33_b_2061_149_Ens04_binary_30cm.tif (event=149)
# Skippping QA
#     Total flooded area (sum of 5km cells): 37.1763 km2
#     Total flooded volume (sum of 5km cells): 20060186.00 m3
# [150/194] Processing res_33_b_2062_150_Ens04_binary_30cm.tif (event=150)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3627 km2
#     Total flooded volume (sum of 5km cells): 223497.91 m3
# [151/194] Processing res_33_b_2062_151_Ens04_binary_30cm.tif (event=151)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7569 km2
#     Total flooded volume (sum of 5km cells): 356292.91 m3
# [152/194] Processing res_33_b_2063_152_Ens04_binary_30cm.tif (event=152)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1842 km2
#     Total flooded volume (sum of 5km cells): 2031137.00 m3
# [153/194] Processing res_33_b_2063_153_Ens04_binary_30cm.tif (event=153)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6741 km2
#     Total flooded volume (sum of 5km cells): 313474.50 m3
# [154/194] Processing res_33_b_2066_154_Ens04_binary_30cm.tif (event=154)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9477 km2
#     Total flooded volume (sum of 5km cells): 524394.94 m3
# [155/194] Processing res_33_b_2067_155_Ens04_binary_30cm.tif (event=155)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3609 km2
#     Total flooded volume (sum of 5km cells): 173485.80 m3
# [156/194] Processing res_33_b_2067_156_Ens04_binary_30cm.tif (event=156)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4883 km2
#     Total flooded volume (sum of 5km cells): 2515249.50 m3
# [157/194] Processing res_33_b_2067_157_Ens04_binary_30cm.tif (event=157)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.2023 km2
#     Total flooded volume (sum of 5km cells): 1368494.12 m3
# [158/194] Processing res_33_b_2067_158_Ens04_binary_30cm.tif (event=158)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.1941 km2
#     Total flooded volume (sum of 5km cells): 1923608.62 m3
# [159/194] Processing res_33_b_2068_159_Ens04_binary_30cm.tif (event=159)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7101 km2
#     Total flooded volume (sum of 5km cells): 421272.88 m3
# [160/194] Processing res_33_b_2070_160_Ens04_binary_30cm.tif (event=160)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.3359 km2
#     Total flooded volume (sum of 5km cells): 3778875.00 m3
# [161/194] Processing res_33_b_2070_161_Ens04_binary_30cm.tif (event=161)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3159 km2
#     Total flooded volume (sum of 5km cells): 164680.22 m3
# [162/194] Processing res_33_b_2071_162_Ens04_binary_30cm.tif (event=162)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.8185 km2
#     Total flooded volume (sum of 5km cells): 3628561.50 m3
# [163/194] Processing res_33_b_2071_163_Ens04_binary_30cm.tif (event=163)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5714 km2
#     Total flooded volume (sum of 5km cells): 834754.50 m3
# [164/194] Processing res_33_b_2072_164_Ens04_binary_30cm.tif (event=164)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1791 km2
#     Total flooded volume (sum of 5km cells): 96500.70 m3
# [165/194] Processing res_33_b_2072_165_Ens04_binary_30cm.tif (event=165)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7387 km2
#     Total flooded volume (sum of 5km cells): 1394268.25 m3
# [166/194] Processing res_33_b_2072_166_Ens04_binary_30cm.tif (event=166)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2897 km2
#     Total flooded volume (sum of 5km cells): 867132.88 m3
# [167/194] Processing res_33_b_2072_167_Ens04_binary_30cm.tif (event=167)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9432 km2
#     Total flooded volume (sum of 5km cells): 472220.12 m3
# [168/194] Processing res_33_b_2072_168_Ens04_binary_30cm.tif (event=168)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4581 km2
#     Total flooded volume (sum of 5km cells): 246191.41 m3
# [169/194] Processing res_33_b_2073_169_Ens04_binary_30cm.tif (event=169)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0450 km2
#     Total flooded volume (sum of 5km cells): 17121.60 m3
# [170/194] Processing res_33_b_2073_170_Ens04_binary_30cm.tif (event=170)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.4965 km2
#     Total flooded volume (sum of 5km cells): 2141473.50 m3
# [171/194] Processing res_33_b_2075_171_Ens04_binary_30cm.tif (event=171)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6741 km2
#     Total flooded volume (sum of 5km cells): 358296.28 m3
# [172/194] Processing res_33_b_2075_172_Ens04_binary_30cm.tif (event=172)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4121 km2
#     Total flooded volume (sum of 5km cells): 774709.19 m3
# [173/194] Processing res_33_b_2075_173_Ens04_binary_30cm.tif (event=173)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.8419 km2
#     Total flooded volume (sum of 5km cells): 3486529.75 m3
# [174/194] Processing res_33_b_2075_174_Ens04_binary_30cm.tif (event=174)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.2281 km2
#     Total flooded volume (sum of 5km cells): 2704210.00 m3
# [175/194] Processing res_33_b_2076_175_Ens04_binary_30cm.tif (event=175)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.8297 km2
#     Total flooded volume (sum of 5km cells): 880394.38 m3
# [176/194] Processing res_33_b_2076_176_Ens04_binary_30cm.tif (event=176)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8820 km2
#     Total flooded volume (sum of 5km cells): 442784.69 m3
# [177/194] Processing res_33_b_2076_177_Ens04_binary_30cm.tif (event=177)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5237 km2
#     Total flooded volume (sum of 5km cells): 1009718.06 m3
# [178/194] Processing res_33_b_2076_178_Ens04_binary_30cm.tif (event=178)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0342 km2
#     Total flooded volume (sum of 5km cells): 14156.10 m3
# [179/194] Processing res_33_b_2076_179_Ens04_binary_30cm.tif (event=179)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.6286 km2
#     Total flooded volume (sum of 5km cells): 3212827.00 m3
# [180/194] Processing res_33_b_2077_180_Ens04_binary_30cm.tif (event=180)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4658 km2
#     Total flooded volume (sum of 5km cells): 2453838.25 m3
# [181/194] Processing res_33_b_2077_181_Ens04_binary_30cm.tif (event=181)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7632 km2
#     Total flooded volume (sum of 5km cells): 453692.69 m3
# [182/194] Processing res_33_b_2077_182_Ens04_binary_30cm.tif (event=182)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.7798 km2
#     Total flooded volume (sum of 5km cells): 3321208.75 m3
# [183/194] Processing res_33_b_2077_183_Ens04_binary_30cm.tif (event=183)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5283 km2
#     Total flooded volume (sum of 5km cells): 262701.00 m3
# [184/194] Processing res_33_b_2077_184_Ens04_binary_30cm.tif (event=184)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1764 km2
#     Total flooded volume (sum of 5km cells): 87289.20 m3
# [185/194] Processing res_33_b_2078_185_Ens04_binary_30cm.tif (event=185)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.7864 km2
#     Total flooded volume (sum of 5km cells): 1646154.00 m3
# [186/194] Processing res_33_b_2078_186_Ens04_binary_30cm.tif (event=186)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6119 km2
#     Total flooded volume (sum of 5km cells): 1055373.38 m3
# [187/194] Processing res_33_b_2079_187_Ens04_binary_30cm.tif (event=187)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2933 km2
#     Total flooded volume (sum of 5km cells): 729748.81 m3
# [188/194] Processing res_33_b_2079_188_Ens04_binary_30cm.tif (event=188)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4419 km2
#     Total flooded volume (sum of 5km cells): 198435.61 m3
# [189/194] Processing res_33_b_2079_189_Ens04_binary_30cm.tif (event=189)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2322 km2
#     Total flooded volume (sum of 5km cells): 98171.10 m3
# [190/194] Processing res_33_b_2079_190_Ens04_binary_30cm.tif (event=190)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.8190 km2
#     Total flooded volume (sum of 5km cells): 5612093.00 m3
# [191/194] Processing res_33_b_2080_191_Ens04_binary_30cm.tif (event=191)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.4232 km2
#     Total flooded volume (sum of 5km cells): 4157787.25 m3
# [192/194] Processing res_33_b_2080_192_Ens04_binary_30cm.tif (event=192)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.5345 km2
#     Total flooded volume (sum of 5km cells): 780055.19 m3
# [193/194] Processing res_33_b_2080_193_Ens04_binary_30cm.tif (event=193)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5580 km2
#     Total flooded volume (sum of 5km cells): 282663.91 m3
# [194/194] Processing res_33_b_2080_194_Ens04_binary_30cm.tif (event=194)
# Skippping QA
#     Total flooded area (sum of 5km cells): 10.7721 km2
#     Total flooded volume (sum of 5km cells): 5687712.00 m3
# Saving area to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/30cm/flooded_area_5km_total_Ens04_33_b_30cm.nc...
# Done! Saved 194 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/30cm/flooded_area_5km_total_Ens04_33_b_30cm.nc
# Saving volume to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/30cm/flooded_volume_5km_total_Ens04_33_b_30cm.nc...
# Done! Saved 194 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens04_33_b/30cm/flooded_volume_5km_total_Ens04_33_b_30cm.nc
#
# ============================================================
# Processing Ens05_33_b: 206 total events
# ============================================================
# [SKIP] Outputs already exist for Ens05_33_b | 10cm
# [SKIP] Outputs already exist for Ens05_33_b | 30cm
#
# ============================================================
# Processing Ens06_33_b: 186 total events
# ============================================================
# [SKIP] Outputs already exist for Ens06_33_b | 10cm
# [SKIP] Outputs already exist for Ens06_33_b | 30cm
#
# ============================================================
# Processing Ens07_33_b: 262 total events
# ============================================================
# [SKIP] Outputs already exist for Ens07_33_b | 10cm
# [SKIP] Outputs already exist for Ens07_33_b | 30cm
#
# ============================================================
# Processing Ens08_33_b: 240 total events
# ============================================================
# [SKIP] Outputs already exist for Ens08_33_b | 10cm
# [SKIP] Outputs already exist for Ens08_33_b | 30cm
#
# ============================================================
# Processing Ens09_33_b: 184 total events
# ============================================================
# [SKIP] Outputs already exist for Ens09_33_b | 10cm
# [SKIP] Outputs already exist for Ens09_33_b | 30cm
#
# ============================================================
# Processing Ens10_33_b: 294 total events
# ============================================================
# [SKIP] Outputs already exist for Ens10_33_b | 10cm
# [SKIP] Outputs already exist for Ens10_33_b | 30cm
#
# ============================================================
# Processing Ens11_33_b: 302 total events
# ============================================================
# [SKIP] Outputs already exist for Ens11_33_b | 10cm
# [SKIP] Outputs already exist for Ens11_33_b | 30cm
#
# ============================================================
# Processing Ens12_33_b: 188 total events
# ============================================================
# [SKIP] Outputs already exist for Ens12_33_b | 10cm
# [SKIP] Outputs already exist for Ens12_33_b | 30cm
#
# ============================================================
# Processing Ens13_33_b: 194 total events
# ============================================================
# [SKIP] Outputs already exist for Ens13_33_b | 10cm
# [SKIP] Outputs already exist for Ens13_33_b | 30cm
#
# ============================================================
# Processing Ens15_33_b: 280 total events
# ============================================================
# [SKIP] Outputs already exist for Ens15_33_b | 10cm
# [SKIP] Outputs already exist for Ens15_33_b | 30cm
#
# ============================================================
# All 12 ensemble members processed!

# %%
output_area_nc
# Out:
# '/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_33_b/Ens15_33_b/30cm/flooded_area_5km_total_Ens15_33_b_30cm.nc'

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Aggregate 30m flood rasters to 5km totals")
#     parser.add_argument(
#         "ha_num",
#         nargs="?",
#         default="23",
#         help="Catchment number (e.g. 23)"
#     )
#     args = parser.parse_args()
