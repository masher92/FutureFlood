# %%
import sys
sys.path.insert(1,'../ProcessEvents')
from config import CATCHMENT_LOOKUP_DICT, ENSEMBLE_MEMBERS, CATCHMENTS

flood = rxr.open_rasterio(
    "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvial/v4/tifs/Ens01_6/filtered/10cm/res_6_1994_1_Ens01_filtered_10cm.tif",
    chunks={"x": 2000, "y": 2000}).squeeze()

print("Min:", flood.min().compute().item())
print("Max:", flood.max().compute().item())
print("Number flooded:", (flood > 0).sum().compute().item())

Min: -9999.0
Max: -9999.0
Number flooded: 0

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 8))

flood_plot = flood.where(flood > 0)

flood_plot.plot(ax=ax, cmap="Reds")

CATCHMENTS.boundary.plot(ax=ax, edgecolor="black", linewidth=0.5)

ax.set_title("Flood extent")
ax.set_axis_off()
plt.show()

print("Min:", flood.min().compute().item())
print("Max:", flood.max().compute().item())
print("Number flooded:", (flood > 0).sum().compute().item())

# %%
def extract_event_number(filename):
    """
    Extract event number from filenames like:
    res_23_1993_1_Ens07_binary_10cm.tif -> 1
    res_23_1993_123_Ens07_binary_10cm.tif -> 123
    """
    match = re.search(r'_(\d+)_Ens\d+_(?:binary|filtered)_', filename)
    if match:
        return int(match.group(1))
    return None


def iter_event_tifs(ha_num, data_kind, ensembles=None, thresholds=None):
    """
    Yield metadata for every event tif in:
    tifs/EnsXX_<HA_NUM>/<data_kind>/10cm/*.tif
    tifs/EnsXX_<HA_NUM>/<data_kind>/30cm/*.tif
    """
    if data_kind not in {"binary", "filtered"}:
        raise ValueError(f"Unsupported data_kind={data_kind}")

    ensembles = ensembles or ENSEMBLE_MEMBERS
    thresholds = thresholds or THRESHOLDS
    ha_num = str(ha_num)

    for ens in ensembles:
        ens_name = f"Ens{ens}_{ha_num}"

        for thr in thresholds:
            tif_glob = os.path.join(TIFS_DIR, ens_name, data_kind, thr, "*.tif")
            tif_paths = sorted(glob.glob(tif_glob))

            if not tif_paths:
                print(f"[WARN] No files found: {os.path.dirname(tif_glob)}")
                continue

            for tif_path in tif_paths:
                event_num = extract_event_number(os.path.basename(tif_path))
                if event_num is None:
                    print(f"[WARN] Could not extract event number from: {os.path.basename(tif_path)}")
                    continue
                
                yield {"ha_num": ha_num,"ensemble": ens_name,"threshold": thr,"data_kind": data_kind,
                    "path": tif_path,"event_num": event_num,}


def process_single_event_area(binary_file, x5, y5, nx, ny, qa_out_tif=None):
    """
    Process a single binary flood tif and return flooded area per 5km grid cell.
    Maps 30m pixels directly to the original 5km grid using coordinates.
    """
    # Open flood raster
    flood = rxr.open_rasterio(
        binary_file,
        chunks={"x": 2000, "y": 2000}).squeeze()

    if flood.rio.crs is None or flood.rio.crs.to_string() != "EPSG:27700":
        flood = flood.rio.reproject("EPSG:27700")

    # Identify valid pixels
    valid = flood.notnull()

    # Get flood pixel coordinates and values
    flood_x = flood.x.values
    flood_y = flood.y.values
    
    # Create meshgrid of flood coordinates
    xx, yy = np.meshgrid(flood_x, flood_y)
    
    # Flatten coordinates and values
    x_flat = xx.ravel()
    y_flat = yy.ravel()
    flood_flat = flood.values.ravel()
    valid_flat = valid.values.ravel()
    
    # Only keep valid, flooded pixels
    mask = valid_flat & (flood_flat > 0)
    x_flood = x_flat[mask]
    y_flood = y_flat[mask]
    
    if x_flood.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    # Map flood-pixel centers to 5km cell indices using cell edges.
    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_flood - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_flood) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_flood - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_flood) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)
    
    # Convert 2D indices to 1D linear indices
    linear_idx = iy * nx + ix

    if qa_out_tif is not None:
        # Build QA raster in original 30m grid:
        # value = 5km linear cell index for flooded pixels, -1 elsewhere.
        flooded_flat_idx = np.where(mask)[0]
        flooded_flat_idx_in_grid = flooded_flat_idx[in_grid]
        qa_flat = np.full(flood_flat.shape, -1, dtype=np.int32)
        qa_flat[flooded_flat_idx_in_grid] = linear_idx.astype(np.int32)
        qa_arr = qa_flat.reshape(flood.shape)

        qa_da = xr.DataArray(qa_arr, coords=flood.coords, dims=flood.dims)
        qa_da = qa_da.rio.write_crs(flood.rio.crs)
        qa_da.rio.write_transform(flood.rio.transform(), inplace=True)

        os.makedirs(os.path.dirname(qa_out_tif), exist_ok=True)
        qa_da.rio.to_raster(qa_out_tif)
    
    # Count flooded pixels per grid cell
    counts_flat = np.bincount(linear_idx, minlength=nx * ny)
    counts = counts_flat.reshape(ny, nx)
    
    # Convert flooded-pixel counts to total flooded area using actual raster resolution.
    xres, yres = flood.rio.resolution()
    pixel_area_km2 = (abs(xres) * abs(yres)) / 1e6
    flood_area = counts.astype(np.float32) * pixel_area_km2
    
    return flood_area


def process_single_event_volume(depth_file, x5, y5, nx, ny):
    """
    Process a single depth flood tif and return flooded volume per 5km grid cell.
    Volume is computed as sum(depth_m * pixel_area_m2) over pixels within each 5km cell.
    """
    depth = rxr.open_rasterio(depth_file, chunks={"x": 2000, "y": 2000}).squeeze()

    if depth.rio.crs is None or depth.rio.crs.to_string() != "EPSG:27700":
        depth = depth.rio.reproject("EPSG:27700")

    valid = depth.notnull()

    depth_x = depth.x.values
    depth_y = depth.y.values
    xx, yy = np.meshgrid(depth_x, depth_y)

    x_flat = xx.ravel()
    y_flat = yy.ravel()
    depth_flat = depth.values.ravel()
    valid_flat = valid.values.ravel()

    # Only include valid, positive depths in the volume sum.
    mask = valid_flat & (depth_flat > 0)
    x_depth = x_flat[mask]
    y_depth = y_flat[mask]
    depth_vals = depth_flat[mask].astype(np.float64)

    if x_depth.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    x5_arr = np.asarray(x5.values)
    y5_arr = np.asarray(y5.values)

    dx5 = float(abs(x5_arr[1] - x5_arr[0]))
    dy5 = float(abs(y5_arr[1] - y5_arr[0]))

    if x5_arr[1] > x5_arr[0]:
        xmin_edge = float(np.min(x5_arr) - dx5 / 2.0)
        ix = np.floor((x_depth - xmin_edge) / dx5).astype(np.int64)
    else:
        xmax_edge = float(np.max(x5_arr) + dx5 / 2.0)
        ix = np.floor((xmax_edge - x_depth) / dx5).astype(np.int64)

    if y5_arr[1] > y5_arr[0]:
        ymin_edge = float(np.min(y5_arr) - dy5 / 2.0)
        iy = np.floor((y_depth - ymin_edge) / dy5).astype(np.int64)
    else:
        ymax_edge = float(np.max(y5_arr) + dy5 / 2.0)
        iy = np.floor((ymax_edge - y_depth) / dy5).astype(np.int64)

    in_grid = (ix >= 0) & (ix < nx) & (iy >= 0) & (iy < ny)
    ix = ix[in_grid]
    iy = iy[in_grid]
    depth_vals = depth_vals[in_grid]

    if ix.size == 0:
        return np.zeros((ny, nx), dtype=np.float32)

    linear_idx = iy * nx + ix

    xres, yres = depth.rio.resolution()
    pixel_area_m2 = abs(xres) * abs(yres)

    # Depth rasters are in meters, so depth[m] * area[m2] -> volume[m3].
    contrib_m3 = depth_vals * pixel_area_m2
    volume_flat = np.bincount(linear_idx, weights=contrib_m3, minlength=nx * ny)
    flood_volume = volume_flat.reshape(ny, nx).astype(np.float32)

    return flood_volume

def save_5km_array_as_geotiff(array_2d, x_coords, y_coords, transform, out_path):
    """Save a single 2D (y, x) array as a georeferenced GeoTIFF."""
    da = xr.DataArray(
        array_2d,
        coords={"y": y_coords, "x": x_coords},
        dims=("y", "x"),
    )
    da = da.rio.write_crs("EPSG:27700")
    da.rio.write_transform(transform, inplace=True)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    da.astype("float32").rio.to_raster(out_path)

# %%
import os
import glob
import re
import argparse
import xarray as xr
import rioxarray as rxr
import numpy as np
from rasterio.transform import from_bounds

# -----------------------------
# CONFIG
# -----------------------------
ROOT_DIR = "/scratch/hydro5/users/la17355/FUTURE-FLOOD/Results/Pluvials"
# OUTPUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"

TIFS_DIR = os.path.join(ROOT_DIR, "tifs")

# Your 12 ensembles
ENSEMBLE_MEMBERS = ["01", "04", "05", "06", "07", "08", "09", "10", "11", "12", "13", "15"]

# Only the two thresholds you care about
THRESHOLDS = ["10cm", "30cm"]

# QA output: write 30m geotiffs showing assigned 5km cell id per flooded pixel.
WRITE_QA_GRID_INDEX_TIF = False
QA_MAX_EVENTS_PER_THRESHOLD = 1
WRITE_QA_OUTPUT_TIF = True
TIF_MAX_EVENTS_PER_THRESHOLD = 30

# Input grid
GRID_5KM_FILE = "/scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc"
# GRID_5KM_FILE = "/scratch/hydro5/users/ld14116/SDM_bias_correction/Hourly/01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_20801101-20801130.nc"

# %%
files = os.listdir(TIFS_DIR)

# Extract everything after 'Ens15_'
catchment_numbers = set()
for f in files:
    match = re.search(r'Ens01_(.+)', f)
    if match:
        catchment_numbers.add(match.group(1))

# -----------------------------
# FILTER TO ONLY INCOMPLETE CATCHMENTS
# -----------------------------
def all_outputs_exist(ha_num):
    out_dir_base = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{ha_num}"
    for ens in ENSEMBLE_MEMBERS:
        for thr in THRESHOLDS:
            out_dir = os.path.join(out_dir_base, f"Ens{ens}_{ha_num}", thr)
            for kind in ("area", "volume"):
                fname = f"flooded_{kind}_5km_total_Ens{ens}_{ha_num}_{thr}.nc"
                if not os.path.exists(os.path.join(out_dir, fname)):
                    return False
    return True

catchments_to_skip = {c for c in catchment_numbers if all_outputs_exist(c)}
catchments_to_run = catchment_numbers - catchments_to_skip

print(f"{len(catchments_to_skip)} catchments already complete, skipping.")
print(f"{len(catchments_to_run)} catchments to process: {sorted(catchments_to_run)}")
# Out:
# 114 catchments already complete, skipping.
# 0 catchments to process: []

# %%
for HA_NUM in ['6']:
    print(f"Running for {HA_NUM}")
    OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"
    print(f"Outputs to be stored in {OUT_DIR}")
    
    # -----------------------------
    # OPEN 5km GRID
    # -----------------------------
    print(f"Loading 5km grid from {GRID_5KM_FILE}...")
    ds = xr.open_dataset(GRID_5KM_FILE)

    x5 = ds["projection_x_coordinate"]
    y5 = ds["projection_y_coordinate"]

    nx = x5.size
    ny = y5.size

    dx = float(abs(x5[1] - x5[0]))
    dy = float(abs(y5[1] - y5[0]))

    xmin = float(x5.min() - dx/2)
    xmax = float(x5.max() + dx/2)
    ymin = float(y5.min() - dy/2)
    ymax = float(y5.max() + dy/2)

    # -----------------------------
    # CREATE GRID-ID RASTER
    # -----------------------------
    grid_ids = np.arange(nx * ny).reshape(ny, nx)

    # Use standard y, x dimension names for rioxarray compatibility
    grid_da = xr.DataArray(
        grid_ids,
        coords={"y": y5.values, "x": x5.values},
        dims=("y", "x"))

    grid_da = grid_da.rio.write_crs("EPSG:27700")

    transform = from_bounds(xmin, ymin, xmax, ymax, nx, ny)
    grid_da.rio.write_transform(transform, inplace=True)

    # Export a GeoTIFF copy of the 5km grid IDs for visual QA.
    # grid_out_dir = os.path.join(OUT_DIR, "grid")
    # os.makedirs(grid_out_dir, exist_ok=True)
    # grid_tif_path = os.path.join(grid_out_dir, f"grid_id_5km_from_input_{HA_NUM}.tif")
    # print(f"Saving 5km grid GeoTIFF to {grid_tif_path}...")
    # grid_da.astype("int32").rio.to_raster(grid_tif_path)

    # -----------------------------
    # COLLECT ALL EVENT FILES
    # -----------------------------
    print(f"Scanning for binary tif files for HA_NUM={HA_NUM}...")
    binary_event_files = list(iter_event_tifs(HA_NUM, data_kind="binary"))

    print(f"Scanning for filtered depth tif files for HA_NUM={HA_NUM}...")
    filtered_event_files = list(iter_event_tifs(HA_NUM, data_kind="filtered"))

    if not binary_event_files:
        raise ValueError(f"No binary tif files found for HA_NUM={HA_NUM}")

    if not filtered_event_files:
        raise ValueError(f"No filtered depth tif files found for HA_NUM={HA_NUM}")

    print(f"Found {len(binary_event_files)} binary event files")
    print(f"Found {len(filtered_event_files)} filtered depth event files")

    # -----------------------------
    # GROUP BY ENSEMBLE
    # -----------------------------
    from collections import defaultdict
    binary_by_ensemble = defaultdict(list)
    filtered_lookup = {}

    for info in binary_event_files:
        binary_by_ensemble[info['ensemble']].append(info)

    for info in filtered_event_files:
        key = (info["ensemble"], info["threshold"], info["event_num"])
        filtered_lookup[key] = info

    print(f"Found {len(binary_by_ensemble)} ensemble members")

    # -----------------------------
    # PROCESS EACH ENSEMBLE + THRESHOLD SEPARATELY
    # -----------------------------
    for ens_name in sorted(binary_by_ensemble.keys()):
#     for ens_name in ['Ens13_106']:        
        ens_events = binary_by_ensemble[ens_name]
        ens_events.sort(key=lambda x: (x['threshold'], x['event_num']))

        print(f"\n{'='*60}")
        print(f"Processing {ens_name}: {len(ens_events)} total events")
        print(f"{'='*60}")
        
        for thr in THRESHOLDS:
            thr_events = [e for e in ens_events if e["threshold"] == thr]
            if not thr_events:
                print(f"[WARN] No events for {ens_name} threshold {thr}")
                continue

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

#             if os.path.exists(output_area_nc) and os.path.exists(output_volume_nc):
#                 print(f"[SKIP] Outputs already exist for {ens_name} | {thr}")
#                 continue

            print(f"\n[{ens_name} | {thr}] Processing {len(thr_events)} events")

            flood_areas = []
            flood_volumes = []
            for i, info in enumerate(thr_events):
                print(f"[{i+1}/{len(thr_events)}] Processing {os.path.basename(info['path'])} (event={info['event_num']})")

                key = (ens_name, thr, info["event_num"])
                if key not in filtered_lookup:
                    raise ValueError(
                        f"Missing filtered depth tif for {ens_name}, {thr}, event={info['event_num']}")

                filtered_info = filtered_lookup[key]

                qa_out_tif = None
                if WRITE_QA_GRID_INDEX_TIF and i < QA_MAX_EVENTS_PER_THRESHOLD:
                    print("Performing QA")
                    qa_dir = os.path.join(OUT_DIR, "qa", ens_name, thr)
                    qa_out_tif = os.path.join(qa_dir,
                        f"qa_5km_cell_index_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
                    print(f"    Writing QA 30m->5km index raster: {qa_out_tif}")
                else:
                    print("Skippping QA")

                flood_area = process_single_event_area(info['path'],x5, y5, nx, ny,qa_out_tif=qa_out_tif)

                flood_volume = process_single_event_volume(filtered_info["path"],x5, y5, nx, ny)

                # --- NEW: export a few events as GeoTIFF for QGIS comparison ---
                if WRITE_QA_OUTPUT_TIF and i < TIF_MAX_EVENTS_PER_THRESHOLD:
                    tif_qa_dir = os.path.join(OUT_DIR, "qa_output_tif", ens_name, thr)

                    area_tif_path = os.path.join(
                        tif_qa_dir,
                        f"flooded_area_5km_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
                    save_5km_array_as_geotiff(flood_area, x5.values, y5.values, transform, area_tif_path)

                    volume_tif_path = os.path.join(
                        tif_qa_dir,
                        f"flooded_volume_5km_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
                    save_5km_array_as_geotiff(flood_volume, x5.values, y5.values, transform, volume_tif_path)

                    print(f"    Wrote QA GeoTIFFs: {area_tif_path}, {volume_tif_path}")
                # --- end NEW ---
                
                total_km2 = float(np.sum(flood_area))
                total_m3 = float(np.sum(flood_volume))
                print(f"    Total flooded area (sum of 5km cells): {total_km2:.4f} km2")
                print(f"    Total flooded volume (sum of 5km cells): {total_m3:.2f} m3")
                flood_areas.append(flood_area)
                flood_volumes.append(flood_volume)

            flood_areas_stack = np.stack(flood_areas, axis=0)
            flood_volumes_stack = np.stack(flood_volumes, axis=0)
            event_nums = np.array([info['event_num'] for info in thr_events], dtype=np.int32)

            out_area = xr.Dataset({"flooded_area_5km_km2": (("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_areas_stack), "event_num": ("event", event_nums),},
                coords={"event": event_nums,"projection_x_coordinate": x5, "projection_y_coordinate": y5})

            out_volume = xr.Dataset({"flooded_volume_5km_m3": (("event", "projection_y_coordinate", "projection_x_coordinate"),
                        flood_volumes_stack), "event_num": ("event", event_nums),},
                coords={"event": event_nums, "projection_x_coordinate": x5, "projection_y_coordinate": y5})

            for out_ds in (out_area, out_volume):
                out_ds["projection_x_coordinate"].attrs.update({
                    "standard_name": "projection_x_coordinate",
                    "long_name": "x coordinate of British National Grid projection",
                    "units": "m"})
                out_ds["projection_y_coordinate"].attrs.update({
                    "standard_name": "projection_y_coordinate",
                    "long_name": "y coordinate of British National Grid projection",
                    "units": "m"})
                out_ds["event_num"].attrs["long_name"] = "event number"
                out_ds["event"].attrs["long_name"] = "event number"

            out_area = out_area.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate")
            out_area.rio.write_transform(transform, inplace=True)
            out_area.rio.write_crs("EPSG:27700", inplace=True)
            out_area.rio.write_coordinate_system(inplace=True)

            out_volume = out_volume.rio.set_spatial_dims(
                x_dim="projection_x_coordinate",
                y_dim="projection_y_coordinate")
            out_volume.rio.write_transform(transform, inplace=True)
            out_volume.rio.write_crs("EPSG:27700", inplace=True)
            out_volume.rio.write_coordinate_system(inplace=True)

            out_area["flooded_area_5km_km2"].attrs["long_name"] = "Total flooded area per 5km grid cell"
            out_area["flooded_area_5km_km2"].attrs["units"] = "km2"
            out_volume["flooded_volume_5km_m3"].attrs["long_name"] = "Total flooded volume per 5km grid cell"
            out_volume["flooded_volume_5km_m3"].attrs["units"] = "m3"

            out_dir = os.path.join(OUT_DIR, ens_name, thr)
            os.makedirs(out_dir, exist_ok=True)

            output_area_nc = os.path.join(out_dir, f"flooded_area_5km_total_{ens_name}_{thr}.nc")
            output_volume_nc = os.path.join(out_dir, f"flooded_volume_5km_total_{ens_name}_{thr}.nc")

            print(f"Saving area to {output_area_nc}...")
            out_area.to_netcdf(output_area_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_area_nc}")

            print(f"Saving volume to {output_volume_nc}...")
            out_volume.to_netcdf(output_volume_nc)
            print(f"Done! Saved {len(thr_events)} events to {output_volume_nc}")

    print(f"\n{'='*60}")
    print(f"All {len(binary_by_ensemble)} ensemble members processed!")
# Out:
# Running for 23
# Outputs to be stored in /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23
# Loading 5km grid from /scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc...
# Scanning for binary tif files for HA_NUM=23...
# Scanning for filtered depth tif files for HA_NUM=23...
# Found 1748 binary event files
# Found 1748 filtered depth event files
# Found 12 ensemble members
#
# ============================================================
# Processing Ens01_23: 190 total events
# ============================================================
#
# [Ens01_23 | 10cm] Processing 95 events
# [1/95] Processing res_23_1992_1_Ens01_binary_10cm.tif (event=1)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_001.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_001.tif
#     Total flooded area (sum of 5km cells): 0.3159 km2
#     Total flooded volume (sum of 5km cells): 132925.50 m3
# [2/95] Processing res_23_1994_2_Ens01_binary_10cm.tif (event=2)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_002.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_002.tif
#     Total flooded area (sum of 5km cells): 0.1215 km2
#     Total flooded volume (sum of 5km cells): 85562.09 m3
# [3/95] Processing res_23_1994_3_Ens01_binary_10cm.tif (event=3)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_003.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_003.tif
#     Total flooded area (sum of 5km cells): 0.5220 km2
#     Total flooded volume (sum of 5km cells): 323349.31 m3
# [4/95] Processing res_23_1995_4_Ens01_binary_10cm.tif (event=4)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_004.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_004.tif
#     Total flooded area (sum of 5km cells): 5.1102 km2
#     Total flooded volume (sum of 5km cells): 2921526.00 m3
# [5/95] Processing res_23_2001_5_Ens01_binary_10cm.tif (event=5)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_005.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_005.tif
#     Total flooded area (sum of 5km cells): 0.7380 km2
#     Total flooded volume (sum of 5km cells): 286443.00 m3
# [6/95] Processing res_23_2001_6_Ens01_binary_10cm.tif (event=6)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_006.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_006.tif
#     Total flooded area (sum of 5km cells): 11.7783 km2
#     Total flooded volume (sum of 5km cells): 4812094.00 m3
# [7/95] Processing res_23_2004_7_Ens01_binary_10cm.tif (event=7)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_007.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_007.tif
#     Total flooded area (sum of 5km cells): 0.3663 km2
#     Total flooded volume (sum of 5km cells): 193058.11 m3
# [8/95] Processing res_23_2004_8_Ens01_binary_10cm.tif (event=8)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_008.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_008.tif
#     Total flooded area (sum of 5km cells): 1.4526 km2
#     Total flooded volume (sum of 5km cells): 620494.19 m3
# [9/95] Processing res_23_2004_9_Ens01_binary_10cm.tif (event=9)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_009.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_009.tif
#     Total flooded area (sum of 5km cells): 3.5928 km2
#     Total flooded volume (sum of 5km cells): 1521013.50 m3
# [10/95] Processing res_23_2008_10_Ens01_binary_10cm.tif (event=10)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_010.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_010.tif
#     Total flooded area (sum of 5km cells): 3.4020 km2
#     Total flooded volume (sum of 5km cells): 1752971.38 m3
# [11/95] Processing res_23_2011_11_Ens01_binary_10cm.tif (event=11)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_011.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_011.tif
#     Total flooded area (sum of 5km cells): 2.3616 km2
#     Total flooded volume (sum of 5km cells): 1045998.88 m3
# [12/95] Processing res_23_2011_12_Ens01_binary_10cm.tif (event=12)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_012.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_012.tif
#     Total flooded area (sum of 5km cells): 2.0286 km2
#     Total flooded volume (sum of 5km cells): 658923.25 m3
# [13/95] Processing res_23_2013_13_Ens01_binary_10cm.tif (event=13)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_013.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_013.tif
#     Total flooded area (sum of 5km cells): 5.3064 km2
#     Total flooded volume (sum of 5km cells): 2142029.75 m3
# [14/95] Processing res_23_2016_14_Ens01_binary_10cm.tif (event=14)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_014.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_014.tif
#     Total flooded area (sum of 5km cells): 3.3354 km2
#     Total flooded volume (sum of 5km cells): 1376626.38 m3
# [15/95] Processing res_23_2017_15_Ens01_binary_10cm.tif (event=15)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_015.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_015.tif
#     Total flooded area (sum of 5km cells): 2.8611 km2
#     Total flooded volume (sum of 5km cells): 1204951.38 m3
# [16/95] Processing res_23_2018_16_Ens01_binary_10cm.tif (event=16)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_016.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_016.tif
#     Total flooded area (sum of 5km cells): 2.8665 km2
#     Total flooded volume (sum of 5km cells): 1123002.00 m3
# [17/95] Processing res_23_2019_17_Ens01_binary_10cm.tif (event=17)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_017.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_017.tif
#     Total flooded area (sum of 5km cells): 7.9290 km2
#     Total flooded volume (sum of 5km cells): 3571553.75 m3
# [18/95] Processing res_23_2019_18_Ens01_binary_10cm.tif (event=18)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_018.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_018.tif
#     Total flooded area (sum of 5km cells): 0.8487 km2
#     Total flooded volume (sum of 5km cells): 456145.19 m3
# [19/95] Processing res_23_2020_19_Ens01_binary_10cm.tif (event=19)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_019.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_019.tif
#     Total flooded area (sum of 5km cells): 23.4090 km2
#     Total flooded volume (sum of 5km cells): 11050406.00 m3
# [20/95] Processing res_23_2022_20_Ens01_binary_10cm.tif (event=20)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_020.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_020.tif
#     Total flooded area (sum of 5km cells): 11.2464 km2
#     Total flooded volume (sum of 5km cells): 4971225.00 m3
# [21/95] Processing res_23_2023_21_Ens01_binary_10cm.tif (event=21)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_021.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_021.tif
#     Total flooded area (sum of 5km cells): 1.8360 km2
#     Total flooded volume (sum of 5km cells): 759717.94 m3
# [22/95] Processing res_23_2025_22_Ens01_binary_10cm.tif (event=22)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_022.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_022.tif
#     Total flooded area (sum of 5km cells): 2.8395 km2
#     Total flooded volume (sum of 5km cells): 951170.50 m3
# [23/95] Processing res_23_2025_23_Ens01_binary_10cm.tif (event=23)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_023.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_023.tif
#     Total flooded area (sum of 5km cells): 1.6344 km2
#     Total flooded volume (sum of 5km cells): 652783.50 m3
# [24/95] Processing res_23_2026_24_Ens01_binary_10cm.tif (event=24)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_024.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_024.tif
#     Total flooded area (sum of 5km cells): 1.2897 km2
#     Total flooded volume (sum of 5km cells): 721089.88 m3
# [25/95] Processing res_23_2027_25_Ens01_binary_10cm.tif (event=25)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_025.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_025.tif
#     Total flooded area (sum of 5km cells): 0.7434 km2
#     Total flooded volume (sum of 5km cells): 254394.89 m3
# [26/95] Processing res_23_2027_26_Ens01_binary_10cm.tif (event=26)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_026.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_026.tif
#     Total flooded area (sum of 5km cells): 3.4245 km2
#     Total flooded volume (sum of 5km cells): 1395649.88 m3
# [27/95] Processing res_23_2029_27_Ens01_binary_10cm.tif (event=27)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_027.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_027.tif
#     Total flooded area (sum of 5km cells): 1.7586 km2
#     Total flooded volume (sum of 5km cells): 600242.38 m3
# [28/95] Processing res_23_2033_28_Ens01_binary_10cm.tif (event=28)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_028.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_028.tif
#     Total flooded area (sum of 5km cells): 1.5579 km2
#     Total flooded volume (sum of 5km cells): 656717.44 m3
# [29/95] Processing res_23_2035_29_Ens01_binary_10cm.tif (event=29)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_029.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_029.tif
#     Total flooded area (sum of 5km cells): 6.9390 km2
#     Total flooded volume (sum of 5km cells): 3423939.75 m3
# [30/95] Processing res_23_2035_30_Ens01_binary_10cm.tif (event=30)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_030.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_030.tif
#     Total flooded area (sum of 5km cells): 0.8928 km2
#     Total flooded volume (sum of 5km cells): 662532.38 m3
# [31/95] Processing res_23_2035_31_Ens01_binary_10cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.2935 km2
#     Total flooded volume (sum of 5km cells): 3330723.75 m3
# [32/95] Processing res_23_2037_32_Ens01_binary_10cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.9348 km2
#     Total flooded volume (sum of 5km cells): 1841423.50 m3
# [33/95] Processing res_23_2037_33_Ens01_binary_10cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.4595 km2
#     Total flooded volume (sum of 5km cells): 2261441.75 m3
# [34/95] Processing res_23_2038_34_Ens01_binary_10cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0179 km2
#     Total flooded volume (sum of 5km cells): 345823.19 m3
# [35/95] Processing res_23_2040_35_Ens01_binary_10cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 7.1001 km2
#     Total flooded volume (sum of 5km cells): 2852894.00 m3
# [36/95] Processing res_23_2041_36_Ens01_binary_10cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7569 km2
#     Total flooded volume (sum of 5km cells): 330006.59 m3
# [37/95] Processing res_23_2041_37_Ens01_binary_10cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.2005 km2
#     Total flooded volume (sum of 5km cells): 4677078.00 m3
# [38/95] Processing res_23_2041_38_Ens01_binary_10cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.1013 km2
#     Total flooded volume (sum of 5km cells): 1484712.88 m3
# [39/95] Processing res_23_2041_39_Ens01_binary_10cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.1173 km2
#     Total flooded volume (sum of 5km cells): 2649247.00 m3
# [40/95] Processing res_23_2041_40_Ens01_binary_10cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.9835 km2
#     Total flooded volume (sum of 5km cells): 1352038.50 m3
# [41/95] Processing res_23_2042_41_Ens01_binary_10cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7713 km2
#     Total flooded volume (sum of 5km cells): 425224.81 m3
# [42/95] Processing res_23_2042_42_Ens01_binary_10cm.tif (event=42)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6083 km2
#     Total flooded volume (sum of 5km cells): 485451.88 m3
# [43/95] Processing res_23_2042_43_Ens01_binary_10cm.tif (event=43)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8181 km2
#     Total flooded volume (sum of 5km cells): 317746.81 m3
# [44/95] Processing res_23_2043_44_Ens01_binary_10cm.tif (event=44)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6362 km2
#     Total flooded volume (sum of 5km cells): 1051007.38 m3
# [45/95] Processing res_23_2043_45_Ens01_binary_10cm.tif (event=45)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5229 km2
#     Total flooded volume (sum of 5km cells): 243702.00 m3
# [46/95] Processing res_23_2045_46_Ens01_binary_10cm.tif (event=46)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8748 km2
#     Total flooded volume (sum of 5km cells): 342884.72 m3
# [47/95] Processing res_23_2046_47_Ens01_binary_10cm.tif (event=47)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4293 km2
#     Total flooded volume (sum of 5km cells): 176725.80 m3
# [48/95] Processing res_23_2046_48_Ens01_binary_10cm.tif (event=48)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.6546 km2
#     Total flooded volume (sum of 5km cells): 2999177.00 m3
# [49/95] Processing res_23_2047_49_Ens01_binary_10cm.tif (event=49)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2862 km2
#     Total flooded volume (sum of 5km cells): 102051.89 m3
# [50/95] Processing res_23_2048_50_Ens01_binary_10cm.tif (event=50)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.9577 km2
#     Total flooded volume (sum of 5km cells): 4007385.00 m3
# [51/95] Processing res_23_2048_51_Ens01_binary_10cm.tif (event=51)
# Skippping QA
#     Total flooded area (sum of 5km cells): 6.1884 km2
#     Total flooded volume (sum of 5km cells): 2700515.00 m3
# [52/95] Processing res_23_2050_52_Ens01_binary_10cm.tif (event=52)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.8295 km2
#     Total flooded volume (sum of 5km cells): 1690866.00 m3
# [53/95] Processing res_23_2050_53_Ens01_binary_10cm.tif (event=53)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4662 km2
#     Total flooded volume (sum of 5km cells): 223650.91 m3
# [54/95] Processing res_23_2051_54_Ens01_binary_10cm.tif (event=54)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4383 km2
#     Total flooded volume (sum of 5km cells): 228399.31 m3
# [55/95] Processing res_23_2051_55_Ens01_binary_10cm.tif (event=55)
# Skippping QA
#     Total flooded area (sum of 5km cells): 17.0631 km2
#     Total flooded volume (sum of 5km cells): 8024732.50 m3
# [56/95] Processing res_23_2051_56_Ens01_binary_10cm.tif (event=56)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3806 km2
#     Total flooded volume (sum of 5km cells): 479233.81 m3
# [57/95] Processing res_23_2051_57_Ens01_binary_10cm.tif (event=57)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.1111 km2
#     Total flooded volume (sum of 5km cells): 2407769.25 m3
# [58/95] Processing res_23_2052_58_Ens01_binary_10cm.tif (event=58)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8055 km2
#     Total flooded volume (sum of 5km cells): 302923.78 m3
# [59/95] Processing res_23_2052_59_Ens01_binary_10cm.tif (event=59)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1755 km2
#     Total flooded volume (sum of 5km cells): 83125.80 m3
# [60/95] Processing res_23_2053_60_Ens01_binary_10cm.tif (event=60)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3429 km2
#     Total flooded volume (sum of 5km cells): 164559.61 m3
# [61/95] Processing res_23_2053_61_Ens01_binary_10cm.tif (event=61)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0909 km2
#     Total flooded volume (sum of 5km cells): 35531.10 m3
# [62/95] Processing res_23_2053_62_Ens01_binary_10cm.tif (event=62)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2430 km2
#     Total flooded volume (sum of 5km cells): 80667.00 m3
# [63/95] Processing res_23_2054_63_Ens01_binary_10cm.tif (event=63)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.0509 km2
#     Total flooded volume (sum of 5km cells): 1513995.25 m3
# [64/95] Processing res_23_2057_64_Ens01_binary_10cm.tif (event=64)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.0322 km2
#     Total flooded volume (sum of 5km cells): 1560455.12 m3
# [65/95] Processing res_23_2060_65_Ens01_binary_10cm.tif (event=65)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0206 km2
#     Total flooded volume (sum of 5km cells): 576887.31 m3
# [66/95] Processing res_23_2060_66_Ens01_binary_10cm.tif (event=66)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.7300 km2
#     Total flooded volume (sum of 5km cells): 3788150.50 m3
# [67/95] Processing res_23_2062_67_Ens01_binary_10cm.tif (event=67)
# Skippping QA
#     Total flooded area (sum of 5km cells): 5.2560 km2
#     Total flooded volume (sum of 5km cells): 2092329.00 m3
# [68/95] Processing res_23_2062_68_Ens01_binary_10cm.tif (event=68)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.1557 km2
#     Total flooded volume (sum of 5km cells): 3631848.50 m3
# [69/95] Processing res_23_2065_69_Ens01_binary_10cm.tif (event=69)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9422 km2
#     Total flooded volume (sum of 5km cells): 646145.06 m3
# [70/95] Processing res_23_2065_70_Ens01_binary_10cm.tif (event=70)
# Skippping QA
#     Total flooded area (sum of 5km cells): 9.8631 km2
#     Total flooded volume (sum of 5km cells): 4314379.50 m3
# [71/95] Processing res_23_2065_71_Ens01_binary_10cm.tif (event=71)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7694 km2
#     Total flooded volume (sum of 5km cells): 855443.62 m3
# [72/95] Processing res_23_2066_72_Ens01_binary_10cm.tif (event=72)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2070 km2
#     Total flooded volume (sum of 5km cells): 142079.41 m3
# [73/95] Processing res_23_2066_73_Ens01_binary_10cm.tif (event=73)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6228 km2
#     Total flooded volume (sum of 5km cells): 387759.59 m3
# [74/95] Processing res_23_2067_74_Ens01_binary_10cm.tif (event=74)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.7496 km2
#     Total flooded volume (sum of 5km cells): 613102.50 m3
# [75/95] Processing res_23_2067_75_Ens01_binary_10cm.tif (event=75)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.9476 km2
#     Total flooded volume (sum of 5km cells): 911888.12 m3
# [76/95] Processing res_23_2068_76_Ens01_binary_10cm.tif (event=76)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1754 km2
#     Total flooded volume (sum of 5km cells): 397296.00 m3
# [77/95] Processing res_23_2069_77_Ens01_binary_10cm.tif (event=77)
# Skippping QA
#     Total flooded area (sum of 5km cells): 8.0856 km2
#     Total flooded volume (sum of 5km cells): 3376246.50 m3
# [78/95] Processing res_23_2070_78_Ens01_binary_10cm.tif (event=78)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4059 km2
#     Total flooded volume (sum of 5km cells): 164738.69 m3
# [79/95] Processing res_23_2071_79_Ens01_binary_10cm.tif (event=79)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8199 km2
#     Total flooded volume (sum of 5km cells): 305265.62 m3
# [80/95] Processing res_23_2072_80_Ens01_binary_10cm.tif (event=80)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.2879 km2
#     Total flooded volume (sum of 5km cells): 487197.00 m3
# [81/95] Processing res_23_2076_81_Ens01_binary_10cm.tif (event=81)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3320 km2
#     Total flooded volume (sum of 5km cells): 613430.12 m3
# [82/95] Processing res_23_2076_82_Ens01_binary_10cm.tif (event=82)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.5238 km2
#     Total flooded volume (sum of 5km cells): 236943.00 m3
# [83/95] Processing res_23_2076_83_Ens01_binary_10cm.tif (event=83)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6630 km2
#     Total flooded volume (sum of 5km cells): 1322500.38 m3
# [84/95] Processing res_23_2076_84_Ens01_binary_10cm.tif (event=84)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6489 km2
#     Total flooded volume (sum of 5km cells): 300451.53 m3
# [85/95] Processing res_23_2076_85_Ens01_binary_10cm.tif (event=85)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1141 km2
#     Total flooded volume (sum of 5km cells): 608505.31 m3
# [86/95] Processing res_23_2076_86_Ens01_binary_10cm.tif (event=86)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.8790 km2
#     Total flooded volume (sum of 5km cells): 1335876.38 m3
# [87/95] Processing res_23_2078_87_Ens01_binary_10cm.tif (event=87)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1322 km2
#     Total flooded volume (sum of 5km cells): 740102.44 m3
# [88/95] Processing res_23_2078_88_Ens01_binary_10cm.tif (event=88)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9279 km2
#     Total flooded volume (sum of 5km cells): 290679.28 m3
# [89/95] Processing res_23_2078_89_Ens01_binary_10cm.tif (event=89)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0953 km2
#     Total flooded volume (sum of 5km cells): 672344.06 m3
# [90/95] Processing res_23_2078_90_Ens01_binary_10cm.tif (event=90)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1006 km2
#     Total flooded volume (sum of 5km cells): 989521.19 m3
# [91/95] Processing res_23_2078_91_Ens01_binary_10cm.tif (event=91)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.5731 km2
#     Total flooded volume (sum of 5km cells): 1246046.38 m3
# [92/95] Processing res_23_2078_92_Ens01_binary_10cm.tif (event=92)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1116 km2
#     Total flooded volume (sum of 5km cells): 73727.10 m3
# [93/95] Processing res_23_2078_93_Ens01_binary_10cm.tif (event=93)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.6075 km2
#     Total flooded volume (sum of 5km cells): 242131.50 m3
# [94/95] Processing res_23_2078_94_Ens01_binary_10cm.tif (event=94)
# Skippping QA
#     Total flooded area (sum of 5km cells): 11.1060 km2
#     Total flooded volume (sum of 5km cells): 5341186.00 m3
# [95/95] Processing res_23_2080_95_Ens01_binary_10cm.tif (event=95)
# Skippping QA
#     Total flooded area (sum of 5km cells): 12.1410 km2
#     Total flooded volume (sum of 5km cells): 5715729.50 m3
# Saving area to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/Ens01_23/10cm/flooded_area_5km_total_Ens01_23_10cm.nc...
# Done! Saved 95 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/Ens01_23/10cm/flooded_area_5km_total_Ens01_23_10cm.nc
# Saving volume to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/Ens01_23/10cm/flooded_volume_5km_total_Ens01_23_10cm.nc...
# Done! Saved 95 events to /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/Ens01_23/10cm/flooded_volume_5km_total_Ens01_23_10cm.nc
#
# [Ens01_23 | 30cm] Processing 95 events
# [1/95] Processing res_23_1992_1_Ens01_binary_30cm.tif (event=1)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_001.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_001.tif
#     Total flooded area (sum of 5km cells): 0.0774 km2
#     Total flooded volume (sum of 5km cells): 69597.00 m3
# [2/95] Processing res_23_1994_2_Ens01_binary_30cm.tif (event=2)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_002.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_002.tif
#     Total flooded area (sum of 5km cells): 0.0360 km2
#     Total flooded volume (sum of 5km cells): 52490.70 m3
# [3/95] Processing res_23_1994_3_Ens01_binary_30cm.tif (event=3)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_003.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_003.tif
#     Total flooded area (sum of 5km cells): 0.1602 km2
#     Total flooded volume (sum of 5km cells): 201576.59 m3
# [4/95] Processing res_23_1995_4_Ens01_binary_30cm.tif (event=4)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_004.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_004.tif
#     Total flooded area (sum of 5km cells): 1.5705 km2
#     Total flooded volume (sum of 5km cells): 1887335.88 m3
# [5/95] Processing res_23_2001_5_Ens01_binary_30cm.tif (event=5)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_005.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_005.tif
#     Total flooded area (sum of 5km cells): 0.2385 km2
#     Total flooded volume (sum of 5km cells): 167351.41 m3
# [6/95] Processing res_23_2001_6_Ens01_binary_30cm.tif (event=6)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_006.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_006.tif
#     Total flooded area (sum of 5km cells): 4.2759 km2
#     Total flooded volume (sum of 5km cells): 3216012.00 m3
# [7/95] Processing res_23_2004_7_Ens01_binary_30cm.tif (event=7)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_007.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_007.tif
#     Total flooded area (sum of 5km cells): 0.0846 km2
#     Total flooded volume (sum of 5km cells): 102824.09 m3
# [8/95] Processing res_23_2004_8_Ens01_binary_30cm.tif (event=8)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_008.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_008.tif
#     Total flooded area (sum of 5km cells): 0.3537 km2
#     Total flooded volume (sum of 5km cells): 338336.12 m3
# [9/95] Processing res_23_2004_9_Ens01_binary_30cm.tif (event=9)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_009.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_009.tif
#     Total flooded area (sum of 5km cells): 1.1709 km2
#     Total flooded volume (sum of 5km cells): 937747.75 m3
# [10/95] Processing res_23_2008_10_Ens01_binary_30cm.tif (event=10)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_010.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_010.tif
#     Total flooded area (sum of 5km cells): 1.0134 km2
#     Total flooded volume (sum of 5km cells): 1076512.50 m3
# [11/95] Processing res_23_2011_11_Ens01_binary_30cm.tif (event=11)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_011.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_011.tif
#     Total flooded area (sum of 5km cells): 0.7938 km2
#     Total flooded volume (sum of 5km cells): 650218.50 m3
# [12/95] Processing res_23_2011_12_Ens01_binary_30cm.tif (event=12)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_012.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_012.tif
#     Total flooded area (sum of 5km cells): 0.5103 km2
#     Total flooded volume (sum of 5km cells): 322467.31 m3
# [13/95] Processing res_23_2013_13_Ens01_binary_30cm.tif (event=13)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_013.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_013.tif
#     Total flooded area (sum of 5km cells): 1.4058 km2
#     Total flooded volume (sum of 5km cells): 1120694.50 m3
# [14/95] Processing res_23_2016_14_Ens01_binary_30cm.tif (event=14)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_014.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_014.tif
#     Total flooded area (sum of 5km cells): 1.1097 km2
#     Total flooded volume (sum of 5km cells): 839209.50 m3
# [15/95] Processing res_23_2017_15_Ens01_binary_30cm.tif (event=15)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_015.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_015.tif
#     Total flooded area (sum of 5km cells): 0.7542 km2
#     Total flooded volume (sum of 5km cells): 672624.88 m3
# [16/95] Processing res_23_2018_16_Ens01_binary_30cm.tif (event=16)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_016.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_016.tif
#     Total flooded area (sum of 5km cells): 0.6822 km2
#     Total flooded volume (sum of 5km cells): 585605.69 m3
# [17/95] Processing res_23_2019_17_Ens01_binary_30cm.tif (event=17)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_017.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_017.tif
#     Total flooded area (sum of 5km cells): 2.7540 km2
#     Total flooded volume (sum of 5km cells): 2272301.00 m3
# [18/95] Processing res_23_2019_18_Ens01_binary_30cm.tif (event=18)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_018.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_018.tif
#     Total flooded area (sum of 5km cells): 0.2448 km2
#     Total flooded volume (sum of 5km cells): 284932.81 m3
# [19/95] Processing res_23_2020_19_Ens01_binary_30cm.tif (event=19)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_019.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_019.tif
#     Total flooded area (sum of 5km cells): 8.0577 km2
#     Total flooded volume (sum of 5km cells): 7199090.50 m3
# [20/95] Processing res_23_2022_20_Ens01_binary_30cm.tif (event=20)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_020.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_020.tif
#     Total flooded area (sum of 5km cells): 4.5009 km2
#     Total flooded volume (sum of 5km cells): 3385869.25 m3
# [21/95] Processing res_23_2023_21_Ens01_binary_30cm.tif (event=21)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_021.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_021.tif
#     Total flooded area (sum of 5km cells): 0.5013 km2
#     Total flooded volume (sum of 5km cells): 415208.69 m3
# [22/95] Processing res_23_2025_22_Ens01_binary_30cm.tif (event=22)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_022.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_022.tif
#     Total flooded area (sum of 5km cells): 0.6309 km2
#     Total flooded volume (sum of 5km cells): 445347.88 m3
# [23/95] Processing res_23_2025_23_Ens01_binary_30cm.tif (event=23)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_023.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_023.tif
#     Total flooded area (sum of 5km cells): 0.4734 km2
#     Total flooded volume (sum of 5km cells): 367465.50 m3
# [24/95] Processing res_23_2026_24_Ens01_binary_30cm.tif (event=24)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_024.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_024.tif
#     Total flooded area (sum of 5km cells): 0.3879 km2
#     Total flooded volume (sum of 5km cells): 442037.72 m3
# [25/95] Processing res_23_2027_25_Ens01_binary_30cm.tif (event=25)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_025.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_025.tif
#     Total flooded area (sum of 5km cells): 0.1584 km2
#     Total flooded volume (sum of 5km cells): 114100.20 m3
# [26/95] Processing res_23_2027_26_Ens01_binary_30cm.tif (event=26)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_026.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_026.tif
#     Total flooded area (sum of 5km cells): 0.9414 km2
#     Total flooded volume (sum of 5km cells): 766119.56 m3
# [27/95] Processing res_23_2029_27_Ens01_binary_30cm.tif (event=27)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_027.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_027.tif
#     Total flooded area (sum of 5km cells): 0.4023 km2
#     Total flooded volume (sum of 5km cells): 282582.00 m3
# [28/95] Processing res_23_2033_28_Ens01_binary_30cm.tif (event=28)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_028.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_028.tif
#     Total flooded area (sum of 5km cells): 0.4770 km2
#     Total flooded volume (sum of 5km cells): 366039.00 m3
# [29/95] Processing res_23_2035_29_Ens01_binary_30cm.tif (event=29)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_029.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_029.tif
#     Total flooded area (sum of 5km cells): 2.2131 km2
#     Total flooded volume (sum of 5km cells): 2179494.00 m3
# [30/95] Processing res_23_2035_30_Ens01_binary_30cm.tif (event=30)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_area_5km_Ens01_23_30cm_event_030.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/30cm/flooded_volume_5km_Ens01_23_30cm_event_030.tif
#     Total flooded area (sum of 5km cells): 0.2781 km2
#     Total flooded volume (sum of 5km cells): 416845.84 m3
# [31/95] Processing res_23_2035_31_Ens01_binary_30cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.6046 km2
#     Total flooded volume (sum of 5km cells): 1991127.75 m3
# [32/95] Processing res_23_2037_32_Ens01_binary_30cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.0251 km2
#     Total flooded volume (sum of 5km cells): 1000030.50 m3
# [33/95] Processing res_23_2037_33_Ens01_binary_30cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3932 km2
#     Total flooded volume (sum of 5km cells): 1349776.75 m3
# [34/95] Processing res_23_2038_34_Ens01_binary_30cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1971 km2
#     Total flooded volume (sum of 5km cells): 151068.59 m3
# [35/95] Processing res_23_2040_35_Ens01_binary_30cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.4543 km2
#     Total flooded volume (sum of 5km cells): 1841098.38 m3
# [36/95] Processing res_23_2041_36_Ens01_binary_30cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1764 km2
#     Total flooded volume (sum of 5km cells): 166503.59 m3
# [37/95] Processing res_23_2041_37_Ens01_binary_30cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 3.6765 km2
#     Total flooded volume (sum of 5km cells): 2931350.25 m3
# [38/95] Processing res_23_2041_38_Ens01_binary_30cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.3464 km2
#     Total flooded volume (sum of 5km cells): 879880.44 m3
# [39/95] Processing res_23_2041_39_Ens01_binary_30cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6911 km2
#     Total flooded volume (sum of 5km cells): 1506248.12 m3
# [40/95] Processing res_23_2041_40_Ens01_binary_30cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9882 km2
#     Total flooded volume (sum of 5km cells): 824205.62 m3
# [41/95] Processing res_23_2042_41_Ens01_binary_30cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2142 km2
#     Total flooded volume (sum of 5km cells): 243599.39 m3
# ...
#     Total flooded area (sum of 5km cells): 0.1881 km2
#     Total flooded volume (sum of 5km cells): 110159.10 m3
# [14/98] Processing res_23_2009_14_Ens04_binary_30cm.tif (event=14)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_014.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_014.tif
#     Total flooded area (sum of 5km cells): 0.3366 km2
#     Total flooded volume (sum of 5km cells): 417285.00 m3
# [15/98] Processing res_23_2011_15_Ens04_binary_30cm.tif (event=15)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_015.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_015.tif
#     Total flooded area (sum of 5km cells): 0.2313 km2
#     Total flooded volume (sum of 5km cells): 227138.42 m3
# [16/98] Processing res_23_2011_16_Ens04_binary_30cm.tif (event=16)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_016.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_016.tif
#     Total flooded area (sum of 5km cells): 0.5400 km2
#     Total flooded volume (sum of 5km cells): 639733.50 m3
# [17/98] Processing res_23_2011_17_Ens04_binary_30cm.tif (event=17)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_017.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_017.tif
#     Total flooded area (sum of 5km cells): 0.3411 km2
#     Total flooded volume (sum of 5km cells): 321209.12 m3
# [18/98] Processing res_23_2018_18_Ens04_binary_30cm.tif (event=18)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_018.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_018.tif
#     Total flooded area (sum of 5km cells): 0.3060 km2
#     Total flooded volume (sum of 5km cells): 262602.91 m3
# [19/98] Processing res_23_2018_19_Ens04_binary_30cm.tif (event=19)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_019.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_019.tif
#     Total flooded area (sum of 5km cells): 1.2852 km2
#     Total flooded volume (sum of 5km cells): 965264.44 m3
# [20/98] Processing res_23_2022_20_Ens04_binary_30cm.tif (event=20)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_020.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_020.tif
#     Total flooded area (sum of 5km cells): 0.2484 km2
#     Total flooded volume (sum of 5km cells): 167099.39 m3
# [21/98] Processing res_23_2022_21_Ens04_binary_30cm.tif (event=21)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_021.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_021.tif
#     Total flooded area (sum of 5km cells): 0.2250 km2
#     Total flooded volume (sum of 5km cells): 154412.09 m3
# [22/98] Processing res_23_2025_22_Ens04_binary_30cm.tif (event=22)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_022.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_022.tif
#     Total flooded area (sum of 5km cells): 0.6435 km2
#     Total flooded volume (sum of 5km cells): 629776.88 m3
# [23/98] Processing res_23_2026_23_Ens04_binary_30cm.tif (event=23)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_023.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_023.tif
#     Total flooded area (sum of 5km cells): 4.2921 km2
#     Total flooded volume (sum of 5km cells): 3499202.75 m3
# [24/98] Processing res_23_2028_24_Ens04_binary_30cm.tif (event=24)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_024.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_024.tif
#     Total flooded area (sum of 5km cells): 0.2187 km2
#     Total flooded volume (sum of 5km cells): 233515.81 m3
# [25/98] Processing res_23_2029_25_Ens04_binary_30cm.tif (event=25)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_025.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_025.tif
#     Total flooded area (sum of 5km cells): 0.3879 km2
#     Total flooded volume (sum of 5km cells): 372402.91 m3
# [26/98] Processing res_23_2029_26_Ens04_binary_30cm.tif (event=26)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_026.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_026.tif
#     Total flooded area (sum of 5km cells): 0.7956 km2
#     Total flooded volume (sum of 5km cells): 911220.25 m3
# [27/98] Processing res_23_2031_27_Ens04_binary_30cm.tif (event=27)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_027.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_027.tif
#     Total flooded area (sum of 5km cells): 0.2358 km2
#     Total flooded volume (sum of 5km cells): 203907.59 m3
# [28/98] Processing res_23_2032_28_Ens04_binary_30cm.tif (event=28)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_028.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_028.tif
#     Total flooded area (sum of 5km cells): 0.2223 km2
#     Total flooded volume (sum of 5km cells): 244780.19 m3
# [29/98] Processing res_23_2032_29_Ens04_binary_30cm.tif (event=29)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_029.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_029.tif
#     Total flooded area (sum of 5km cells): 0.0243 km2
#     Total flooded volume (sum of 5km cells): 26253.90 m3
# [30/98] Processing res_23_2032_30_Ens04_binary_30cm.tif (event=30)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_area_5km_Ens04_23_30cm_event_030.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens04_23/30cm/flooded_volume_5km_Ens04_23_30cm_event_030.tif
#     Total flooded area (sum of 5km cells): 0.4473 km2
#     Total flooded volume (sum of 5km cells): 471568.50 m3
# [31/98] Processing res_23_2034_31_Ens04_binary_30cm.tif (event=31)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.3292 km2
#     Total flooded volume (sum of 5km cells): 1810647.88 m3
# [32/98] Processing res_23_2035_32_Ens04_binary_30cm.tif (event=32)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1197 km2
#     Total flooded volume (sum of 5km cells): 111758.41 m3
# [33/98] Processing res_23_2035_33_Ens04_binary_30cm.tif (event=33)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.0887 km2
#     Total flooded volume (sum of 5km cells): 3148096.75 m3
# [34/98] Processing res_23_2036_34_Ens04_binary_30cm.tif (event=34)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0999 km2
#     Total flooded volume (sum of 5km cells): 91980.90 m3
# [35/98] Processing res_23_2036_35_Ens04_binary_30cm.tif (event=35)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.1322 km2
#     Total flooded volume (sum of 5km cells): 927398.62 m3
# [36/98] Processing res_23_2036_36_Ens04_binary_30cm.tif (event=36)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1926 km2
#     Total flooded volume (sum of 5km cells): 185457.61 m3
# [37/98] Processing res_23_2037_37_Ens04_binary_30cm.tif (event=37)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1251 km2
#     Total flooded volume (sum of 5km cells): 111456.91 m3
# [38/98] Processing res_23_2037_38_Ens04_binary_30cm.tif (event=38)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3510 km2
#     Total flooded volume (sum of 5km cells): 341365.50 m3
# [39/98] Processing res_23_2038_39_Ens04_binary_30cm.tif (event=39)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1503 km2
#     Total flooded volume (sum of 5km cells): 99748.80 m3
# [40/98] Processing res_23_2038_40_Ens04_binary_30cm.tif (event=40)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4356 km2
#     Total flooded volume (sum of 5km cells): 311683.53 m3
# [41/98] Processing res_23_2041_41_Ens04_binary_30cm.tif (event=41)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0657 km2
#     Total flooded volume (sum of 5km cells): 145163.70 m3
# [42/98] Processing res_23_2042_42_Ens04_binary_30cm.tif (event=42)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3789 km2
#     Total flooded volume (sum of 5km cells): 252611.09 m3
# [43/98] Processing res_23_2042_43_Ens04_binary_30cm.tif (event=43)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.8783 km2
#     Total flooded volume (sum of 5km cells): 2027962.75 m3
# [44/98] Processing res_23_2042_44_Ens04_binary_30cm.tif (event=44)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.5812 km2
#     Total flooded volume (sum of 5km cells): 2065976.12 m3
# [45/98] Processing res_23_2044_45_Ens04_binary_30cm.tif (event=45)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1341 km2
#     Total flooded volume (sum of 5km cells): 90721.80 m3
# [46/98] Processing res_23_2044_46_Ens04_binary_30cm.tif (event=46)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1548 km2
#     Total flooded volume (sum of 5km cells): 236038.50 m3
# [47/98] Processing res_23_2045_47_Ens04_binary_30cm.tif (event=47)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4184 km2
#     Total flooded volume (sum of 5km cells): 1318822.12 m3
# [48/98] Processing res_23_2046_48_Ens04_binary_30cm.tif (event=48)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2745 km2
#     Total flooded volume (sum of 5km cells): 299522.69 m3
# [49/98] Processing res_23_2046_49_Ens04_binary_30cm.tif (event=49)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.3213 km2
#     Total flooded volume (sum of 5km cells): 227300.41 m3
# [50/98] Processing res_23_2046_50_Ens04_binary_30cm.tif (event=50)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9144 km2
#     Total flooded volume (sum of 5km cells): 1095147.00 m3
# [51/98] Processing res_23_2046_51_Ens04_binary_30cm.tif (event=51)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6803 km2
#     Total flooded volume (sum of 5km cells): 1247661.88 m3
# [52/98] Processing res_23_2049_52_Ens04_binary_30cm.tif (event=52)
# Skippping QA
#     Total flooded area (sum of 5km cells): 2.1969 km2
#     Total flooded volume (sum of 5km cells): 1989640.75 m3
# [53/98] Processing res_23_2049_53_Ens04_binary_30cm.tif (event=53)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.9360 km2
#     Total flooded volume (sum of 5km cells): 899959.56 m3
# [54/98] Processing res_23_2050_54_Ens04_binary_30cm.tif (event=54)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.4868 km2
#     Total flooded volume (sum of 5km cells): 1098501.25 m3
# [55/98] Processing res_23_2050_55_Ens04_binary_30cm.tif (event=55)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2808 km2
#     Total flooded volume (sum of 5km cells): 205752.59 m3
# [56/98] Processing res_23_2050_56_Ens04_binary_30cm.tif (event=56)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0072 km2
#     Total flooded volume (sum of 5km cells): 15180.30 m3
# [57/98] Processing res_23_2050_57_Ens04_binary_30cm.tif (event=57)
# Skippping QA
#     Total flooded area (sum of 5km cells): 1.6974 km2
#     Total flooded volume (sum of 5km cells): 1354627.75 m3
# [58/98] Processing res_23_2051_58_Ens04_binary_30cm.tif (event=58)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.0090 km2
#     Total flooded volume (sum of 5km cells): 7518.60 m3
# [59/98] Processing res_23_2052_59_Ens04_binary_30cm.tif (event=59)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.1008 km2
#     Total flooded volume (sum of 5km cells): 85473.90 m3
# [60/98] Processing res_23_2052_60_Ens04_binary_30cm.tif (event=60)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.2727 km2
#     Total flooded volume (sum of 5km cells): 200272.50 m3
# [61/98] Processing res_23_2052_61_Ens04_binary_30cm.tif (event=61)
# Skippping QA
#     Total flooded area (sum of 5km cells): 4.3020 km2
#     Total flooded volume (sum of 5km cells): 3726545.50 m3
# [62/98] Processing res_23_2053_62_Ens04_binary_30cm.tif (event=62)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.8514 km2
#     Total flooded volume (sum of 5km cells): 738774.00 m3
# [63/98] Processing res_23_2053_63_Ens04_binary_30cm.tif (event=63)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.4662 km2
#     Total flooded volume (sum of 5km cells): 407731.50 m3
# [64/98] Processing res_23_2055_64_Ens04_binary_30cm.tif (event=64)
# Skippping QA
#     Total flooded area (sum of 5km cells): 0.7614 km2
#     Total flooded volume (sum of 5km cells): 562260.62 m3
# [65/98] Processing res_23_2058_65_Ens04_binary_30cm.tif (event=65)
# Skippping QA
# KeyboardInterrupt

# %% [markdown]
# ### To save TIFF versions for checking in QGIS

# %%
# HA_NUM = '23'
# print(f"Running for {HA_NUM}")
# OUT_DIR = f"/scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_{HA_NUM}"
# print(f"Outputs to be stored in {OUT_DIR}")

# # -----------------------------
# # OPEN 5km GRID
# # -----------------------------
# print(f"Loading 5km grid from {GRID_5KM_FILE}...")
# ds = xr.open_dataset(GRID_5KM_FILE)

# x5 = ds["projection_x_coordinate"]
# y5 = ds["projection_y_coordinate"]

# nx = x5.size
# ny = y5.size

# dx = float(abs(x5[1] - x5[0]))
# dy = float(abs(y5[1] - y5[0]))

# xmin = float(x5.min() - dx/2)
# xmax = float(x5.max() + dx/2)
# ymin = float(y5.min() - dy/2)
# ymax = float(y5.max() + dy/2)

# # -----------------------------
# # CREATE GRID-ID RASTER
# # -----------------------------
# grid_ids = np.arange(nx * ny).reshape(ny, nx)

# # Use standard y, x dimension names for rioxarray compatibility
# grid_da = xr.DataArray(
#     grid_ids,
#     coords={"y": y5.values, "x": x5.values},
#     dims=("y", "x"))

# grid_da = grid_da.rio.write_crs("EPSG:27700")

# transform = from_bounds(xmin, ymin, xmax, ymax, nx, ny)
# grid_da.rio.write_transform(transform, inplace=True)

# # Export a GeoTIFF copy of the 5km grid IDs for visual QA.
# # grid_out_dir = os.path.join(OUT_DIR, "grid")
# # os.makedirs(grid_out_dir, exist_ok=True)
# # grid_tif_path = os.path.join(grid_out_dir, f"grid_id_5km_from_input_{HA_NUM}.tif")
# # print(f"Saving 5km grid GeoTIFF to {grid_tif_path}...")
# # grid_da.astype("int32").rio.to_raster(grid_tif_path)

# # -----------------------------
# # COLLECT ALL EVENT FILES
# # -----------------------------
# print(f"Scanning for binary tif files for HA_NUM={HA_NUM}...")
# binary_event_files = list(iter_event_tifs(HA_NUM, data_kind="binary"))

# print(f"Scanning for filtered depth tif files for HA_NUM={HA_NUM}...")
# filtered_event_files = list(iter_event_tifs(HA_NUM, data_kind="filtered"))

# if not binary_event_files:
#     raise ValueError(f"No binary tif files found for HA_NUM={HA_NUM}")

# if not filtered_event_files:
#     raise ValueError(f"No filtered depth tif files found for HA_NUM={HA_NUM}")

# print(f"Found {len(binary_event_files)} binary event files")
# print(f"Found {len(filtered_event_files)} filtered depth event files")

# # -----------------------------
# # GROUP BY ENSEMBLE
# # -----------------------------
# from collections import defaultdict
# binary_by_ensemble = defaultdict(list)
# filtered_lookup = {}

# for info in binary_event_files:
#     binary_by_ensemble[info['ensemble']].append(info)

# for info in filtered_event_files:
#     key = (info["ensemble"], info["threshold"], info["event_num"])
#     filtered_lookup[key] = info

# print(f"Found {len(binary_by_ensemble)} ensemble members")

# # -----------------------------
# # PROCESS EACH ENSEMBLE + THRESHOLD SEPARATELY
# # -----------------------------
# for ens_name in sorted(binary_by_ensemble.keys())[0:1]:
# #     for ens_name in ['Ens13_106']:        
#     ens_events = binary_by_ensemble[ens_name]
#     ens_events.sort(key=lambda x: (x['threshold'], x['event_num']))

#     print(f"\n{'='*60}")
#     print(f"Processing {ens_name}: {len(ens_events)} total events")
#     print(f"{'='*60}")

#     for thr in ['10cm']:
#         thr_events = [e for e in ens_events if e["threshold"] == thr][:30]
#         print(f"\n[{ens_name} | {thr}] Processing {len(thr_events)} events")

#         flood_areas = []
#         flood_volumes = []
#         for i, info in enumerate(thr_events):
#             print(f"[{i+1}/{len(thr_events)}] Processing {os.path.basename(info['path'])} (event={info['event_num']})")

#             key = (ens_name, thr, info["event_num"])
#             if key not in filtered_lookup:
#                 raise ValueError(
#                     f"Missing filtered depth tif for {ens_name}, {thr}, event={info['event_num']}")

#             filtered_info = filtered_lookup[key]

#             qa_out_tif = None
#             if WRITE_QA_GRID_INDEX_TIF and i < QA_MAX_EVENTS_PER_THRESHOLD:
#                 print("Performing QA")
#                 qa_dir = os.path.join(OUT_DIR, "qa", ens_name, thr)
#                 qa_out_tif = os.path.join(qa_dir,
#                     f"qa_5km_cell_index_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
#                 print(f"    Writing QA 30m->5km index raster: {qa_out_tif}")
#             else:
#                 print("Skippping QA")

#             flood_area = process_single_event_area(info['path'],x5, y5, nx, ny,qa_out_tif=qa_out_tif)

#             flood_volume = process_single_event_volume(filtered_info["path"],x5, y5, nx, ny)

#             # --- NEW: export a few events as GeoTIFF for QGIS comparison ---
#             if WRITE_QA_OUTPUT_TIF and i < TIF_MAX_EVENTS_PER_THRESHOLD:
#                 tif_qa_dir = os.path.join(OUT_DIR, "qa_output_tif", ens_name, thr)

#                 area_tif_path = os.path.join(
#                     tif_qa_dir,
#                     f"flooded_area_5km_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
#                 save_5km_array_as_geotiff(flood_area, x5.values, y5.values, transform, area_tif_path)

#                 volume_tif_path = os.path.join(
#                     tif_qa_dir,
#                     f"flooded_volume_5km_{ens_name}_{thr}_event_{info['event_num']:03d}.tif")
#                 save_5km_array_as_geotiff(flood_volume, x5.values, y5.values, transform, volume_tif_path)

#                 print(f"    Wrote QA GeoTIFFs: {area_tif_path}, {volume_tif_path}")
#             # --- end NEW ---
# Out:
# Running for 23
# Outputs to be stored in /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23
# Loading 5km grid from /scratch/hydro4/users/la17355/FUTURE-FLOOD/UKCP_rainfall/5km/Ens_01/bc_pr_rcp85_land-cpm_uk_5km_01_1hr_19901201-19911130.nc...
# Scanning for binary tif files for HA_NUM=23...
# Scanning for filtered depth tif files for HA_NUM=23...
# Found 1748 binary event files
# Found 1748 filtered depth event files
# Found 12 ensemble members
#
# ============================================================
# Processing Ens01_23: 190 total events
# ============================================================
#
# [Ens01_23 | 10cm] Processing 30 events
# [1/30] Processing res_23_1992_1_Ens01_binary_10cm.tif (event=1)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_001.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_001.tif
# [2/30] Processing res_23_1994_2_Ens01_binary_10cm.tif (event=2)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_002.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_002.tif
# [3/30] Processing res_23_1994_3_Ens01_binary_10cm.tif (event=3)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_003.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_003.tif
# [4/30] Processing res_23_1995_4_Ens01_binary_10cm.tif (event=4)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_004.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_004.tif
# [5/30] Processing res_23_2001_5_Ens01_binary_10cm.tif (event=5)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_005.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_005.tif
# [6/30] Processing res_23_2001_6_Ens01_binary_10cm.tif (event=6)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_006.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_006.tif
# [7/30] Processing res_23_2004_7_Ens01_binary_10cm.tif (event=7)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_007.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_007.tif
# [8/30] Processing res_23_2004_8_Ens01_binary_10cm.tif (event=8)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_008.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_008.tif
# [9/30] Processing res_23_2004_9_Ens01_binary_10cm.tif (event=9)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_009.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_009.tif
# [10/30] Processing res_23_2008_10_Ens01_binary_10cm.tif (event=10)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_010.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_010.tif
# [11/30] Processing res_23_2011_11_Ens01_binary_10cm.tif (event=11)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_011.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_011.tif
# [12/30] Processing res_23_2011_12_Ens01_binary_10cm.tif (event=12)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_012.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_012.tif
# [13/30] Processing res_23_2013_13_Ens01_binary_10cm.tif (event=13)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_013.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_013.tif
# [14/30] Processing res_23_2016_14_Ens01_binary_10cm.tif (event=14)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_014.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_014.tif
# [15/30] Processing res_23_2017_15_Ens01_binary_10cm.tif (event=15)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_015.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_015.tif
# [16/30] Processing res_23_2018_16_Ens01_binary_10cm.tif (event=16)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_016.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_016.tif
# [17/30] Processing res_23_2019_17_Ens01_binary_10cm.tif (event=17)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_017.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_017.tif
# [18/30] Processing res_23_2019_18_Ens01_binary_10cm.tif (event=18)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_018.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_018.tif
# [19/30] Processing res_23_2020_19_Ens01_binary_10cm.tif (event=19)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_019.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_019.tif
# [20/30] Processing res_23_2022_20_Ens01_binary_10cm.tif (event=20)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_020.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_020.tif
# [21/30] Processing res_23_2023_21_Ens01_binary_10cm.tif (event=21)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_021.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_021.tif
# [22/30] Processing res_23_2025_22_Ens01_binary_10cm.tif (event=22)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_022.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_022.tif
# [23/30] Processing res_23_2025_23_Ens01_binary_10cm.tif (event=23)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_023.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_023.tif
# [24/30] Processing res_23_2026_24_Ens01_binary_10cm.tif (event=24)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_024.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_024.tif
# [25/30] Processing res_23_2027_25_Ens01_binary_10cm.tif (event=25)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_025.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_025.tif
# [26/30] Processing res_23_2027_26_Ens01_binary_10cm.tif (event=26)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_026.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_026.tif
# [27/30] Processing res_23_2029_27_Ens01_binary_10cm.tif (event=27)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_027.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_027.tif
# [28/30] Processing res_23_2033_28_Ens01_binary_10cm.tif (event=28)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_028.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_028.tif
# [29/30] Processing res_23_2035_29_Ens01_binary_10cm.tif (event=29)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_029.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_029.tif
# [30/30] Processing res_23_2035_30_Ens01_binary_10cm.tif (event=30)
# Skippping QA
#     Wrote QA GeoTIFFs: /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_area_5km_Ens01_23_10cm_event_030.tif, /scratch/hydro4/users/kv25483/FutureFlood/Data/PluvialResults/5km_total/Catchment_23/qa_output_tif/Ens01_23/10cm/flooded_volume_5km_Ens01_23_10cm_event_030.tif
