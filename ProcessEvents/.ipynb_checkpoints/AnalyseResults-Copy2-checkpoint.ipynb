# %%
def plot_with_best_fit_line(results_df, ax, col1, col2, label1, label2, title):
    x = results_df[col1]
    y = results_df[col2]

    ax.scatter(x, y)

    # 🔹 Fit line
    m, b = np.polyfit(x, y, 1)

    # Predicted values
    y_pred = m * x + b

    # R²
    ss_res = np.sum((y - y_pred)**2)
    ss_tot = np.sum((y - np.mean(y))**2)
    r2 = 1 - (ss_res / ss_tot)

    # 🔹 Create line values
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = m * x_line + b

    # 🔹 Plot line
    ax.plot(x_line, y_line, color='black')

    ax.text( 0.05, 0.95,  f'$R^2 = {r2:.2f}$', transform=ax.transAxes, verticalalignment='top')

    ax.set_xlabel(label1)
    ax.set_ylabel(label2)
    
    ax.set_title(title)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyproj import Transformer

# %% [markdown]
# ### Get data across all ensemble members

# %%
ENS_LIST = ['01', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '15']
all_ens = list()
for ens in ENS_LIST:
    this_en = pd.read_csv(f"../../Data/Events/results_ens_{ens}.csv")
    all_ens.append(this_en)
results_all = pd.concat(all_ens)
# results_all['30cm_fld_vol_under_threshold']

# %%
# Define transformer (WGS84 → BNG)
transformer = Transformer.from_crs("EPSG:4326", "EPSG:27700", always_xy=True)

# Newcastle coordinates (lon, lat!)
lon, lat = -1.601382, 54.970304

newcastle_x, newcastle_y = transformer.transform(lon, lat)

# Euclidean distance in metres (BNG is in metres)
dist = np.sqrt((results_all['x_coord'] - newcastle_x)**2 +(results_all['y_coord'] - newcastle_y)**2)

# Create boolean column (within 10 km = 10,000 m)
results_all['within_10km_city_centre'] = dist <= 10000

results_all['distance_to_city_centre'] = dist

# %%
results_all.columns
# Out:
# Index(['event_num', 'yr', 'start_idx', 'stop_idx', 'max_precip', 't_global',
#        'x_idx', 'y_idx', 'x_coord', 'y_coord', 'total_acc',
#        'peak_position_ratio', 'd50', 'gini', 'time_based_std', 'dry_ratio',
#        'max_quartile_index', 'times', 'values', '10cm_peak_value',
#        '10cm_threshold', '10cm_threshold_mask', '10cm_cluster_mask',
#        '10cm_neighbourhood_sum', '10cm_fld_area_at_peak',
#        '10cm_fld_vol_at_peak', '10cm_fld_area_under_threshold',
#        '10cm_fld_vol_under_threshold', '10cm_fld_area_under_cluster',
#        '10cm_fld_vol_under_cluster', '30cm_peak_value', '30cm_threshold',
#        '30cm_threshold_mask', '30cm_cluster_mask', '30cm_neighbourhood_sum',
#        '30cm_fld_area_at_peak', '30cm_fld_vol_at_peak',
#        '30cm_fld_area_under_threshold', '30cm_fld_vol_under_threshold',
#        '30cm_fld_area_under_cluster', '30cm_fld_vol_under_cluster',
#        'mean_sm_2_before_event', 'mean_sm_3_before_event',
# ...

# %%
explainer_variables = ['max_precip', 'x_coord', 'y_coord', 'total_acc','peak_position_ratio', 'd50', 'gini', 'time_based_std', 
                       'dry_ratio', 'max_quartile_index', '10cm_neighbourhood_sum', 'within_10km_city_centre',
#                        'mean_sm_2_before_event', 'mean_sm_3_before_event', 'mean_sm_4_before_event', 'mean_sm_5_before_event',
                       'mean_sm_catchment']
predictor_variable = '10cm_fld_area_at_peak'

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# Split data into train/test
X_train, X_test, y_train, y_test = train_test_split(results_all[explainer_variables], 
                                                    results_all[predictor_variable], 
                                                    test_size=0.2, random_state=42)

# Fit Random Forest
rf = RandomForestRegressor(n_estimators=500, random_state=42)
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)

# Model performance
print("R²:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R²: 0.8306050361871509
# RMSE: 0.028815556751564525

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'rf' is your trained RandomForestRegressor
feature_importances = pd.Series(rf.feature_importances_, index=explainer_variables)

# Sort descending
feature_importances = feature_importances.sort_values(ascending=False)

# Print
print(feature_importances)

# Optional: plot
plt.figure(figsize=(10,6))
sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="viridis")
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Random Forest Feature Importance")
plt.show()
# Out:
# x_coord                    0.448557
# total_acc                  0.155984
# y_coord                    0.117201
# max_precip                 0.100906
# 10cm_neighbourhood_sum     0.046406
# mean_sm_catchment          0.021521
# gini                       0.021447
# d50                        0.019780
# peak_position_ratio        0.019404
# within_10km_city_centre    0.018509
# time_based_std             0.017608
# dry_ratio                  0.010713
# max_quartile_index         0.001963
# dtype: float64
# /tmp/ipykernel_1239540/1251516029.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="viridis")

# %%
near_newcastle = results_all[results_all["within_10km_city_centre"]==True]

# %%
from scipy.stats import linregress
df = near_newcastle.copy()
explainer_varible = 'mean_sm_2_before_event'
x = df['total_acc']
y = df['10cm_fld_area_at_peak']

# Fit linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Predicted values
y_pred = intercept + slope * x

# Residuals
df['residuals'] = y - y_pred

import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.scatter(df[explainer_varible], df['residuals'])

plt.axhline(0, linestyle='--')  # reference line
plt.xlabel('Mean soil moisture')
plt.ylabel('Residual flood area')
plt.title('Residuals vs Soil Moisture')

plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

# --- Top row: Near Newcastle ---
plot_with_best_fit_line(
    near_newcastle, axs[0, 0],
    'total_acc', '10cm_fld_area_at_peak',
    'Accumulated rainfall at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 10cm')

plot_with_best_fit_line(
    near_newcastle, axs[0, 1],
    'total_acc', '30cm_fld_area_at_peak',
    'Accumulated rainfall at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 30cm')

# --- Bottom row: All events ---
plot_with_best_fit_line(
    results_all, axs[1, 0],
    'total_acc', '10cm_fld_area_at_peak',
    'Accumulated rainfall at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 10cm')

plot_with_best_fit_line(
    results_all, axs[1, 1],
    'total_acc', '30cm_fld_area_at_peak',
    'Accumulated rainfall at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 30cm')

# Titles for rows (optional but clearer)
axs[0, 0].set_title("Near Newcastle (10cm)")
axs[0, 1].set_title("Near Newcastle (30cm)")
axs[1, 0].set_title("All events (10cm)")
axs[1, 1].set_title("All events (30cm)")

fig.suptitle("Rainfall accumulation vs Flood Relationships", fontsize=14)
fig.tight_layout()

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

# --- Top row: Near Newcastle ---
plot_with_best_fit_line(
    near_newcastle, axs[0, 0],
    'max_precip', '10cm_fld_area_at_peak',
    'Max precip at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 10cm')

plot_with_best_fit_line(
    near_newcastle, axs[0, 1],
    'max_precip', '30cm_fld_area_at_peak',
    'Max precip at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 30cm')

# --- Bottom row: All events ---
plot_with_best_fit_line(
    results_all, axs[1, 0],
    'max_precip', '10cm_fld_area_at_peak',
    'Max precip at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 10cm')

plot_with_best_fit_line(
    results_all, axs[1, 1],
    'max_precip', '30cm_fld_area_at_peak',
    'Max precip at grid \n cell with maximum',
    'Flood area at grid \n cell with maximum',
    'Flooding over 30cm')

# Titles for rows (optional but clearer)
axs[0, 0].set_title("Near Newcastle (10cm)")
axs[0, 1].set_title("Near Newcastle (30cm)")
axs[1, 0].set_title("All events (10cm)")
axs[1, 1].set_title("All events (30cm)")

fig.suptitle("Max precip vs Flood Relationships", fontsize=14)
fig.tight_layout()

# %%
# fig, axs = plt.subplots(ncols=2, figsize=(10,3))
# plot_with_best_fit_line(near_newcastle, axs[0], 'max_precip', '10cm_fld_area_under_cluster',
#                        'Maximum precipitation intensity', 'Flood area at grid \n cell with maximum',
#                        'Flooding over 10cm')
# plot_with_best_fit_line(near_newcastle, axs[1], 'max_precip', '30cm_fld_area_under_cluster',
#                        'Maximum precipitation intensity', 'Flood area at grid \n cell with maximum',
#                        'Flooding over 30cm')
# # fig.tight_layout()
